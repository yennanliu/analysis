# %%
# !ls
# Out:
# google_cloud_creds2.json       sample_data
# random_10K_image_urls (1).csv  vision_api_query_sample.csv
# random_10K_image_urls.csv

# %%
# install library 
#!pip install google-cloud-vision

# %%
rm random_10K_image_urls.csv

# %%
# upload the crendential 

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ecd9f3a7-fa86-48b0-95ae-800dca260e6b" name="files[]" multiple disabled />
#      <output id="result-ecd9f3a7-fa86-48b0-95ae-800dca260e6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving random_10K_image_urls.csv to random_10K_image_urls.csv

# %%
# python 3 



# gcloud 
from google.cloud import vision
from google.oauth2 import service_account
from google.protobuf.json_format import MessageToDict

# OP 
import pandas as pd 
import numpy as np 

#--------------------------------------------------
# config 
# save ur google cloud credentials below
credentials = service_account.Credentials.from_service_account_file('google_cloud_creds2.json')
client = vision.ImageAnnotatorClient(credentials=credentials)


#--------------------------------------------------
# help func 


"""

# https://cloud.google.com/vision/docs/other-features

1) Image properties : vision.enums.Feature.Type.IMAGE_PROPERTIES
2) Web entities : vision.enums.Feature.Type.WEB_DETECTION
3) Safe search :  vision.enums.Feature.Type.SAFE_SEARCH_DETECTION

"""



def call_google_image_api(url,type):
    response = client.annotate_image({
    'image': {'source': {'image_uri': url}},
    'features': [{'type': type}],})
    print ('response : ', response)
    response_dict = MessageToDict(response)
    return response_dict



def g_face_detection(url):
    response = client.annotate_image({
    'image': {'source': {'image_uri': url}},
    'features': [{'type': vision.enums.Feature.Type.FACE_DETECTION}],})
    print ('response : ', response)
    response_dict = MessageToDict(response)
    return response_dict


def g_image_property(url):
    response = client.annotate_image({
    'image': {'source': {'image_uri': url}},
    'features': [{'type': vision.enums.Feature.Type.IMAGE_PROPERTIES}],})
    print ('response : ', response)
    response_dict = MessageToDict(response)
    return response_dict
  
  
def g_web_detection(url):
    response = client.annotate_image({
    'image': {'source': {'image_uri': url}},
    'features': [{'type': vision.enums.Feature.Type.WEB_DETECTION}],})
    print ('response : ', response)
    response_dict = MessageToDict(response)
    return response_dict




def call_google_handwritten_api(uri):

    from google.cloud import vision_v1p3beta1 as vision
    credentials = service_account.Credentials.from_service_account_file('google_cloud_creds2.json')
    
    
    client = vision.ImageAnnotatorClient(credentials=credentials)
    image = vision.types.Image()
    image.source.image_uri = uri

    # Language hint codes for handwritten OCR:
    # en-t-i0-handwrit, mul-Latn-t-i0-handwrit
    # Note: Use only one language hint code per request for handwritten OCR.
    image_context = vision.types.ImageContext(
        language_hints=['en-t-i0-handwrit'])

    response = client.document_text_detection(image=image,
                                              image_context=image_context)

    print('Full Text: {}'.format(response.full_text_annotation.text))
    for page in response.full_text_annotation.pages:
        for block in page.blocks:
            print('\nBlock confidence: {}\n'.format(block.confidence))

            for paragraph in block.paragraphs:
                print('Paragraph confidence: {}'.format(
                    paragraph.confidence))

                for word in paragraph.words:
                    word_text = ''.join([
                        symbol.text for symbol in word.symbols
                    ])
                    print('Word text: {} (confidence: {})'.format(
                        word_text, word.confidence))

                    for symbol in word.symbols:
                        print('\tSymbol: {} (confidence: {})'.format(
                            symbol.text, symbol.confidence))


#--------------------------------------------------


def get_web_entity(web_property_response):
  return [i for i in web_property_response['webDetection']['webEntities'] ]

# %%
####### run on uri dataframe  (but with object product image) #######

"""

# https://cloud.google.com/vision/docs/other-features

1) Image properties : vision.enums.Feature.Type.IMAGE_PROPERTIES
2) Web entities : vision.enums.Feature.Type.WEB_DETECTION
3) Safe search :  vision.enums.Feature.Type.SAFE_SEARCH_DETECTION

"""



url_list2 = ['https://www.hellyhansen.com/media/catalog/product/cache/c687aa7517cf01e65c009f6943c2b1e9/6/7/67029_898.jpg',
             'https://www.patagonia.com/dis/dw/image/v2/ABBM_PRD/on/demandware.static/-/Sites-patagonia-master/default/dw0b78138c/images/hi-res/27805_COI.jpg?sw=750&sh=750&sm=fit&sfrm=png',
             'https://www.nigeltyas.co.uk/pub/media/catalog/product/images/hepworth-wrought-iron-table-lamp-1.jpg',
             'https://secure.img1-fg.wfcdn.com/im/06953777/compr-r85/3696/36966209/marsdeni-barrel-chair.jpg']

# %%
df_query_result2 = pd.DataFrame({ 'url':url_list2 })

# %%
df_query_result2
# Out:
#                                                  url
# 0  https://www.hellyhansen.com/media/catalog/prod...
# 1  https://www.patagonia.com/dis/dw/image/v2/ABBM...
# 2  https://www.nigeltyas.co.uk/pub/media/catalog/...
# 3  https://secure.img1-fg.wfcdn.com/im/06953777/c...

# %%
df_query_result2['image_property'] = df_query_result2['url'].apply(lambda x : g_image_property(x))
df_query_result2['web_detection'] = df_query_result2['url'].apply(lambda x : g_web_detection(x))
# Out:
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 78.0
#         green: 81.0
#         blue: 84.0
#       }
#       score: 0.4108472764492035
#       pixel_fraction: 0.23591837286949158
#     }
#     colors {
#       color {
#         red: 185.0
#         green: 204.0
#         blue: 131.0
#       }
#       score: 0.038874302059412
#       pixel_fraction: 0.00362244900316
#     }
#     colors {
#       color {
#         red: 72.0
#         green: 89.0
#         blue: 56.0
#       }
#       score: 0.026838770136237144
#       pixel_fraction: 0.007040816359221935
#     }
#     colors {
#       color {
#         red: 139.0
#         green: 163.0
#         blue: 125.0
#       }
#       score: 0.01559548731893301
#       pixel_fraction: 0.004285714123398066
#     }
#     colors {
#       color {
#         red: 52.0
#         green: 54.0
#         blue: 58.0
#       }
#       score: 0.19434647262096405
#       pixel_fraction: 0.16443876922130585
#     }
#     colors {
#       color {
#         red: 26.0
#         green: 26.0
#         blue: 31.0
#       }
#       score: 0.06905682384967804
#       pixel_fraction: 0.07826530933380127
#     }
#     colors {
#       color {
#         red: 43.0
#         green: 57.0
#         blue: 28.0
#       }
#       score: 0.02465449646115303
#       pixel_fraction: 0.004795918241143227
#     }
#     colors {
#       color {
#         red: 67.0
#         green: 87.0
#         blue: 75.0
#       }
#       score: 0.02375384047627449
#       pixel_fraction: 0.006224489770829678
#     }
#     colors {
#       color {
#         red: 107.0
#         green: 117.0
#         blue: 111.0
#       }
#       score: 0.019869830459356308
#       pixel_fraction: 0.017244897782802582
#     }
#     colors {
#       color {
#         red: 145.0
#         green: 156.0
#         blue: 150.0
#       }
#       score: 0.018351033329963684
#       pixel_fraction: 0.01448979601264
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 699
#       }
#       vertices {
#         x: 699
#         y: 699
#       }
#       vertices {
#         y: 699
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 152.0
#         green: 110.0
#         blue: 70.0
#       }
#       score: 0.5439797043800354
#       pixel_fraction: 0.2456616908311844
#     }
#     colors {
#       color {
#         red: 121.0
#         green: 81.0
#         blue: 43.0
#       }
#       score: 0.18287068605422974
#       pixel_fraction: 0.08621297031641006
#     }
#     colors {
#       color {
#         red: 254.0
#         green: 241.0
#         blue: 219.0
#       }
#       score: 0.000981755554676056
#       pixel_fraction: 0.006991600152105093
#     }
#     colors {
#       color {
#         red: 114.0
#         green: 77.0
#         blue: 49.0
#       }
#       score: 0.08241540193557739
#       pixel_fraction: 0.07806448638439178
#     }
#     colors {
#       color {
#         red: 147.0
#         green: 108.0
#         blue: 77.0
#       }
#       score: 0.05694543197751045
#       pixel_fraction: 0.03334842249751091
#     }
#     colors {
#       color {
#         red: 175.0
#         green: 134.0
#         blue: 93.0
#       }
#       score: 0.037601206451654434
#       pixel_fraction: 0.015944872051477432
#     }
#     colors {
#       color {
#         red: 78.0
#         green: 44.0
#         blue: 22.0
#       }
#       score: 0.03452768921852112
#       pixel_fraction: 0.02967657521367073
#     }
#     colors {
#       color {
#         red: 152.0
#         green: 118.0
#         blue: 72.0
#       }
#       score: 0.015491941943764687
#       pixel_fraction: 0.012373623438179493
#     }
#     colors {
#       color {
#         red: 89.0
#         green: 50.0
#         blue: 16.0
#       }
#       score: 0.014751388691365719
#       pixel_fraction: 0.006840702146291733
#     }
#     colors {
#       color {
#         red: 145.0
#         green: 116.0
#         blue: 87.0
#       }
#       score: 0.005949700251221657
#       pixel_fraction: 0.01649816334247589
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 749
#       }
#       vertices {
#         x: 749
#         y: 749
#       }
#       vertices {
#         y: 749
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 50.0
#         green: 19.0
#         blue: 2.0
#       }
#       score: 0.2590746581554413
#       pixel_fraction: 0.006229860242456198
#     }
#     colors {
#       color {
#         red: 116.0
#         green: 70.0
#         blue: 28.0
#       }
#       score: 0.18171653151512146
#       pixel_fraction: 0.01904761977493763
#     }
#     colors {
#       color {
#         red: 254.0
#         green: 105.0
#         blue: 61.0
#       }
#       score: 0.014626862481236458
#       pixel_fraction: 0.04869316145777702
#     }
#     colors {
#       color {
#         red: 225.0
#         green: 172.0
#         blue: 96.0
#       }
#       score: 0.0021307580173015594
#       pixel_fraction: 0.011170784011483192
#     }
#     colors {
#       color {
#         red: 70.0
#         green: 39.0
#         blue: 16.0
#       }
#       score: 0.20047667622566223
#       pixel_fraction: 0.0051557463593780994
#     }
#     colors {
#       color {
#         red: 96.0
#         green: 48.0
#         blue: 6.0
#       }
#       score: 0.16416515409946442
#       pixel_fraction: 0.005943430121988058
#     }
#     colors {
#       color {
#         red: 36.0
#         green: 7.0
#         blue: 1.0
#       }
#       score: 0.04888037592172623
#       pixel_fraction: 0.0010025062365457416
#     }
#     colors {
#       color {
#         red: 79.0
#         green: 56.0
#         blue: 30.0
#       }
#       score: 0.023402437567710876
#       pixel_fraction: 0.0005728607065975666
#     }
#     colors {
#       color {
#         red: 100.0
#         green: 74.0
#         blue: 50.0
#       }
#       score: 0.022415027022361755
#       pixel_fraction: 0.0008592910598963499
#     }
#     colors {
#       color {
#         red: 153.0
#         green: 104.0
#         blue: 55.0
#       }
#       score: 0.021602045744657516
#       pixel_fraction: 0.11335481703281403
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 599
#       }
#       vertices {
#         x: 599
#         y: 928
#       }
#       vertices {
#         y: 928
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 39.0
#         green: 44.0
#         blue: 71.0
#       }
#       score: 0.6791887283325195
#       pixel_fraction: 0.44084444642066956
#     }
#     colors {
#       color {
#         red: 25.0
#         green: 30.0
#         blue: 53.0
#       }
#       score: 0.14356255531311035
#       pixel_fraction: 0.09257777780294418
#     }
#     colors {
#       color {
#         red: 70.0
#         green: 84.0
#         blue: 119.0
#       }
#       score: 0.1305219978094101
#       pixel_fraction: 0.05000000074505806
#     }
#     colors {
#       color {
#         red: 123.0
#         green: 125.0
#         blue: 138.0
#       }
#       score: 0.0006594613660126925
#       pixel_fraction: 0.0025333333760499954
#     }
#     colors {
#       color {
#         red: 47.0
#         green: 48.0
#         blue: 82.0
#       }
#       score: 0.04172151908278465
#       pixel_fraction: 0.01595555618405342
#     }
#     colors {
#       color {
#         red: 242.0
#         green: 243.0
#         blue: 245.0
#       }
#       score: 0.00032683188328519464
#       pixel_fraction: 0.3653777837753296
#     }
#     colors {
#       color {
#         red: 20.0
#         green: 20.0
#         blue: 28.0
#       }
#       score: 0.0015399050898849964
#       pixel_fraction: 0.013066667132079601
#     }
#     colors {
#       color {
#         red: 26.0
#         green: 28.0
#         blue: 58.0
#       }
#       score: 0.0009297776850871742
#       pixel_fraction: 0.0009333333582617342
#     }
#     colors {
#       color {
#         red: 46.0
#         green: 46.0
#         blue: 57.0
#       }
#       score: 0.0007441876223310828
#       pixel_fraction: 0.005111111328005791
#     }
#     colors {
#       color {
#         red: 81.0
#         green: 82.0
#         blue: 94.0
#       }
#       score: 0.00045006719301454723
#       pixel_fraction: 0.0026666666381061077
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 2527
#       }
#       vertices {
#         x: 2527
#         y: 2527
#       }
#       vertices {
#         y: 2527
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/01940j"
#     score: 1.4008290767669678
#     description: "Backpack"
#   }
#   web_entities {
#     entity_id: "/m/0n5v01m"
#     score: 0.8273212909698486
#     description: "Bag"
#   }
#   web_entities {
#     entity_id: "/g/11g06sdhk7"
#     score: 0.7199000120162964
#     description: "Dublin Backpack"
#   }
#   web_entities {
#     entity_id: "/g/11f7s22tfl"
#     score: 0.7124000191688538
#     description: "Helly Hansen DUBLIN BACKPACK"
#   }
#   web_entities {
#     entity_id: "/m/09j2d"
#     score: 0.7113999724388123
#     description: "Clothing"
#   }
#   web_entities {
#     entity_id: "/g/11bc6s6fyx"
#     score: 0.7071999907493591
#   }
#   web_entities {
#     entity_id: "/m/06d72w"
#     score: 0.7067999839782715
#     description: "Helly Hansen"
#   }
#   web_entities {
#     entity_id: "/t/264v20f0k67hb"
#     score: 0.7067999839782715
#   }
#   web_entities {
#     entity_id: "/m/014dsx"
#     score: 0.6319000124931335
#     description: "Travel"
#   }
#   web_entities {
#     entity_id: "/m/0463sg"
#     score: 0.5425000190734863
#     description: "Clothing Accessories"
#   }
#   partial_matching_images {
#     url: "https://dam.media.xxlsports.com/9249739735070_1073622_STRIPE_EVENING_BLUE_1_jpg.jpg"
#   }
#   partial_matching_images {
#     url: "https://d3d71ba2asa5oz.cloudfront.net/62000918/images/67029_690_1.jpg"
#   }
#   partial_matching_images {
#     url: "https://www.hellyhansen.com/media/catalog/product/cache/c687aa7517cf01e65c009f6943c2b1e9/6/7/67029_898.jpg"
#   }
#   partial_matching_images {
#     url: "https://www.hellyhansen.com/media/catalog/product/cache/c687aa7517cf01e65c009f6943c2b1e9/6/7/67029_690.jpg"
#   }
#   partial_matching_images {
#     url: "http://andrespelaez.co/wp-content/uploads/2018/06/hansen-wholesale-reviews-shoes-backpack-unisex-stripe-evening-blue-wide-range-price-tech-materials.jpg"
#   }
#   partial_matching_images {
#     url: "https://www.hellyhansen.com/media/catalog/product/cache/0f831c1845fc143d00d6d1ebc49f446a/6/7/67029_898.jpg"
#   }
#   partial_matching_images {
#     url: "https://www.hellyhansen.com/media/catalog/product/cache/098d24d33836ecadc205138326a2819d/6/7/67029_898.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.hellyhansen.com/en_us/dublin-backpack-67029"
#     page_title: "<b>DUBLIN BACKPACK</b> - <b>Backpacks</b> - Gear - WOMEN - <b>Helly Hansen</b>"
#     partial_matching_images {
#       url: "https://www.hellyhansen.com/media/catalog/product/cache/098d24d33836ecadc205138326a2819d/6/7/67029_898.jpg"
#     }
#     partial_matching_images {
#       url: "https://www.hellyhansen.com/media/catalog/product/cache/c687aa7517cf01e65c009f6943c2b1e9/6/7/67029_690.jpg"
#     }
#     partial_matching_images {
#       url: "https://www.hellyhansen.com/media/catalog/product/cache/c687aa7517cf01e65c009f6943c2b1e9/6/7/67029_898.jpg"
#     }
#     partial_matching_images {
#       url: "https://www.hellyhansen.com/media/catalog/product/cache/0f831c1845fc143d00d6d1ebc49f446a/6/7/67029_898.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.hellyhansen.com/en_gb/dublin-backpack-67029"
#     page_title: "<b>DUBLIN BACKPACK</b> - <b>Backpacks</b> - Gear - WOMEN - <b>Helly Hansen</b>"
#     partial_matching_images {
#       url: "https://www.hellyhansen.com/media/catalog/product/cache/098d24d33836ecadc205138326a2819d/6/7/67029_898.jpg"
#     }
#     partial_matching_images {
#       url: "https://www.hellyhansen.com/media/catalog/product/cache/c687aa7517cf01e65c009f6943c2b1e9/6/7/67029_690.jpg"
#     }
#     partial_matching_images {
#       url: "https://www.hellyhansen.com/media/catalog/product/cache/c687aa7517cf01e65c009f6943c2b1e9/6/7/67029_898.jpg"
#     }
#     partial_matching_images {
#       url: "https://www.hellyhansen.com/media/catalog/product/cache/0f831c1845fc143d00d6d1ebc49f446a/6/7/67029_898.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.ebay.co.uk/itm/Helly-Hansen-Dublin-33L-Durable-Backpack-Rucksack-Outdoor-Travel-Bag-/311451723796"
#     page_title: "<b>Helly Hansen Dublin</b> 33L Durable <b>Backpack Rucksack</b> Outdoor ..."
#     partial_matching_images {
#       url: "https://d3d71ba2asa5oz.cloudfront.net/62000918/images/67029_690_1.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.ebay.com/itm/Helly-Hansen-Dublin-33L-Durable-Backpack-Rucksack-Outdoor-Travel-Bag-/311451723796"
#     page_title: "<b>Helly Hansen Dublin</b> 33L Durable <b>Backpack Rucksack</b> Outdoor ..."
#     partial_matching_images {
#       url: "https://d3d71ba2asa5oz.cloudfront.net/62000918/images/67029_690_1.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.ebay.ie/itm/Helly-Hansen-Dublin-33L-Durable-Backpack-Rucksack-Outdoor-Travel-Bag-/311451723796"
#     page_title: "<b>Helly Hansen Dublin</b> 33L Durable <b>Backpack Rucksack</b> Outdoor ..."
#     partial_matching_images {
#       url: "https://d3d71ba2asa5oz.cloudfront.net/62000918/images/67029_690_1.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.ebay.com.au/itm/Helly-Hansen-Dublin-33L-Durable-Backpack-Rucksack-Outdoor-Travel-Bag-/311451723796"
#     page_title: "<b>Helly Hansen Dublin</b> 33L Durable <b>Backpack Rucksack</b> Outdoor ..."
#     partial_matching_images {
#       url: "https://d3d71ba2asa5oz.cloudfront.net/62000918/images/67029_690_1.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://andrespelaez.co/hansen-wholesale-reviews/hansen-wholesale-reviews-sally-complete-salon-manicure-kook-a-mango-ships-only/"
#     page_title: "<b>Hansen</b> Wholesale Reviews <b>Sally</b> Complete Salon Manicure Kook A ..."
#     partial_matching_images {
#       url: "http://andrespelaez.co/wp-content/uploads/2018/06/hansen-wholesale-reviews-shoes-backpack-unisex-stripe-evening-blue-wide-range-price-tech-materials.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://andrespelaez.co/hansen-wholesale-reviews/"
#     page_title: "<b>hansen</b> wholesale reviews \342\200\223 andrespelaez.co"
#     partial_matching_images {
#       url: "http://andrespelaez.co/wp-content/uploads/2018/06/hansen-wholesale-reviews-shoes-backpack-unisex-stripe-evening-blue-wide-range-price-tech-materials.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://cass.aero/news.asp?p_id=backpack"
#     page_title: "<b>backpack</b> Sale,up to 59% Discounts"
#     partial_matching_images {
#       url: "https://www.hellyhansen.com/media/catalog/product/cache/c687aa7517cf01e65c009f6943c2b1e9/6/7/67029_898.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.xxl.dk/helly-hansen-dublin-backpack-rygsak-forpris-199/p/1073622_13_style"
#     page_title: "<b>Helly Hansen Dublin Backpack</b>, rygs\303\246k (F\303\230RPRIS 199,-) - - XXL"
#     partial_matching_images {
#       url: "https://dam.media.xxlsports.com/9249739735070_1073622_STRIPE_EVENING_BLUE_1_jpg.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://www.hellyhansen.com/media/catalog/product/cache/c687aa7517cf01e65c009f6943c2b1e9/6/7/67029_898.jpg"
#   }
#   visually_similar_images {
#     url: "https://estafeta.com.ua/imgs/m506938.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn7.bigcommerce.com/s-59bt4/images/stencil/1280x1280/products/4939/5323/download_9__76178.1494485122.jpg?c=2&imbypass=on"
#   }
#   visually_similar_images {
#     url: "https://www.karstadt.de/dw/image/v2/karstadt/derivates/1/001/148/337/SProdukt_4182065.jpg?sw=1200&sh=1200&sm=fit"
#   }
#   visually_similar_images {
#     url: "http://www.cantodopaco.com/images/Zaino%20Donna/Donna%2064%2095%20Helly%20Hansen%20Dublin%20Backpack%20nero%205555.jpg"
#   }
#   visually_similar_images {
#     url: "http://www.kanzlei-rieser.de/image/cache/data/category_6/helly-hansen-dublin-rucksack-48-cm-damen-reissverschluss-hellblau-6856104-gfhhqud--15249-500x500_0.jpg"
#   }
#   visually_similar_images {
#     url: "http://www.gosocialgomedia.co.uk/images/image/Ebony%20Men%20%20Bags%20%20rXHI%20-%20helly-hansen%20Dublin%20Backpack%20HE039SE59JUA.jpg"
#   }
#   visually_similar_images {
#     url: "http://images.wildberries.by/big/new/3160000/3169837-1.jpg"
#   }
#   visually_similar_images {
#     url: "http://www.blueheronhalfathon.ca/images/shoebuybags/VF13203274-Helly-Hansen-Dublin-Backpack-Outlet-Online-Canada-outlet-store.jpg"
#   }
#   visually_similar_images {
#     url: "https://scrooge-c.scdn.gr/images/sku_main_images/000584/584428/20160818130037_helly_hansen_dublin_backpack_33l_67029_990.jpeg"
#   }
#   best_guess_labels {
#     label: "helly hansen dublin backpack"
#     language_code: " invalid_language_code"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/g/11hd5lnp38"
#     score: 0.730400025844574
#     description: "Patagonia - Men\'s Iron Forge Hemp Canvas Ranch Jacket"
#   }
#   web_entities {
#     entity_id: "/m/013s93"
#     score: 0.7249500155448914
#     description: "T-shirt"
#   }
#   web_entities {
#     entity_id: "/m/0g152j"
#     score: 0.7168999910354614
#     description: "Patagonia"
#   }
#   web_entities {
#     entity_id: "/t/25ybbfp73rjxr"
#     score: 0.7168999910354614
#   }
#   web_entities {
#     entity_id: "/m/032b3c"
#     score: 0.7142999768257141
#     description: "Jacket"
#   }
#   web_entities {
#     entity_id: "/m/01n4qj"
#     score: 0.7019000053405762
#     description: "Shirt"
#   }
#   web_entities {
#     entity_id: "/m/09j2d"
#     score: 0.6437000036239624
#     description: "Clothing"
#   }
#   web_entities {
#     entity_id: "/m/026lc7w"
#     score: 0.5328999757766724
#     description: "Workwear"
#   }
#   web_entities {
#     entity_id: "/g/11gh3_pwg8"
#     score: 0.5292999744415283
#     description: "Patagonia Men\'s Iron Forge Hemp Canvas Double Knee Pants"
#   }
#   web_entities {
#     entity_id: "/g/11hd65tz3q"
#     score: 0.5163999795913696
#     description: "Patagonia Men\'s Iron Forge Hemp Canvas Barn Coat"
#   }
#   full_matching_images {
#     url: "https://www.fieldandstream.com/sites/fieldandstream.com/files/styles/1000_1x_/public/images/2017/11/patagonia-iron-forge-canvas-jacket.jpg?itok=MUjTfUlJ"
#   }
#   full_matching_images {
#     url: "https://www.patagonia.ca/dis/dw/image/v2/ABBM_PRD/on/demandware.static/-/Sites-patagonia-master/default/dw0b78138c/images/hi-res/27805_COI.jpg?sw=750&sh=750&sm=fit&sfrm=png"
#   }
#   full_matching_images {
#     url: "https://www.fieldandstream.com/sites/fieldandstream.com/files/styles/655_1x_/public/images/2017/11/patagonia-iron-forge-canvas-jacket.jpg?itok=Mrx9ulbb"
#   }
#   full_matching_images {
#     url: "http://www.theprimarymag.com/wp-content/uploads/2017/08/patagonias-workwear-collection-fall-must-1.jpg"
#   }
#   full_matching_images {
#     url: "https://activegearreview.com/wp-content/uploads/2017/08/Ms-Iron-Forge-Hemp-Canvas-Ranch-Jacket-600x600.jpg"
#   }
#   full_matching_images {
#     url: "https://www.mountainlifemedia.ca/wp-content/uploads/2017/10/patagonias-workwear-collection-fall-must-1.jpg"
#   }
#   full_matching_images {
#     url: "https://img3.onthesnow.com/image/gg/49/493310.jpg"
#   }
#   full_matching_images {
#     url: "https://www.patagonia.com/dis/dw/image/v2/ABBM_PRD/on/demandware.static/-/Sites-patagonia-master/default/dw0b78138c/images/hi-res/27805_COI.jpg?sw=300&sh=300&sfrm=png"
#   }
#   full_matching_images {
#     url: "https://www.mountainlifemedia.ca/wp-content/uploads/2017/10/patagonia-feature.jpg"
#   }
#   full_matching_images {
#     url: "https://i.pinimg.com/236x/49/30/41/493041de0e24496e3e2282a908dae45a.jpg"
#   }
#   partial_matching_images {
#     url: "https://cimg7.ibsrv.net/gimg/honda-tech.com-vbulletin/1500x1005/80-63898b9f_828f_4f2b_a578_ec179020b307_116f2c39d5bdc3671c6b0e2fde96face322782e1.jpeg"
#   }
#   partial_matching_images {
#     url: "https://i2.wp.com/s3.amazonaws.com/images.gearjunkie.com/uploads/2017/08/Patagonia-Iron-Forge-Hemp-Canvas-Ranch-Jacket.jpg?ssl=1"
#   }
#   partial_matching_images {
#     url: "http://www.chayaisms.com/wp-content/uploads/2018/05/patagonia-patagonia-mens-iron-forge-hempc2ae-canvas-barn-coat-coriander-brown-mens-jackets-vests.jpg"
#   }
#   partial_matching_images {
#     url: "https://www.patagonia.jp/static/on/demandware.static/-/Library-Sites-PatagoniaShared/default/dw70af01a2/marketing/workwear/FPO-F18-WW-M-steel-forge-jacket.png"
#   }
#   partial_matching_images {
#     url: "https://i.pinimg.com/originals/0b/aa/26/0baa26f6ecb43d78f4564217b9c12ad6.jpg"
#   }
#   partial_matching_images {
#     url: "http://ediblesmagazine.com/wp-content/uploads/2018/02/TOP_10_HEMP_INNOVATIONS_HEMP_CLOTHING.jpg"
#   }
#   partial_matching_images {
#     url: "https://static1.squarespace.com/static/57aa0f96d482e969a624432f/t/5a0dc895e4966b3f637f6837/1510852764214/patagonia+jkt.png"
#   }
#   partial_matching_images {
#     url: "https://i.pinimg.com/originals/38/80/d9/3880d993f3b328afcdbc7609b9e79a39.jpg"
#   }
#   partial_matching_images {
#     url: "https://images.milled.com/2018-03-19/hy96OMcHh9jyVIQr/W6a9rEDZYAyc.jpg"
#   }
#   partial_matching_images {
#     url: "https://images.prod.meredith.com/product/d5c354d1285d1bdce34ad74cd7309d61/1509723154176/l/mens-iron-forge-hemp-tm-canvas-ranch-jacket"
#   }
#   pages_with_matching_images {
#     url: "https://www.patagonia.com/product/mens-iron-forge-hemp-canvas-ranch-jacket/27805.html"
#     page_title: "<b>Patagonia Men&#39;s Iron Forge Hemp</b>\302\256 <b>Canvas Ranch Jacket</b>"
#     full_matching_images {
#       url: "https://www.patagonia.com/dis/dw/image/v2/ABBM_PRD/on/demandware.static/-/Sites-patagonia-master/default/dw0b78138c/images/hi-res/27805_COI.jpg?sw=50&sh=50&sm=fit&sfrm=png"
#     }
#     full_matching_images {
#       url: "https://www.patagonia.com/dis/dw/image/v2/ABBM_PRD/on/demandware.static/-/Sites-patagonia-master/default/dw0b78138c/images/hi-res/27805_COI.jpg?sw=750&sh=750&sm=fit&sfrm=png"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.mountainlifemedia.ca/2017/10/patagonia-iron-forge-hemp-canvas-ranch-jacket/"
#     page_title: "<b>Patagonia Iron Forge Hemp Canvas Ranch Jacket</b> - Mountain Life"
#     full_matching_images {
#       url: "https://www.mountainlifemedia.ca/wp-content/uploads/2017/10/patagonia-feature.jpg"
#     }
#     full_matching_images {
#       url: "https://www.mountainlifemedia.ca/wp-content/uploads/2017/10/patagonias-workwear-collection-fall-must-1.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.patagonia.com/shop/hemp-clothing"
#     page_title: "<b>Hemp</b> Clothing by <b>Patagonia</b>"
#     full_matching_images {
#       url: "https://www.patagonia.com/dis/dw/image/v2/ABBM_PRD/on/demandware.static/-/Sites-patagonia-master/default/dw0b78138c/images/hi-res/27805_COI.jpg?sw=300&sh=300&sfrm=png"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.pinterest.com/pin/277745502003894094/"
#     page_title: "<b>PATAGONIA MEN&#39;S IRON FORGE HEMP CANVAS</b> CHORE <b>COAT</b> ..."
#     partial_matching_images {
#       url: "https://i.pinimg.com/originals/38/80/d9/3880d993f3b328afcdbc7609b9e79a39.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://bestlifeonline.com/shop/mens-iron-forge-hemp-r-canvas-ranch-jacket-pd5c354d1285d1bdce34ad74cd7309d61.html"
#     page_title: "Amazing Savings on <b>Men&#39;s Iron Forge Hemp</b>(R) <b>Canvas Ranch Jacket</b>"
#     partial_matching_images {
#       url: "https://images.prod.meredith.com/product/d5c354d1285d1bdce34ad74cd7309d61/1509723154176/l/mens-iron-forge-hemp-tm-canvas-ranch-jacket"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.fitnessmagazine.com/shop/mens-iron-forge-hemp-r-canvas-ranch-jacket-pd5c354d1285d1bdce34ad74cd7309d61.html"
#     page_title: "Fall Sales are Upon Us! Get this Deal on <b>Men&#39;s Iron Forge Hemp</b>(R ..."
#     partial_matching_images {
#       url: "https://images.prod.meredith.com/product/d5c354d1285d1bdce34ad74cd7309d61/1509723154176/l/mens-iron-forge-hemp-tm-canvas-ranch-jacket"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.patagonia.jp/workwear-f18.html"
#     page_title: "Workwear by <b>Patagonia</b>\302\256 - Built For The Hardest Work - \343\203\221\343\202\277\343\202\264\343\203\213\343\202\242"
#     partial_matching_images {
#       url: "https://www.patagonia.jp/static/on/demandware.static/-/Library-Sites-PatagoniaShared/default/dw70af01a2/marketing/workwear/FPO-F18-WW-M-steel-forge-jacket.png"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.pinterest.com/pin/46232333658086706/"
#     page_title: "<b>Men&#39;s Iron Forge Hemp</b>\302\256 <b>Canvas Ranch Jacket</b> | gear^ | Pinterest ..."
#     partial_matching_images {
#       url: "https://i.pinimg.com/originals/0b/aa/26/0baa26f6ecb43d78f4564217b9c12ad6.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://www.nicolehood.co.uk/blog/2017/11/16/sustainable-gifts-for-christmas"
#     page_title: "Sustainable gifts for Christmas \342\200\224 Nicole Hood"
#     partial_matching_images {
#       url: "https://static1.squarespace.com/static/57aa0f96d482e969a624432f/t/5a0dc895e4966b3f637f6837/1510852764214/patagonia+jkt.png"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.skiinfo.nl/skinieuws/a/587516/the-25-best-gifts-for-skiers-this-season"
#     page_title: "The 25 Best Gifts for Skiers this Season - Skiinfo.nl"
#     full_matching_images {
#       url: "https://img3.onthesnow.com/image/gg/49/493310.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://www.patagonia.com/dis/dw/image/v2/ABBM_PRD/on/demandware.static/-/Sites-patagonia-master/default/dw0b78138c/images/hi-res/27805_COI.jpg?sw=750&sh=750&sm=fit&sfrm=png"
#   }
#   visually_similar_images {
#     url: "https://images.prod.meredith.com/product/d5c354d1285d1bdce34ad74cd7309d61/1509723154176/m/mens-iron-forge-hemp-tm-canvas-ranch-jacket"
#   }
#   visually_similar_images {
#     url: "https://i.pinimg.com/236x/a3/92/cc/a392cca10f2861584244be18c95015ff--jackets-for-men-mens-jackets.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.pinimg.com/originals/21/73/6d/21736d26f6f1a2cf406cec6c811c7854.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.patagonia.com/dis/dw/image/v2/ABBM_PRD/on/demandware.static/-/Sites-patagonia-master/default/dwef455497/images/hi-res/27795_DKAS_OM1.jpg?sw=750&sh=750&sm=fit&sfrm=png"
#   }
#   visually_similar_images {
#     url: "https://www.patagonia.com/dis/dw/image/v2/ABBM_PRD/on/demandware.static/-/Sites-patagonia-master/default/dwe4cd8db3/images/hi-res/27800_COI_OM2.jpg?sw=750&sh=750&sm=fit&sfrm=png"
#   }
#   visually_similar_images {
#     url: "https://cmzone-vzbqbxhynotw9ion96xv.netdna-ssl.com/wp-content/uploads/2017/08/Patagonia-Has-a-New-Workwear-Line-1.jpg"
#   }
#   visually_similar_images {
#     url: "https://images.prod.meredith.com/product/a7d099abbb58f8cd4e186aad90451218/1503478136740/m/mountain-khakis-mens-ranch-shearling-jacket-small-terra"
#   }
#   visually_similar_images {
#     url: "https://i2.wp.com/d27ah0i12nj2vl.cloudfront.net/media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/7/6/769lg4.jpg?resize=450,300"
#   }
#   visually_similar_images {
#     url: "http://www.chayaisms.com/wp-content/uploads/2018/05/patagonia-patagonia-mens-iron-forge-hempc2ae-canvas-ranch-jacket-ink-black-mens-jackets-vests_2.jpg"
#   }
#   best_guess_labels {
#     label: "patagonia men\'s iron forge hemp \342\204\242 canvas ranch jacket"
#     language_code: "en"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/04k84"
#     score: 0.9857999682426453
#     description: "Light"
#   }
#   web_entities {
#     entity_id: "/m/04bcr3"
#     score: 0.7443000078201294
#     description: "Table"
#   }
#   web_entities {
#     entity_id: "/g/11bc5zwtss"
#     score: 0.7163000106811523
#     description: "Electric light"
#   }
#   web_entities {
#     entity_id: "/m/08jpwt"
#     score: 0.713699996471405
#     description: "Light fixture"
#   }
#   web_entities {
#     entity_id: "/m/0dtln"
#     score: 0.6388000249862671
#     description: "Lamp"
#   }
#   web_entities {
#     entity_id: "/m/02lts"
#     score: 0.6244999766349792
#     description: "Electricity"
#   }
#   web_entities {
#     entity_id: "/m/02q1jcp"
#     score: 0.5799000263214111
#     description: "Pendant light"
#   }
#   web_entities {
#     entity_id: "/m/0pf1p"
#     score: 0.5666000247001648
#     description: "Wrought iron"
#   }
#   web_entities {
#     entity_id: "/m/025rw19"
#     score: 0.5611000061035156
#     description: "Iron"
#   }
#   web_entities {
#     entity_id: "/m/019sc6"
#     score: 0.5343999862670898
#     description: "Lighting"
#   }
#   full_matching_images {
#     url: "https://tse2.mm.bing.net/th?id=OIP.YmFcWiZS4Gz22vCimKLk-QHaLd"
#   }
#   full_matching_images {
#     url: "https://d3t543lkaz1xy.cloudfront.net/photo/59907f927623460a5edb29ce_m"
#   }
#   full_matching_images {
#     url: "https://i.pinimg.com/236x/9f/8a/9d/9f8a9d9b2865e0c6ed08dff6a64b23f2.jpg"
#   }
#   full_matching_images {
#     url: "https://scottstrissel.files.wordpress.com/2018/08/lamp.jpg?w=194&h=300"
#   }
#   full_matching_images {
#     url: "https://msp.c.yimg.jp/yjimage?q=pa.hTZ0XyLFy.Z2WuIiCQvXaLcvQCt.8JikCoFFkvEGE0vSgEKyrXv2M6B00JbPqat4oFFSVicewPUC0oUHfjxRccLQ0JTjOWdpPT0xzV0j4wZurk5Dc83IlLoKHXiNKk_GkNjR9NWcJPa2b5g--&sig=138k6464e&x=180&y=279"
#   }
#   full_matching_images {
#     url: "https://userscontent2.emaze.com/images/65535a82-e6c2-417a-91db-96314ded3ba6/a408bee5354c5af0db785de02ab733bf.jpeg"
#   }
#   full_matching_images {
#     url: "https://res.cloudinary.com/emazecom/image/fetch/c_limit,a_ignore,w_120,h_200/https%3A%2F%2Fuserscontent2.emaze.com%2Fimages%2Fabe0e3ab-4dc9-4592-a0d7-000189c8d122%2F62615c5a2652e06cf6daf0a298a2e4f9.jpg"
#   }
#   partial_matching_images {
#     url: "http://wahyublahe.com/upload/2018/08/23/lamp-diwali-table-2812photographycom-lamp-diwali-table-l-7f49c3210811e746.jpg"
#   }
#   partial_matching_images {
#     url: "http://bedesign.co/wp-content/uploads/2018/07/lamp-animal-iron-table-lamps-in-natural-black-design-luxury-for-sale-floor-giraffe-print-sha.jpg"
#   }
#   partial_matching_images {
#     url: "http://portalwiedzy.info/wp-content/uploads/2018/09/black-iron-table-lamp-wrought-iron-table-lamp-in-natural-black-finish-with.jpg"
#   }
#   partial_matching_images {
#     url: "https://www.nigeltyas.co.uk/pub/media/catalog/product/cache/6b1c09900b407c50fce2db5e66ebc123/images/hepworth-wrought-iron-table-lamp-1.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.nigeltyas.co.uk/hepworth-wrought-iron-table-lamp.html"
#     page_title: "Hepworth Wrought Iron Table Lamp - Nigel Tyas"
#     partial_matching_images {
#       url: "https://www.nigeltyas.co.uk/pub/media/catalog/product/cache/6b1c09900b407c50fce2db5e66ebc123/images/hepworth-wrought-iron-table-lamp-1.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://hairgoals.club/iron-table-lamps/iron-table-lamps-iron-table-lamp-wrought/"
#     page_title: "Iron Table Lamps Iron Table Lamp Wrought - hairgoals.club"
#     partial_matching_images {
#       url: "http://hairgoals.club/wp-content/uploads/2018/08/iron-table-lamps-wrought-iron-table-lamp-in-natural-black-finish-with-wrought-iron-table-lamp-sets.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.idec2017.org/iron-ceiling-fans-with-light.html"
#     page_title: "Iron Ceiling Fans With <b>Light</b>: Retro 5 <b>Light</b> Wrought Iron Black Fan ..."
#     full_matching_images {
#       url: "https://www.idec2017.org/media/home-decorators-collection-reagan-ii-52-in-led-natural-iron-table-lamp-lighting-and-ceiling-fans_i_1283-21.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://bestpowertools.info/orange-table-lamp/table-lamp-you-can-create-your-own-light-pattern-by-bending-the-tabs-inward-burnt-orange-shades/"
#     page_title: "decoration: Table Lamp You Can Create Your Own <b>Light</b> Pattern By ..."
#     partial_matching_images {
#       url: "http://bestpowertools.info/wp-content/uploads/2018/02/wrought-iron-table-lamp-in-natural-black-finish-with-orange-ebay.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://420dispensary.info/iron-light-fixtures/"
#     page_title: "iron <b>light</b> fixtures \342\200\223 420dispensary.info"
#     partial_matching_images {
#       url: "http://420dispensary.info/wp-content/uploads/2018/02/iron-light-fixtures-wrought-iron-table-lamp-in-natural-black-finish-with-black-iron-wall-light-fittings-black-iron-kitchen-light-fixtures.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://ubidi.club/wrought-iron-lamps/wrought-iron-lamps-wrought-iron-light-pendants-on-industrial-loft-wrought-iron-pendant-lights-creative-gear-lamp-b-wrought-iron-light-fittings-australia/"
#     page_title: "Wrought Iron Lamps Wrought Iron <b>Light</b> Pendants On Industrial Loft ..."
#     partial_matching_images {
#       url: "http://ubidi.club/wp-content/uploads/2018/04/wrought-iron-lamps-wrought-iron-table-lamp-in-natural-black-finish-with-wrought-iron-floor-lamps-australia.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://ubidi.club/wrought-iron-lamps/wrought-iron-lamps-rustic-wrought-iron-lamps-wrought-iron-light-fittings-australia/"
#     page_title: "Wrought Iron Lamps Rustic Wrought Iron Lamps Wrought Iron <b>Light</b> ..."
#     partial_matching_images {
#       url: "http://ubidi.club/wp-content/uploads/2018/04/wrought-iron-lamps-wrought-iron-table-lamp-in-natural-black-finish-with-wrought-iron-floor-lamps-australia.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://hairgoals.club/iron-table-lamps/iron-table-lamps-wrought-iron-table-lamp-bases/"
#     page_title: "Iron Table Lamps Wrought Iron Table Lamp Bases - hairgoals.club"
#     partial_matching_images {
#       url: "http://hairgoals.club/wp-content/uploads/2018/08/iron-table-lamps-wrought-iron-table-lamp-in-natural-black-finish-with-wrought-iron-table-lamp-sets.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://pastorsponderings.org/2018/08/29/messy-church-weekend-vbs-i-ams-of-jesus/"
#     page_title: "Messy Church \342\200\223 Weekend VBS\342\200\246\342\200\235I Am&#39;s of Jesus\342\200\235 \342\200\223 Pastor&#39;s ..."
#     full_matching_images {
#       url: "https://scottstrissel.files.wordpress.com/2018/08/lamp.jpg?w=194&h=300"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://djtrunks.com/lamp-images/lamp-images-arc-floor-lamp-temple-lamp-images-hd/"
#     page_title: "Lamp Images Arc Floor Lamp Temple Lamp Images Hd \342\200\223 djtrunks.com"
#     partial_matching_images {
#       url: "http://djtrunks.com/wp-content/uploads/2018/07/lamp-images-wrought-iron-table-lamp-in-natural-black-finish-with-lamp-cartoon-pictures.jpg"
#     }
#   }
#   best_guess_labels {
#     label: "Electric light"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/01mzpv"
#     score: 0.7342000007629395
#     description: "Chair"
#   }
#   web_entities {
#     entity_id: "/m/030z9k"
#     score: 0.70660001039505
#     description: "Upholstery"
#   }
#   web_entities {
#     entity_id: "/m/03f6tq"
#     score: 0.6633999943733215
#     description: "Living room"
#   }
#   web_entities {
#     entity_id: "/g/11g1rjdq93"
#     score: 0.6446999907493591
#     description: "Homelegance Button Tufted LowRaised Curved Backrest Accent Chair"
#   }
#   web_entities {
#     entity_id: "/m/0gq6kx"
#     score: 0.5562000274658203
#     description: "Swivel chair"
#   }
#   web_entities {
#     entity_id: "/m/0fq0crf"
#     score: 0.5516999959945679
#     description: "Club chair"
#   }
#   web_entities {
#     entity_id: "/g/120t3_gy"
#     score: 0.5320000052452087
#     description: "Seat"
#   }
#   web_entities {
#     entity_id: "/m/0174g1"
#     score: 0.5246999859809875
#     description: "Cushion"
#   }
#   web_entities {
#     entity_id: "/m/0c_jw"
#     score: 0.4918999969959259
#     description: "Furniture"
#   }
#   web_entities {
#     entity_id: "/m/01g5v"
#     score: 0.44279998540878296
#     description: "Blue"
#   }
#   full_matching_images {
#     url: "https://secure.img1-fg.wfcdn.com/im/90867761/compr-r85/3696/36966209/default_name.jpg"
#   }
#   full_matching_images {
#     url: "http://virginiavirtual360.com/wp-content/uploads/2018/08/awesome-barrel-chair-goods-accent-light-teal-navy-for-turquoise-and-brown-style-ideas-fixed-22238s-home-design-chairs-furniture-turquoise5-54y.jpg"
#   }
#   full_matching_images {
#     url: "http://virginiavirtual360.com/wp-content/uploads/2018/08/marsdeni-barrel-chairs-home-design-blue-club-chair-5-32y.jpg"
#   }
#   full_matching_images {
#     url: "https://stonepathreview.org/uploads/awesome-barrel-chair-goods-accent-light-teal-navy-for-turquoise-and-brown-style-ideas_FIXED_22238.jpg"
#   }
#   full_matching_images {
#     url: "https://images-na.ssl-images-amazon.com/images/I/81om6s68B2L._SL1500_.jpg"
#   }
#   full_matching_images {
#     url: "http://nationonthetake.com/wp-content/uploads/2018/08/occasional-chairs-small-swivel-accent-chair-velvet-tufted-chair-printed-armchair-teal-side-chair-charcoal-accent-chair-fabric-accent-chairs--936x936.jpg"
#   }
#   full_matching_images {
#     url: "http://markfcooper.com/wp-content/uploads/2018/04/latitude-run-marsdeni-barrel-chair-reviews-wayfair-inside-cobalt-blue-prepare-6.jpg"
#   }
#   full_matching_images {
#     url: "http://i0.wp.com/secure.img1-fg.wfcdn.com/im/15067462/resize-h800%5Ecompr-r85/3696/36966209/Marsdeni+Barrel+Chair.jpg"
#   }
#   full_matching_images {
#     url: "https://secure.img1-fg.wfcdn.com/im/02986026/resize-h800-w800%5Ecompr-r85/3696/36966209/Marsdeni+Barrel+Chair.jpg"
#   }
#   full_matching_images {
#     url: "http://www.southamptonartgallery.com/wp-content/uploads/2018/06/attractive-best-best-collection-cobalt-blue-chair-marsdeni-barrel-chair-reviews-joss-main.jpg"
#   }
#   partial_matching_images {
#     url: "https://fabianportmann.com/wp-content/uploads/reizvoll-cocktailsessel-leder-braun-ideen.jpg"
#   }
#   partial_matching_images {
#     url: "https://images-na.ssl-images-amazon.com/images/I/81Kmm-mS-yL._SL1500_.jpg"
#   }
#   partial_matching_images {
#     url: "http://i0.wp.com/secure.img1-fg.wfcdn.com/im/29688741/resize-h800%5Ecompr-r85/3920/39201652/Liam+Barrel+Chair.jpg"
#   }
#   partial_matching_images {
#     url: "http://www.sportsarena.me/wp-content/uploads/2018/08/gray-and-white-accent-chair-medium-size-of-modern-white-accent-chair-awesome-living-room-blue-accent-chairs-gray-white-accent-chair.jpg"
#   }
#   partial_matching_images {
#     url: "http://www.ccenergialtd.com/wp-content/uploads/2017/11/what-is-accent-furniture-living-room-chairs-bedroom-for-small-spaces-wood-chair-occasional-large-size-of-upholstered-sofa-house-set-comfy-couches-leather-blue-armchair-693x693.jpg"
#   }
#   partial_matching_images {
#     url: "http://astronlabs.co/wp-content/uploads/2018/03/cool-comfy-chairs-medium-size-of-bedroom-chair-marvelous-comfy-reading-cool-accent-chairs-extraordinary-armchairs-comfy-lounge-chairs-for-small-spaces.jpg"
#   }
#   partial_matching_images {
#     url: "http://peepan.me/wp-content/uploads/2018/08/cool-armchairs-cool-comfy-chairs-medium-size-of-bedroom-chair-marvelous-comfy-reading-cool-accent-chairs-extraordinary-armchairs-cheap-armchairs-for-sale.jpg"
#   }
#   partial_matching_images {
#     url: "http://coreshots.co/wp-content/uploads/2018/05/cool-comfy-chairs-cool-comfy-chairs-medium-size-of-bedroom-chair-marvelous-comfy-reading-cool-accent-chairs-extraordinary-armchairs-comfy-chairs-for-bedrooms-cheap.jpg"
#   }
#   partial_matching_images {
#     url: "https://images-na.ssl-images-amazon.com/images/I/81Kmm-mS-yL._SX569_.jpg"
#   }
#   partial_matching_images {
#     url: "https://img.buzzfeed.com/buzzfeed-static/static/2017-03/15/17/enhanced/buzzfeed-prod-fastlane-03/original-grid-image-20118-1489614033-1.jpg?crop=525:525;0,0&downsize=715:*&output-format=auto&output-quality=auto"
#   }
#   pages_with_matching_images {
#     url: "https://www.wayfair.com/keyword.php?keyword=liam+barrel+chair"
#     page_title: "Liam <b>Barrel Chair</b> | Wayfair"
#     full_matching_images {
#       url: "https://secure.img2-fg.wfcdn.com/im/06953777/compr-r85/3696/36966209/Marsdeni+Barrel+Chair.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.amazon.com/Upholstered-Contemporary-Living-Removable-Microfiber/dp/B06XFN53SF"
#     page_title: "Amazon.com: Upholstered <b>Chair</b>, <b>Barrel</b> Back <b>Armchair</b> ..."
#     full_matching_images {
#       url: "https://images-na.ssl-images-amazon.com/images/I/81om6s68B2L._SY355_.jpg"
#     }
#     full_matching_images {
#       url: "https://images-na.ssl-images-amazon.com/images/I/81om6s68B2L._SL1500_.jpg"
#     }
#     full_matching_images {
#       url: "https://images-na.ssl-images-amazon.com/images/I/81om6s68B2L._SX679_.jpg"
#     }
#     full_matching_images {
#       url: "https://images-na.ssl-images-amazon.com/images/I/81om6s68B2L._SX569_.jpg"
#     }
#     full_matching_images {
#       url: "https://images-na.ssl-images-amazon.com/images/I/41tdUBt0pmL.jpg"
#     }
#     full_matching_images {
#       url: "https://images-na.ssl-images-amazon.com/images/I/81om6s68B2L._SX522_.jpg"
#     }
#     full_matching_images {
#       url: "https://images-na.ssl-images-amazon.com/images/I/81om6s68B2L._SX425_.jpg"
#     }
#     full_matching_images {
#       url: "https://images-na.ssl-images-amazon.com/images/I/81om6s68B2L._SX466_.jpg"
#     }
#     full_matching_images {
#       url: "https://images-na.ssl-images-amazon.com/images/I/81om6s68B2L._SY450_.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.amazon.com/Fox-Hill-Savannah-Club-Chair/dp/B01F488VUI"
#     page_title: "Amazon.com: Fox Hill Savannah Club <b>Chair</b>: Kitchen &amp; Dining"
#     partial_matching_images {
#       url: "https://images-na.ssl-images-amazon.com/images/I/71a3QIgV5fL._SX466_.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.wayfair.com/furniture/pdx/latitude-run-marsdeni-barrel-chair-latr2530.html"
#     page_title: "Latitude Run Marsdeni <b>Barrel Chair</b> &amp; Reviews | Wayfair"
#     full_matching_images {
#       url: "https://secure.img1-fg.wfcdn.com/im/22878090/resize-h122-w122%5Ecompr-r85/3696/36966209/Marsdeni+Barrel+Chair.jpg"
#     }
#     full_matching_images {
#       url: "https://secure.img1-fg.wfcdn.com/im/02986026/resize-h800-w800%5Ecompr-r85/3696/36966209/Marsdeni+Barrel+Chair.jpg"
#     }
#     full_matching_images {
#       url: "https://secure.img1-fg.wfcdn.com/im/67630802/resize-h400-p1-w400%5Ecompr-r85/3696/36966209/Marsdeni+Barrel+Chair.jpg"
#     }
#     full_matching_images {
#       url: "https://secure.img1-fg.wfcdn.com/im/06953777/compr-r85/3696/36966209/marsdeni-barrel-chair.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.birchlane.com/furniture/sb0/accent-chairs-c1867183.html"
#     page_title: "Farmhouse Accent <b>Chairs</b> | Birch Lane"
#     full_matching_images {
#       url: "https://secure.img1-ag.wfcdn.com/im/67989526/resize-h310-w310%5Ecompr-r85/3696/36966209/marsdeni-barrel-chair.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.pinterest.com/pin/46584177370517787/"
#     page_title: "A Stunning Set of Milo Baughman Swiveling <b>Barrel Chairs</b> - Pinterest"
#     partial_matching_images {
#       url: "https://i.pinimg.com/236x/97/95/c2/9795c23da71009be0f95847b1a5e87ff--barrel-chair-guest-suite.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.allmodern.com/keyword.php?keyword=kennedy+barrel+chair"
#     page_title: "Modern &amp; Contemporary Kennedy <b>Barrel Chair</b> | AllModern"
#     partial_matching_images {
#       url: "https://secure.img1-fg.wfcdn.com/im/53368247/resize-h310-w310%5Ecompr-r85/3920/39201652/liam-barrel-chair.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.jossandmain.com/furniture/hd0/marsdeni-barrel-chair-l54-k~latr2530.html?curpage=28&piid[]=20550683"
#     page_title: "Marsdeni <b>Barrel Chair</b> | Joss &amp; Main"
#     full_matching_images {
#       url: "https://secure.img1-fg.wfcdn.com/im/27943594/resize-h400-w400%5Ecompr-r85/3696/36966209/Marsdeni+Barrel+Chair.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.jossandmain.com/furniture/hd0/marsdeni-barrel-chair-l54-k~latr2530.html?sortby=88&curpage=35"
#     page_title: "Marsdeni <b>Barrel Chair</b> | Joss &amp; Main"
#     full_matching_images {
#       url: "https://secure.img1-ag.wfcdn.com/im/23975830/resize-h600-w600%5Ecompr-r85/3696/36966209/Marsdeni+Barrel+Chair.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.hayneedle.com/furniture/accent-chairs_brands-fox-hill_list_178194_5994"
#     page_title: "Fox Hill Accent <b>Chairs</b> | Hayneedle"
#     partial_matching_images {
#       url: "https://content.haycdn.com/mgen/inuse:FOXH214.jpg?is=300,300,0xffffff&cvt=jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://secure.img1-ag.wfcdn.com/im/44321876/resize-h400-w400%5Ecompr-r85/3696/36966207/Marsdeni+Barrel+Chair.jpg"
#   }
#   visually_similar_images {
#     url: "https://secure.img1-fg.wfcdn.com/im/25687852/resize-h800-w800%5Ecompr-r85/3696/36966207/Marsdeni+Barrel+Chair.jpg"
#   }
#   visually_similar_images {
#     url: "https://secure.img2-fg.wfcdn.com/im/98725996/resize-h600-w600%5Ecompr-r85/3696/36966207/Marsdeni+Barrel+Chair.jpg"
#   }
#   visually_similar_images {
#     url: "https://s-media-cache-ak0.pinimg.com/originals/96/ac/f0/96acf0fd121009314a46dd64c9b6364c.jpg"
#   }
#   visually_similar_images {
#     url: "https://secure.img2-fg.wfcdn.com/im/73892114/resize-h310-w310%5Ecompr-r85/3617/36177296/kangas-barrel-chair.jpg"
#   }
#   visually_similar_images {
#     url: "https://secure.img2-fg.wfcdn.com/im/10200903/resize-h310-w310%5Ecompr-r85/3022/30226252/eye-barrel-chair.jpg"
#   }
#   visually_similar_images {
#     url: "http://jukify.me/wp-content/uploads/2018/01/excellent-blue-barrel-chair-barrel-chair.jpg"
#   }
#   visually_similar_images {
#     url: "https://secure.img2-fg.wfcdn.com/im/17033241/resize-h310-w310%5Ecompr-r85/3679/36793875/stian-barrel-chair.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.ebayimg.com/images/g/bg8AAOSwSlBYtNu1/s-l300.jpg"
#   }
#   visually_similar_images {
#     url: "http://emdyp.me/wp-content/uploads/2018/07/wayfair-blue-chair-barrel-chair-wayfair-blue-velvet-chair.jpg"
#   }
#   best_guess_labels {
#     label: "barrel chair blue"
#     language_code: "en"
#   }
# }

# %%
df_query_result2
# Out:
#                                                  url  \
# 0  https://www.hellyhansen.com/media/catalog/prod...
# 1  https://www.patagonia.com/dis/dw/image/v2/ABBM...
# 2  https://www.nigeltyas.co.uk/pub/media/catalog/...
# 3  https://secure.img1-fg.wfcdn.com/im/06953777/c...
#
#                                       image_property  \
# 0  {'imagePropertiesAnnotation': {'dominantColors...
# 1  {'imagePropertiesAnnotation': {'dominantColors...
# 2  {'imagePropertiesAnnotation': {'dominantColors...
# 3  {'imagePropertiesAnnotation': {'dominantColors...
#
#                                        web_detection
# 0  {'webDetection': {'webEntities': [{'entityId':...
# 1  {'webDetection': {'webEntities': [{'entityId':...
# 2  {'webDetection': {'webEntities': [{'entityId':...
# 3  {'webDetection': {'webEntities': [{'entityId':...

# %%
df_query_result2.to_csv('vision_api_query_sample.csv')

# %%
files.download('vision_api_query_sample.csv')

# %%
ls
# Out:
# google_cloud_creds2.json       sample_data/
# random_10K_image_urls (1).csv  vision_api_query_sample.csv

# %%
#df_query_result2.iloc[0]['web_detection']

# %%
################ TRY WITH RANDOM 10 K  NOTH URL  ################

# %%
df_10k_random = pd.read_csv('random_10K_image_urls.csv')

# %%
df_10k_random.head(3)
# Out:
#                                                  url
# 0  https://assets-notonthehighstreet-com.s3.amazo...
# 1  https://assets-notonthehighstreet-com.s3.amazo...
# 2  https://assets-notonthehighstreet-com.s3.amazo...

# %%
# sample data 
df_10k_random_ = df_10k_random.head(10)

# query google vision api 
df_10k_random_['image_property'] = df_10k_random_['url'].apply(lambda x : g_image_property(x))
df_10k_random_['web_detection'] = df_10k_random_['url'].apply(lambda x : g_web_detection(x))
# extract web entity information 
df_10k_random_['web_entity'] = df_10k_random_['web_detection'].apply(lambda x : get_web_entity(x))
# Out:
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 166.0
#         green: 162.0
#         blue: 153.0
#       }
#       score: 0.34678566455841064
#       pixel_fraction: 0.18145833909511566
#     }
#     colors {
#       color {
#         red: 64.0
#         green: 96.0
#         blue: 68.0
#       }
#       score: 0.03624964505434036
#       pixel_fraction: 0.006527777761220932
#     }
#     colors {
#       color {
#         red: 171.0
#         green: 163.0
#         blue: 146.0
#       }
#       score: 0.15224076807498932
#       pixel_fraction: 0.07777778059244156
#     }
#     colors {
#       color {
#         red: 186.0
#         green: 185.0
#         blue: 179.0
#       }
#       score: 0.07636457681655884
#       pixel_fraction: 0.12479166686534882
#     }
#     colors {
#       color {
#         red: 121.0
#         green: 120.0
#         blue: 114.0
#       }
#       score: 0.04679257050156593
#       pixel_fraction: 0.03187499940395355
#     }
#     colors {
#       color {
#         red: 86.0
#         green: 85.0
#         blue: 78.0
#       }
#       score: 0.04497827589511871
#       pixel_fraction: 0.027361111715435982
#     }
#     colors {
#       color {
#         red: 56.0
#         green: 54.0
#         blue: 49.0
#       }
#       score: 0.033778201788663864
#       pixel_fraction: 0.022638889029622078
#     }
#     colors {
#       color {
#         red: 219.0
#         green: 234.0
#         blue: 236.0
#       }
#       score: 0.0325448103249073
#       pixel_fraction: 0.32034721970558167
#     }
#     colors {
#       color {
#         red: 64.0
#         green: 92.0
#         blue: 79.0
#       }
#       score: 0.02984190359711647
#       pixel_fraction: 0.013680555857717991
#     }
#     colors {
#       color {
#         red: 94.0
#         green: 125.0
#         blue: 95.0
#       }
#       score: 0.02679683081805706
#       pixel_fraction: 0.0036805556155741215
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 185.0
#         green: 158.0
#         blue: 139.0
#       }
#       score: 0.20225070416927338
#       pixel_fraction: 0.05693277344107628
#     }
#     colors {
#       color {
#         red: 185.0
#         green: 149.0
#         blue: 148.0
#       }
#       score: 0.14666655659675598
#       pixel_fraction: 0.053011205047369
#     }
#     colors {
#       color {
#         red: 205.0
#         green: 177.0
#         blue: 157.0
#       }
#       score: 0.1768627166748047
#       pixel_fraction: 0.05406162515282631
#     }
#     colors {
#       color {
#         red: 183.0
#         green: 148.0
#         blue: 136.0
#       }
#       score: 0.08781303465366364
#       pixel_fraction: 0.02710084058344364
#     }
#     colors {
#       color {
#         red: 215.0
#         green: 181.0
#         blue: 181.0
#       }
#       score: 0.0709015280008316
#       pixel_fraction: 0.08592437207698822
#     }
#     colors {
#       color {
#         red: 153.0
#         green: 116.0
#         blue: 106.0
#       }
#       score: 0.053304221481084824
#       pixel_fraction: 0.012675070203840733
#     }
#     colors {
#       color {
#         red: 142.0
#         green: 115.0
#         blue: 96.0
#       }
#       score: 0.046419478952884674
#       pixel_fraction: 0.008473389782011509
#     }
#     colors {
#       color {
#         red: 205.0
#         green: 187.0
#         blue: 182.0
#       }
#       score: 0.0424998439848423
#       pixel_fraction: 0.147198885679245
#     }
#     colors {
#       color {
#         red: 152.0
#         green: 114.0
#         blue: 113.0
#       }
#       score: 0.037489090114831924
#       pixel_fraction: 0.008543417789041996
#     }
#     colors {
#       color {
#         red: 172.0
#         green: 154.0
#         blue: 149.0
#       }
#       score: 0.03423192352056503
#       pixel_fraction: 0.39523810148239136
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 347
#       }
#       vertices {
#         y: 347
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 223.0
#         green: 200.0
#         blue: 175.0
#       }
#       score: 0.3367827832698822
#       pixel_fraction: 0.050208333879709244
#     }
#     colors {
#       color {
#         red: 235.0
#         green: 230.0
#         blue: 227.0
#       }
#       score: 0.24570441246032715
#       pixel_fraction: 0.7167361378669739
#     }
#     colors {
#       color {
#         red: 59.0
#         green: 51.0
#         blue: 48.0
#       }
#       score: 0.035400308668613434
#       pixel_fraction: 0.012569444254040718
#     }
#     colors {
#       color {
#         red: 128.0
#         green: 74.0
#         blue: 58.0
#       }
#       score: 0.018277309834957123
#       pixel_fraction: 0.005625000223517418
#     }
#     colors {
#       color {
#         red: 101.0
#         green: 30.0
#         blue: 15.0
#       }
#       score: 0.007512776646763086
#       pixel_fraction: 0.0011111111380159855
#     }
#     colors {
#       color {
#         red: 203.0
#         green: 198.0
#         blue: 195.0
#       }
#       score: 0.1252969205379486
#       pixel_fraction: 0.0637499988079071
#     }
#     colors {
#       color {
#         red: 233.0
#         green: 214.0
#         blue: 193.0
#       }
#       score: 0.057471953332424164
#       pixel_fraction: 0.01354166679084301
#     }
#     colors {
#       color {
#         red: 159.0
#         green: 152.0
#         blue: 148.0
#       }
#       score: 0.03064323030412197
#       pixel_fraction: 0.017569445073604584
#     }
#     colors {
#       color {
#         red: 125.0
#         green: 117.0
#         blue: 113.0
#       }
#       score: 0.024925008416175842
#       pixel_fraction: 0.011388888582587242
#     }
#     colors {
#       color {
#         red: 90.0
#         green: 82.0
#         blue: 79.0
#       }
#       score: 0.02367486245930195
#       pixel_fraction: 0.011388888582587242
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 233.0
#         green: 233.0
#         blue: 225.0
#       }
#       score: 0.24488899111747742
#       pixel_fraction: 0.06173611059784889
#     }
#     colors {
#       color {
#         red: 24.0
#         green: 24.0
#         blue: 21.0
#       }
#       score: 0.16312621533870697
#       pixel_fraction: 0.09416666626930237
#     }
#     colors {
#       color {
#         red: 118.0
#         green: 118.0
#         blue: 110.0
#       }
#       score: 0.12323987483978271
#       pixel_fraction: 0.048055555671453476
#     }
#     colors {
#       color {
#         red: 199.0
#         green: 197.0
#         blue: 189.0
#       }
#       score: 0.09753844141960144
#       pixel_fraction: 0.031180555000901222
#     }
#     colors {
#       color {
#         red: 86.0
#         green: 85.0
#         blue: 82.0
#       }
#       score: 0.08000663667917252
#       pixel_fraction: 0.3577083349227905
#     }
#     colors {
#       color {
#         red: 50.0
#         green: 49.0
#         blue: 49.0
#       }
#       score: 0.07585982978343964
#       pixel_fraction: 0.3492361009120941
#     }
#     colors {
#       color {
#         red: 158.0
#         green: 156.0
#         blue: 148.0
#       }
#       score: 0.07055202126502991
#       pixel_fraction: 0.027708332985639572
#     }
#     colors {
#       color {
#         red: 161.0
#         green: 154.0
#         blue: 134.0
#       }
#       score: 0.04353611543774605
#       pixel_fraction: 0.00798611156642437
#     }
#     colors {
#       color {
#         red: 129.0
#         green: 122.0
#         blue: 101.0
#       }
#       score: 0.03915640711784363
#       pixel_fraction: 0.009027778171002865
#     }
#     colors {
#       color {
#         red: 200.0
#         green: 192.0
#         blue: 173.0
#       }
#       score: 0.038646649569272995
#       pixel_fraction: 0.0069444444961845875
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 88.0
#         green: 78.0
#         blue: 63.0
#       }
#       score: 0.23351836204528809
#       pixel_fraction: 0.056388888508081436
#     }
#     colors {
#       color {
#         red: 238.0
#         green: 232.0
#         blue: 224.0
#       }
#       score: 0.12677127122879028
#       pixel_fraction: 0.15194444358348846
#     }
#     colors {
#       color {
#         red: 61.0
#         green: 131.0
#         blue: 148.0
#       }
#       score: 0.07057429850101471
#       pixel_fraction: 0.1850000023841858
#     }
#     colors {
#       color {
#         red: 242.0
#         green: 186.0
#         blue: 171.0
#       }
#       score: 0.024975689128041267
#       pixel_fraction: 0.008263888768851757
#     }
#     colors {
#       color {
#         red: 215.0
#         green: 128.0
#         blue: 119.0
#       }
#       score: 0.021891634911298752
#       pixel_fraction: 0.00798611156642437
#     }
#     colors {
#       color {
#         red: 214.0
#         green: 80.0
#         blue: 75.0
#       }
#       score: 0.007168736308813095
#       pixel_fraction: 0.0018055555410683155
#     }
#     colors {
#       color {
#         red: 55.0
#         green: 12.0
#         blue: 7.0
#       }
#       score: 0.0024698786437511444
#       pixel_fraction: 0.00020833333837799728
#     }
#     colors {
#       color {
#         red: 91.0
#         green: 84.0
#         blue: 78.0
#       }
#       score: 0.06569154560565948
#       pixel_fraction: 0.0416666679084301
#     }
#     colors {
#       color {
#         red: 244.0
#         green: 230.0
#         blue: 212.0
#       }
#       score: 0.044551506638526917
#       pixel_fraction: 0.03236111253499985
#     }
#     colors {
#       color {
#         red: 116.0
#         green: 117.0
#         blue: 113.0
#       }
#       score: 0.03481007739901543
#       pixel_fraction: 0.030138889327645302
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 187.0
#         green: 193.0
#         blue: 182.0
#       }
#       score: 0.6079646348953247
#       pixel_fraction: 0.25312501192092896
#     }
#     colors {
#       color {
#         red: 26.0
#         green: 28.0
#         blue: 22.0
#       }
#       score: 0.07017625123262405
#       pixel_fraction: 0.020347222685813904
#     }
#     colors {
#       color {
#         red: 160.0
#         green: 165.0
#         blue: 155.0
#       }
#       score: 0.13731607794761658
#       pixel_fraction: 0.023333333432674408
#     }
#     colors {
#       color {
#         red: 47.0
#         green: 50.0
#         blue: 43.0
#       }
#       score: 0.06748747825622559
#       pixel_fraction: 0.027499999850988388
#     }
#     colors {
#       color {
#         red: 224.0
#         green: 226.0
#         blue: 218.0
#       }
#       score: 0.04223116487264633
#       pixel_fraction: 0.6458333134651184
#     }
#     colors {
#       color {
#         red: 119.0
#         green: 122.0
#         blue: 114.0
#       }
#       score: 0.0421275794506073
#       pixel_fraction: 0.012777777388691902
#     }
#     colors {
#       color {
#         red: 81.0
#         green: 83.0
#         blue: 76.0
#       }
#       score: 0.03269679471850395
#       pixel_fraction: 0.017083333805203438
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 236.0
#         green: 236.0
#         blue: 236.0
#       }
#       score: 0.22615693509578705
#       pixel_fraction: 0.16256944835186005
#     }
#     colors {
#       color {
#         red: 231.0
#         green: 225.0
#         blue: 117.0
#       }
#       score: 0.19691269099712372
#       pixel_fraction: 0.008263888768851757
#     }
#     colors {
#       color {
#         red: 233.0
#         green: 225.0
#         blue: 89.0
#       }
#       score: 0.12496335804462433
#       pixel_fraction: 0.005625000223517418
#     }
#     colors {
#       color {
#         red: 218.0
#         green: 212.0
#         blue: 74.0
#       }
#       score: 0.07311296463012695
#       pixel_fraction: 0.006736110895872116
#     }
#     colors {
#       color {
#         red: 218.0
#         green: 212.0
#         blue: 107.0
#       }
#       score: 0.0704493597149849
#       pixel_fraction: 0.006041666492819786
#     }
#     colors {
#       color {
#         red: 82.0
#         green: 76.0
#         blue: 107.0
#       }
#       score: 0.0004907039692625403
#       pixel_fraction: 0.00013888889225199819
#     }
#     colors {
#       color {
#         red: 236.0
#         green: 232.0
#         blue: 199.0
#       }
#       score: 0.04512206092476845
#       pixel_fraction: 0.007916666567325592
#     }
#     colors {
#       color {
#         red: 234.0
#         green: 225.0
#         blue: 162.0
#       }
#       score: 0.041900139302015305
#       pixel_fraction: 0.003888888983055949
#     }
#     colors {
#       color {
#         red: 226.0
#         green: 227.0
#         blue: 152.0
#       }
#       score: 0.04109867662191391
#       pixel_fraction: 0.0027777778450399637
#     }
#     colors {
#       color {
#         red: 238.0
#         green: 220.0
#         blue: 120.0
#       }
#       score: 0.030980536714196205
#       pixel_fraction: 0.0015277777565643191
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 317
#       }
#       vertices {
#         x: 317
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 0.9899999499320984
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 97.0
#         green: 118.0
#         blue: 166.0
#       }
#       score: 0.19681981205940247
#       pixel_fraction: 0.010347221978008747
#     }
#     colors {
#       color {
#         red: 220.0
#         green: 203.0
#         blue: 149.0
#       }
#       score: 0.07184486091136932
#       pixel_fraction: 0.010833333246409893
#     }
#     colors {
#       color {
#         red: 103.0
#         green: 120.0
#         blue: 156.0
#       }
#       score: 0.16015924513339996
#       pixel_fraction: 0.013194444589316845
#     }
#     colors {
#       color {
#         red: 67.0
#         green: 89.0
#         blue: 136.0
#       }
#       score: 0.14588424563407898
#       pixel_fraction: 0.0071527776308357716
#     }
#     colors {
#       color {
#         red: 130.0
#         green: 148.0
#         blue: 186.0
#       }
#       score: 0.08303681761026382
#       pixel_fraction: 0.007430555764585733
#     }
#     colors {
#       color {
#         red: 212.0
#         green: 200.0
#         blue: 164.0
#       }
#       score: 0.06606760621070862
#       pixel_fraction: 0.028263889253139496
#     }
#     colors {
#       color {
#         red: 123.0
#         green: 144.0
#         blue: 191.0
#       }
#       score: 0.05116792023181915
#       pixel_fraction: 0.0027083333116024733
#     }
#     colors {
#       color {
#         red: 71.0
#         green: 88.0
#         blue: 121.0
#       }
#       score: 0.04582860693335533
#       pixel_fraction: 0.004791666753590107
#     }
#     colors {
#       color {
#         red: 193.0
#         green: 196.0
#         blue: 193.0
#       }
#       score: 0.02846316061913967
#       pixel_fraction: 0.12854166328907013
#     }
#     colors {
#       color {
#         red: 162.0
#         green: 157.0
#         blue: 126.0
#       }
#       score: 0.022273141890764236
#       pixel_fraction: 0.06576389074325562
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 155.0
#         green: 156.0
#         blue: 162.0
#       }
#       score: 0.2973148226737976
#       pixel_fraction: 0.4402777850627899
#     }
#     colors {
#       color {
#         red: 26.0
#         green: 22.0
#         blue: 22.0
#       }
#       score: 0.2609545886516571
#       pixel_fraction: 0.056458331644535065
#     }
#     colors {
#       color {
#         red: 54.0
#         green: 50.0
#         blue: 51.0
#       }
#       score: 0.14950236678123474
#       pixel_fraction: 0.09763889014720917
#     }
#     colors {
#       color {
#         red: 86.0
#         green: 84.0
#         blue: 90.0
#       }
#       score: 0.12736041843891144
#       pixel_fraction: 0.06479166448116302
#     }
#     colors {
#       color {
#         red: 117.0
#         green: 117.0
#         blue: 123.0
#       }
#       score: 0.11153966188430786
#       pixel_fraction: 0.0560416653752327
#     }
#     colors {
#       color {
#         red: 112.0
#         green: 117.0
#         blue: 135.0
#       }
#       score: 0.031021861359477043
#       pixel_fraction: 0.17569445073604584
#     }
#     colors {
#       color {
#         red: 88.0
#         green: 91.0
#         blue: 108.0
#       }
#       score: 0.012497282586991787
#       pixel_fraction: 0.009236111305654049
#     }
#     colors {
#       color {
#         red: 186.0
#         green: 186.0
#         blue: 195.0
#       }
#       score: 0.005976103246212006
#       pixel_fraction: 0.0015972221735864878
#     }
#     colors {
#       color {
#         red: 134.0
#         green: 141.0
#         blue: 161.0
#       }
#       score: 0.0017226987984031439
#       pixel_fraction: 0.0964583307504654
#     }
#     colors {
#       color {
#         red: 50.0
#         green: 51.0
#         blue: 66.0
#       }
#       score: 0.0013972129672765732
#       pixel_fraction: 0.0013194443890824914
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#         y: 30
#       }
#       vertices {
#         x: 349
#         y: 30
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 0.9699999690055847
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 221.0
#         green: 221.0
#         blue: 215.0
#       }
#       score: 0.3792009949684143
#       pixel_fraction: 0.3040972352027893
#     }
#     colors {
#       color {
#         red: 83.0
#         green: 84.0
#         blue: 81.0
#       }
#       score: 0.06210485100746155
#       pixel_fraction: 0.013749999925494194
#     }
#     colors {
#       color {
#         red: 105.0
#         green: 70.0
#         blue: 45.0
#       }
#       score: 0.023440690711140633
#       pixel_fraction: 0.0037499999161809683
#     }
#     colors {
#       color {
#         red: 203.0
#         green: 203.0
#         blue: 199.0
#       }
#       score: 0.16266196966171265
#       pixel_fraction: 0.33965277671813965
#     }
#     colors {
#       color {
#         red: 22.0
#         green: 49.0
#         blue: 102.0
#       }
#       score: 0.0008256178116425872
#       pixel_fraction: 0.0010416667209938169
#     }
#     colors {
#       color {
#         red: 155.0
#         green: 158.0
#         blue: 156.0
#       }
#       score: 0.07520284503698349
#       pixel_fraction: 0.17826388776302338
#     }
#     colors {
#       color {
#         red: 116.0
#         green: 117.0
#         blue: 114.0
#       }
#       score: 0.05778409168124199
#       pixel_fraction: 0.019375000149011612
#     }
#     colors {
#       color {
#         red: 171.0
#         green: 145.0
#         blue: 118.0
#       }
#       score: 0.0479092076420784
#       pixel_fraction: 0.04416666552424431
#     }
#     colors {
#       color {
#         red: 49.0
#         green: 50.0
#         blue: 48.0
#       }
#       score: 0.04632264003157616
#       pixel_fraction: 0.009444444440305233
#     }
#     colors {
#       color {
#         red: 28.0
#         green: 28.0
#         blue: 26.0
#       }
#       score: 0.03934197127819061
#       pixel_fraction: 0.010416666977107525
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/01h3n"
#     score: 0.7762500047683716
#     description: "Bee"
#   }
#   web_entities {
#     entity_id: "/m/023j4r"
#     score: 0.7027000188827515
#     description: "Nail"
#   }
#   web_entities {
#     entity_id: "/m/0zdksk1"
#     score: 0.5293999910354614
#     description: "Nail art"
#   }
#   web_entities {
#     entity_id: "/m/0204p6"
#     score: 0.43650001287460327
#     description: "Decal"
#   }
#   web_entities {
#     entity_id: "/t/24mypdx4svpvn"
#     score: 0.4174000024795532
#   }
#   web_entities {
#     entity_id: "/m/05b97g"
#     score: 0.33239999413490295
#     description: "Sticker"
#   }
#   web_entities {
#     entity_id: "/m/0fz0z"
#     score: 0.3203999996185303
#     description: "Honey bee"
#   }
#   web_entities {
#     entity_id: "/m/0rzp91s"
#     score: 0.31450000405311584
#   }
#   web_entities {
#     entity_id: "/g/11gh3gv56b"
#     score: 0.2946999967098236
#     description: "Nail Art-Cards"
#   }
#   web_entities {
#     entity_id: "/t/2559cfx2jwyf6"
#     score: 0.2653000056743622
#   }
#   full_matching_images {
#     url: "https://katebroughton.co.uk/content/uploads/2012/10/XMNT_CU_WEB-250x250.jpg"
#   }
#   partial_matching_images {
#     url: "https://katebroughton.co.uk/content/uploads/2017/01/BENT_CU_WEB.jpg"
#   }
#   partial_matching_images {
#     url: "https://i.etsystatic.com/5239034/r/il/a3791a/1131235786/il_570xN.1131235786_f328.jpg"
#   }
#   partial_matching_images {
#     url: "https://i.etsystatic.com/5239034/r/il/4e00ed/1131237164/il_570xN.1131237164_az7m.jpg"
#   }
#   partial_matching_images {
#     url: "https://s359.kapook.com/entry/241b6a10-342c-4f9c-acac-26af181029f6.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/listing/251431918/house-plant-leaf-nail-transfers-cheese"
#     page_title: "house plant leaf nail <b>transfers</b> cheese plant <b>nail art decals</b> | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5239034/r/il/4e00ed/1131237164/il_570xN.1131237164_az7m.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/catalog/nail-art/"
#     page_title: "<b>Nail Art</b> - <b>Kate Broughton</b>"
#     full_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2012/10/XMNT_CU_WEB-250x250.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/shop/bee-nail-stickers/"
#     page_title: "<b>Bee nail transfers</b> \302\2434.00 - <b>Kate Broughton</b>"
#     partial_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2017/01/BENT_CU_WEB.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/sg-en/listing/251431918/house-plant-leaf-nail-transfers-cheese"
#     page_title: "house plant leaf nail <b>transfers</b> cheese plant <b>nail art decals</b> | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5239034/r/il/4e00ed/1131237164/il_570xN.1131237164_az7m.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/shop/exotic-bird-nail-transfers/"
#     page_title: "Exotic bird <b>nail transfers</b> \302\2434.00 - <b>Kate Broughton</b>"
#     full_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2012/10/XMNT_CU_WEB-250x250.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/shop/page/3/"
#     page_title: "Shop - <b>Kate Broughton</b>"
#     partial_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2017/01/BENT_CU_WEB.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/listing/113217939/christmas-nail-transfers-handmade"
#     page_title: "christmas nail <b>transfers</b> handmade festive <b>nail art decals</b> | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5239034/r/il/a3791a/1131235786/il_570xN.1131235786_f328.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/shop/badger-nail-stickers/"
#     page_title: "badger <b>nail transfers</b> \302\2434.00 - <b>Kate Broughton</b>"
#     full_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2012/10/XMNT_CU_WEB-250x250.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/shop/owl-nail-stickers/"
#     page_title: "owl <b>nail transfers</b> \302\2434.00 - <b>Kate Broughton</b>"
#     full_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2012/10/XMNT_CU_WEB-250x250.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/uk/listing/251431918/house-plant-leaf-nail-transfers-cheese"
#     page_title: "house plant leaf nail <b>transfers</b> cheese plant <b>nail art decals</b> | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5239034/r/il/4e00ed/1131237164/il_570xN.1131237164_az7m.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/d2/d9/2aa0-f0f1-4028-9021-cd0e9a5b5f8e/preview_bee-nail-art-stickers.jpg"
#   }
#   visually_similar_images {
#     url: "https://img.shopstyle-cdn.com/pim/54/b7/54b7197d896d336daae529d5a163f670_xlarge.jpg"
#   }
#   visually_similar_images {
#     url: "https://img1.etsystatic.com/167/0/5239034/il_340x270.1177836373_ncnh.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/40/a0/46c0-638a-46bf-98c1-b5c2b3af51f5/original_wild-flower-nail-art-stickers.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/49/8c/8571-eec7-43b6-9cd6-98f0e6259220/preview_cat-nail-art-stickers.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.etsystatic.com/5239034/r/il/e0718d/1131234540/il_570xN.1131234540_n5cj.jpg"
#   }
#   visually_similar_images {
#     url: "https://img.etsystatic.com/il/1dcfa9/1131236038/il_fullxfull.1131236038_cmyg.jpg?version=0"
#   }
#   visually_similar_images {
#     url: "https://i.etsystatic.com/5239034/r/il/bb8a8e/1177835057/il_570xN.1177835057_fzgv.jpg"
#   }
#   visually_similar_images {
#     url: "https://katebroughton.co.uk/content/uploads/2017/01/BCNT_flat_WEB-250x250.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/e1/a4/21fc-1f91-4652-807d-e0fef8c2e3ff/original_christmas-nail-art-stickers.jpg"
#   }
#   best_guess_labels {
#     label: "kate broughton bee nail art transfers"
#     language_code: "en"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/03lnq3"
#     score: 0.8978147506713867
#     description: "Key Chains"
#   }
#   web_entities {
#     entity_id: "/g/11c6t_8_mf"
#     score: 0.5656999945640564
#   }
#   web_entities {
#     entity_id: "/m/07kdlck"
#     score: 0.5011000037193298
#     description: "Keyring"
#   }
#   web_entities {
#     entity_id: "/m/0rzp91s"
#     score: 0.47749999165534973
#   }
#   web_entities {
#     entity_id: "/m/0d84n"
#     score: 0.3400999903678894
#     description: "Gift"
#   }
#   web_entities {
#     entity_id: "/m/01p9z0"
#     score: 0.328900009393692
#     description: "Wood carving"
#   }
#   web_entities {
#     entity_id: "/g/11hdc2bvxf"
#     score: 0.2680000066757202
#     description: "Buddha Groove Hand Carved Wood Sitting Buddha Statue"
#   }
#   web_entities {
#     entity_id: "/m/01mrgs"
#     score: 0.2531999945640564
#     description: "Craft"
#   }
#   web_entities {
#     entity_id: "/m/080hkjn"
#     score: 0.25119999051094055
#     description: "Handbag"
#   }
#   web_entities {
#     entity_id: "/m/03v3yw"
#     score: 0.2272000014781952
#     description: "Key"
#   }
#   partial_matching_images {
#     url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/ca/market/wooden_keyring"
#     page_title: "Wooden keyring | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/sg-en/market/wooden_keyring"
#     page_title: "Wooden keyring | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/market/days_together_but?page=2"
#     page_title: "Days together but | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/hk-en/listing/265326636/carved-heart-personalised-wooden-plant"
#     page_title: "Carved Heart Personalised Wooden Plant Label | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#     }
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/0405/9589/products/SAM_4257_large.JPG?v=1523674156"
#   }
#   visually_similar_images {
#     url: "http://cdn.shopify.com/s/files/1/0405/9589/products/Brass_Tag_Keychain_Engraved_with_7_670_Days__Happy_21st___21_Year_Anniversary_Couples_Keychain_H_grande.jpg?v=1503450697"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/0405/9589/products/His_Cowgirl_Hand_Stamped_on_Aluminum_Tag_Keychain_and_Cowboy_Boot_Charm_Keychain_h_large.jpg?v=1453841512"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/0405/9589/products/Best_Mom_Ever_Hand_Stamped_Aluminum_Tag_Keychain_Hand_Stamped_Mother_s_Keychain_h_large.JPG?v=1475419844"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/0405/9589/products/my_favorite_spoon_aluminum_keychain_large.JPG?v=1491674108"
#   }
#   visually_similar_images {
#     url: "http://cdn.shopify.com/s/files/1/0405/9589/products/My_Best_Catch_Engraved_on_Aluminum_Tag_Keychain_with_Football_Charm_Keychain_Handmade_Couples_Keychain_h_grande.jpg?v=1507063368"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/0405/9589/products/SAM_2862_large.JPG?v=1511498136"
#   }
#   visually_similar_images {
#     url: "https://s-media-cache-ak0.pinimg.com/originals/c7/f5/2a/c7f52a51df22f8b54223f1575e25a7d0.jpg"
#   }
#   best_guess_labels {
#     label: "keychain"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/0lbxg"
#     score: 0.7024000287055969
#     description: "Father"
#   }
#   web_entities {
#     entity_id: "/m/0cjkt"
#     score: 0.7014999985694885
#     description: "Father\'s Day"
#   }
#   web_entities {
#     entity_id: "/m/0lbxz"
#     score: 0.6937000155448914
#     description: "Mother"
#   }
#   web_entities {
#     entity_id: "/m/0cjjt"
#     score: 0.5910000205039978
#     description: "Mother\'s Day"
#   }
#   web_entities {
#     entity_id: "/m/0d84n"
#     score: 0.4943999946117401
#     description: "Gift"
#   }
#   web_entities {
#     entity_id: "/m/0d7pp"
#     score: 0.4595000147819519
#     description: "Credit card"
#   }
#   web_entities {
#     entity_id: "/g/11bwd7p_dc"
#     score: 0.43244999647140503
#     description: "Children\'s Book in Italian: My Daddy Is the Best. il Mio Papa e il Migliore: Childrens Italian Book (Bilingual Edition) Children\'s Picture Book English Italian. Kids Italian Book. Italian Picture Book"
#   }
#   web_entities {
#     entity_id: "/t/2559cfx2jwyf6"
#     score: 0.23800000548362732
#   }
#   web_entities {
#     entity_id: "/m/07ssc"
#     score: 0.2013000100851059
#     description: "United Kingdom"
#   }
#   web_entities {
#     entity_id: "/m/019_nn"
#     score: 0.1858000010251999
#     description: "Friendship"
#   }
#   full_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/preview_first-my-father-s-day-card.jpg"
#   }
#   full_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/thumb_first-my-father-s-day-card.jpg"
#   }
#   partial_matching_images {
#     url: "https://www.notsocks.co.nz/media/catalog/product/f/i/first_my_mother_card_1.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/oldenglishcompany/product/first-my-mother-card"
#     page_title: "&#39;<b>first my</b>&#39; <b>mother&#39;s day card</b> by old english company ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/thumb_first-my-father-s-day-card.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/oldenglishcompany/product/first-my-father-s-day-card"
#     page_title: "<b>first my</b> father&#39;s <b>day card</b> by old english company ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/preview_first-my-father-s-day-card.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notsocks.co.nz/first-my-mother-forever-my-friend-card"
#     page_title: "<b>First my Mother</b>, Forever <b>my</b> Friend <b>Card</b> - Not Socks Gifts"
#     partial_matching_images {
#       url: "https://www.notsocks.co.nz/media/catalog/product/f/i/first_my_mother_card_1.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/fathers-day/cards-wrap/sentimental-cards"
#     page_title: "Sentimental Father&#39;s <b>Day Cards</b> | notonthehighstreet.com"
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/preview_first-my-father-s-day-card.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/oldenglishcompany/product/personalised-father-s-day-print"
#     page_title: "personalised dad print by old english company | notonthehighstreet ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/thumb_first-my-father-s-day-card.jpg"
#     }
#   }
#   best_guess_labels {
#     label: "\'first my\' mother\'s day card"
#     language_code: "en"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/05fc9mj"
#     score: 0.8762999773025513
#     description: "Christmas decoration"
#   }
#   web_entities {
#     entity_id: "/m/025nd"
#     score: 0.6388999819755554
#     description: "Christmas tree"
#   }
#   web_entities {
#     entity_id: "/m/01vq3"
#     score: 0.6108999848365784
#     description: "Christmas Day"
#   }
#   web_entities {
#     entity_id: "/g/11f5j1mf02"
#     score: 0.4993000030517578
#     description: "East of India Wooden"
#   }
#   web_entities {
#     entity_id: "/m/0d84n"
#     score: 0.4869000017642975
#     description: "Gift"
#   }
#   web_entities {
#     entity_id: "/m/04kwhq"
#     score: 0.40059998631477356
#     description: "Christmas ornament"
#   }
#   web_entities {
#     entity_id: "/m/07j7r"
#     score: 0.30079999566078186
#     description: "Tree"
#   }
#   web_entities {
#     entity_id: "/g/11h9vqjh7h"
#     score: 0.2824000120162964
#     description: "Christmas gift"
#   }
#   web_entities {
#     entity_id: "/m/02_wsd"
#     score: 0.21570000052452087
#     description: "Conifer cone"
#   }
#   web_entities {
#     entity_id: "/m/01r546"
#     score: 0.1983434557914734
#     description: "Earring"
#   }
#   full_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/preview_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#   }
#   partial_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/thumb_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/theweddingofmydreams/product/large-wooden-acorn-and-pinecone-christmas-decorations"
#     page_title: "large wooden acorn and pinecone <b>christmas</b> decorations by the ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/preview_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/theweddingofmydreams/product/wooden-star-christmas-decorations"
#     page_title: "wooden star <b>christmas</b> decorations by the wedding of my dreams ..."
#     partial_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/thumb_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/theweddingofmydreams/product/wooden-trees-hanging-christmas-tree-decorations"
#     page_title: "wooden trees hanging <b>christmas</b> tree decorations by the wedding of ..."
#     partial_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/thumb_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/partners/theweddingofmydreams/products?page=5"
#     page_title: "the wedding of my dreams - products | notonthehighstreet.com"
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/preview_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://anextraordinaryday.net/wp-content/uploads/2015/10/Classy-Marbleized-Metallic-Christmas-Ornaments-to-Make-the-Tree-Sparkle-AnExtraordinaryDay.net_.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.sincerelysarad.com/wp-content/uploads/2016/10/Balsam-Hill-Tree-Decor.jpg"
#   }
#   visually_similar_images {
#     url: "http://villa-antonio.info/wp-content/uploads/2018/08/glass-ball-ornaments-ready-to-personalize-clear-christmas.jpg"
#   }
#   visually_similar_images {
#     url: "https://image.shutterstock.com/image-photo/silver-christmas-tree-baubles-isolated-260nw-330484679.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/1100/6424/files/snowglobe2.jpg?15167514632770090523"
#   }
#   visually_similar_images {
#     url: "https://get.pxhere.com/photo/glass-food-produce-yellow-christmas-lighting-christmas-ornament-christmas-decoration-christmas-time-grey-christmas-bauble-glass-ball-macro-photography-christmas-decorations-weihnachtsbaumschmuck-christmas-ornaments-tree-decorations-depend-mottle-1058229.jpg"
#   }
#   visually_similar_images {
#     url: "http://www.happyhalloweenday.com/wp-content/uploads/2016/10/Harry-Potter-Christmas-Ornaments.jpg"
#   }
#   visually_similar_images {
#     url: "https://image.dhgate.com/0x0s/f2-albu-g6-M00-A3-A8-rBVaSFsVjLiANo1MAAH0xcox0ss345.jpg/10pcs-wooden-baubles-tags-christmas-tree.jpg"
#   }
#   visually_similar_images {
#     url: "https://4.bp.blogspot.com/-A90EGBznQ-E/UFXuHXn9hnI/AAAAAAAAIPs/YueYzO_bGMg/s1600/christmas-tree-ornaments-13.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.pinimg.com/236x/3d/89/44/3d89440d3f7ff2c6deff24975f79cbcd--silver-christmas-magical-christmas.jpg"
#   }
#   best_guess_labels {
#     label: "Christmas decoration"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/01jwgf"
#     score: 0.47429999709129333
#     description: "Product"
#   }
#   web_entities {
#     entity_id: "/m/05z87"
#     score: 0.29264944791793823
#     description: "plastic"
#   }
#   web_entities {
#     entity_id: "/m/080f_8b"
#     score: 0.27079999446868896
#     description: "Household goods"
#   }
#   web_entities {
#     entity_id: "/m/068fpk"
#     score: 0.2393999993801117
#     description: "Coasters"
#   }
#   web_entities {
#     entity_id: "/g/11f7pg89w2"
#     score: 0.22360000014305115
#   }
#   web_entities {
#     entity_id: "/m/03y18t"
#     score: 0.21649549901485443
#     description: "Product design"
#   }
#   web_entities {
#     entity_id: "/m/0c_jw"
#     score: 0.20829999446868896
#     description: "Furniture"
#   }
#   web_entities {
#     entity_id: "/g/122fpn6r"
#     score: 0.16670000553131104
#     description: "Drink"
#   }
#   web_entities {
#     entity_id: "/m/01cd9"
#     score: 0.15553702414035797
#     description: "Brand"
#   }
#   web_entities {
#     entity_id: "/m/0d84n"
#     score: 0.1534000039100647
#     description: "Gift"
#   }
#   full_matching_images {
#     url: "https://www.tch.net/media/catalog/product/cache/1/small_image/295x295/9df78eab33525d08d6e5fb8d27136e95/3/E/3E6FCFE68270AD01B203DF16C596C1D5.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.tch.net/shop-by-product/coasters"
#     page_title: "Coasters - Shop By Product - Tch.net"
#     full_matching_images {
#       url: "https://www.tch.net/media/catalog/product/cache/1/small_image/295x295/9df78eab33525d08d6e5fb8d27136e95/3/E/3E6FCFE68270AD01B203DF16C596C1D5.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.tch.net/shop-by-product/coasters?limit=24"
#     page_title: "Coasters - Shop By Product - Tch.net"
#     full_matching_images {
#       url: "https://www.tch.net/media/catalog/product/cache/1/small_image/295x295/9df78eab33525d08d6e5fb8d27136e95/3/E/3E6FCFE68270AD01B203DF16C596C1D5.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "http://device.com.co/wp-content/uploads/2018/05/cute-toaster-toaster-coaster-super-cute-toaster-with-happy-popping-toast-on-a-drink-coaster.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.bottleyourbrand.com/media/dol/design/1/1464196791051951942218386.png"
#   }
#   visually_similar_images {
#     url: "https://image.made-in-china.com/202f0j00iJgQUWtlaVqZ/Custom-Fashion-Antiskid-Silicone-Rubber-Cup-Mug-Pot-Coaster-for-Drink.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.picclickimg.com/d/w1600/pict/152846632414_/Vintage-Travel-Poster-Drink-Coaster-London-Pan.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.pinimg.com/236x/b6/9e/74/b69e74ea24f8be32c152582018a7255f--coaster-crafts-cup-coaster.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.pinimg.com/originals/13/5b/df/135bdf0e5c1415f27804672df25509f0.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.picclickimg.com/d/l400/pict/152846631882_/Vintage-Travel-Poster-Drink-Coaster-Greece-1956.jpg"
#   }
#   visually_similar_images {
#     url: "https://img0.etsystatic.com/171/0/5957905/il_570xN.1204202620_r10j.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.picclickimg.com/d/l400/pict/162827257356_/Vintage-Travel-Poster-Drink-Coaster-Maui-United.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.ebayimg.com/images/g/RY8AAOSwD1xZ0lIl/s-l300.jpg"
#   }
#   best_guess_labels {
#     label: "Drink coaster"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/027_ny3"
#     score: 0.39968791604042053
#     description: "Still life photography"
#   }
#   web_entities {
#     entity_id: "/m/01spzs"
#     score: 0.38303130865097046
#     description: "Still life"
#   }
#   web_entities {
#     entity_id: "/m/0jjw"
#     score: 0.36640000343322754
#     description: "Art"
#   }
#   web_entities {
#     entity_id: "/m/010g1bz6"
#     score: 0.3481999933719635
#     description: "/m/02csf"
#   }
#   web_entities {
#     entity_id: "/m/0h0vk"
#     score: 0.33799999952316284
#     description: "Contemporary art"
#   }
#   web_entities {
#     entity_id: "/g/11cs5flkpx"
#     score: 0.27889999747276306
#     description: "Affordable Art Fair"
#   }
#   web_entities {
#     entity_id: "/m/0bp6j"
#     score: 0.2718000113964081
#     description: "Screen printing"
#   }
#   web_entities {
#     entity_id: "/t/2bp0gchh8ty8x"
#     score: 0.25949999690055847
#   }
#   web_entities {
#     entity_id: "/m/02csf"
#     score: 0.24471355974674225
#     description: "Drawing"
#   }
#   web_entities {
#     entity_id: "/m/0c5mq"
#     score: 0.22939999401569366
#     description: "Printing"
#   }
#   partial_matching_images {
#     url: "https://ktedwards.co.uk/wp-content/uploads/2017/02/On-top-of-the-world.jpg"
#   }
#   partial_matching_images {
#     url: "https://affordableartfair.com/media/catalog/product/cache/1/small_image/400x/17f82f742ffe127f42dca9de82fb58b1/o/n/on-top-of-the-world-katie-edwards-illustration-wychwood-art-1.jpg"
#   }
#   partial_matching_images {
#     url: "https://affordableartfair.com/media/catalog/product/cache/1/image/300x/17f82f742ffe127f42dca9de82fb58b1/o/n/on-top-of-the-world-katie-edwards-illustration-wychwood-art-1.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://affordableartfair.com/mont-ventoux"
#     page_title: "Affordable <b>Art</b> Fair | Buy prints online by Eliza Southwood"
#     partial_matching_images {
#       url: "https://affordableartfair.com/media/catalog/product/cache/1/image/300x/17f82f742ffe127f42dca9de82fb58b1/o/n/on-top-of-the-world-katie-edwards-illustration-wychwood-art-1.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://affordableartfair.com/katie-edwards-zebra-crossing-ii"
#     page_title: "Affordable <b>Art</b> Fair | Buy prits online by Katie Edwards"
#     partial_matching_images {
#       url: "https://affordableartfair.com/media/catalog/product/cache/1/image/300x/17f82f742ffe127f42dca9de82fb58b1/o/n/on-top-of-the-world-katie-edwards-illustration-wychwood-art-1.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://ktedwards.co.uk/project/on-top-of-the-world/"
#     page_title: "KATIE EDWARDS \302\273 On Top Of The World"
#     partial_matching_images {
#       url: "https://ktedwards.co.uk/wp-content/uploads/2017/02/On-top-of-the-world.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://images.neimanmarcus.com/ca/1/product_assets/H/B/L/B/E/NMHBLBE_mk.jpg"
#   }
#   visually_similar_images {
#     url: "https://thinkpraygift.com/wp-content/uploads/2015/09/1934-Best-Friend-Open-Art-Secret-Dry-Erase-Board-Think-Pray-Gift-350x435.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.twyla.com/web/assets/images/home/blog-tips-for-buying-art.57c6d8f076c7d1d069ce9707dcf8ecf0.jpg"
#   }
#   visually_similar_images {
#     url: "https://thinkpraygift.com/wp-content/uploads/2015/09/1933-With-God-Open-Art-Secret-Dry-Erase-Board-Think-Pray-Gift-350x435.jpg"
#   }
#   visually_similar_images {
#     url: "https://diyprojects.com/wp-content/uploads/2017/01/Wood-Wall-Art-02.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.gilliankyle.com/wp-content/uploads/2017/11/gillian-kyle-scottish-art-canvas-prints-scottish-wildlife-flights-of-fancy-bee-noir-print-555x555.jpg"
#   }
#   visually_similar_images {
#     url: "https://images.canvasondemand.com/promo-boxes/dcf2c821-10aa-43d2-8643-3df75fcfc0b3.jpg"
#   }
#   visually_similar_images {
#     url: "https://images.horchow.com/ca/4/product_assets/H/8/J/V/H/HCH8JVH_mk.jpg"
#   }
#   visually_similar_images {
#     url: "http://www.ucl.ac.uk/slade/media/2016/07/23/8315-original-945-stairs_lily-johnson_16_27431957670_o-960x640.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.etsystatic.com/6209236/d/il/dd97eb/1492093448/il_340x270.1492093448_40tl.jpg?version=0"
#   }
#   best_guess_labels {
#     label: "Art"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/0174g1"
#     score: 0.7049999833106995
#     description: "Cushion"
#   }
#   web_entities {
#     entity_id: "/m/034c16"
#     score: 0.6541000008583069
#     description: "Pillow"
#   }
#   web_entities {
#     entity_id: "/m/0rzp91s"
#     score: 0.5503000020980835
#   }
#   web_entities {
#     entity_id: "/m/0hnnb"
#     score: 0.5205000042915344
# ...
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/24/9c/845a-9bba-41da-addb-fe9f1f3a1bef/thumb_druzy-triangle-gold-necklace.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/iscahandmimi/product/sterling-silver-amethyst-slice-necklace"
#     page_title: "Sterling Silver Amethyst Slice Necklace - Notonthehighstreet.com"
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/24/9c/845a-9bba-41da-addb-fe9f1f3a1bef/thumb_druzy-triangle-gold-necklace.jpg"
#     }
#   }
#   best_guess_labels {
#     label: "druzy anh\303\244nger, blaue dreieck kristall, gold gef\303\274llt kette, rohe stein schmuck, edelstein halskette, geschenk f\303\274r freundin, geburtstagsgesch"
#     language_code: "de"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/01llx7"
#     score: 0.8895000219345093
#     description: "Bracelet"
#   }
#   web_entities {
#     entity_id: "/m/01r546"
#     score: 0.766800045967102
#     description: "Earring"
#   }
#   web_entities {
#     entity_id: "/m/01llwg"
#     score: 0.7286314964294434
#     description: "Necklace"
#   }
#   web_entities {
#     entity_id: "/m/025rs2z"
#     score: 0.7149999737739563
#     description: "Gold"
#   }
#   web_entities {
#     entity_id: "/m/04yf6s0"
#     score: 0.6980000138282776
#     description: "Colored gold"
#   }
#   web_entities {
#     entity_id: "/m/09l0j_"
#     score: 0.6733999848365784
#     description: "Ring"
#   }
#   web_entities {
#     entity_id: "/m/07sh0l"
#     score: 0.6636995673179626
#     description: "Locket"
#   }
#   web_entities {
#     entity_id: "/m/0404d"
#     score: 0.6037999987602234
#     description: "Jewellery"
#   }
#   web_entities {
#     entity_id: "/g/11c6vfcpx7"
#     score: 0.5893999934196472
#   }
#   web_entities {
#     entity_id: "/m/06_vzz4"
#     score: 0.5605999827384949
#     description: "Silver-gilt"
#   }
#   full_matching_images {
#     url: "https://img.shopstyle-cdn.com/pim/1d/8e/1d8ed3be266fd9c5624ae8a449b697cb_xlarge.jpg"
#   }
#   full_matching_images {
#     url: "https://www.biancajones.co.uk/wp-content/uploads/2015/04/pink-tourm-bracelet-300x300.jpg"
#   }
#   partial_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/f6/0b/6b23-9cd3-49ca-8f3c-27ee60231c87/preview_birthstone-initial-bracelet-in-yellow-or-rose-gold.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.biancajones.co.uk/personalised-jewellery/jewellery/yellow-gold-vermeil/page/4/"
#     page_title: "Yellow &amp; Rose <b>Gold</b> Vermeil Jewellery by Bianca Jones"
#     full_matching_images {
#       url: "https://www.biancajones.co.uk/wp-content/uploads/2015/04/pink-tourm-bracelet-300x300.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/biancajones/product/birthstone-initial-bracelet-in-yellow-or-rose-gold"
#     page_title: "birthstone initial bracelet in yellow <b>gold</b> vermeil by bianca jones ..."
#     partial_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/f6/0b/6b23-9cd3-49ca-8f3c-27ee60231c87/preview_birthstone-initial-bracelet-in-yellow-or-rose-gold.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/partners/biancajones/products"
#     page_title: "bianca jones jewellery - products | notonthehighstreet.com"
#     partial_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/f6/0b/6b23-9cd3-49ca-8f3c-27ee60231c87/preview_birthstone-initial-bracelet-in-yellow-or-rose-gold.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.biancajones.co.uk/personalised-jewellery/jewellery/bracelets/page/2/"
#     page_title: "Bracelets to Personalise with Initials or coordinates Bianca Jones ..."
#     full_matching_images {
#       url: "https://www.biancajones.co.uk/wp-content/uploads/2015/04/pink-tourm-bracelet-300x300.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.shopstyle.co.uk/browse?fts=gold+belcher+bracelet"
#     page_title: "<b>Gold</b> Belcher Bracelet - ShopStyle UK"
#     full_matching_images {
#       url: "https://img.shopstyle-cdn.com/pim/1d/8e/1d8ed3be266fd9c5624ae8a449b697cb_xlarge.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.shopstyle.co.uk/browse?fts=hand+ring+bracelet+chain"
#     page_title: "Hand Ring Bracelet Chain - ShopStyle UK"
#     full_matching_images {
#       url: "https://img.shopstyle-cdn.com/pim/1d/8e/1d8ed3be266fd9c5624ae8a449b697cb_xlarge.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://sc02.alicdn.com/kf/HTB13D9CNpXXXXbXXXXXq6xXFXXXU/hoodies-cord-with-metal-tips-Custom-Colored.jpg_640x640xz.jpg"
#   }
#   visually_similar_images {
#     url: "https://images-na.ssl-images-amazon.com/images/I/41OIAPXOX1L._SX395_.jpg"
#   }
#   visually_similar_images {
#     url: "https://content.propertyroom.com/listings/sellers/seller1/images/origimgs/jewelry-box-with-roses-and-gold-colored-detailing-1_21620182055352791451.jpg"
#   }
#   visually_similar_images {
#     url: "https://archaiccomic.com/r/2018/07/yellow-gold-diamond-stud-earrings-color-tcw-colored-sku-tiny-nose-crystal-tungsten-wedding-bands-black-engagement-rings-for-her-emerald-drop-pearl-opal-necklace-white-swarovski-150x150.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.ebayimg.com/thumbs/images/g/arYAAOSwD31awGEz/s-l225.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.ebayimg.com/thumbs/images/g/NiQAAOSwQPlV~LIO/s-l225.jpg"
#   }
#   visually_similar_images {
#     url: "https://di2ponv0v5otw.cloudfront.net/posts/2018/05/14/5af9d0946bf5a6492e8407ea/s_5af9d0c41dffda5537ff01c7.jpg"
#   }
#   visually_similar_images {
#     url: "https://images.gunsinternational.com/listings_sub/acc_72668/gi_100640757/Dakota-Arms-Model-76-African-404-Dakota-Upgraded-Stock-Engraved-Gold-Inlaid-Case-Colored-Talley-Ring_100640757_72668_2A5A1B0C69153F1E.jpg"
#   }
#   visually_similar_images {
#     url: "http://www.pardiskhazar.com/images/category_22/MSTRDS%20Sunglasses%20Shades%20Mumbo%20Mirror%20in%20gold%20colored%20Category%203%20%20strong%20sunlight%20EVSBRZL.jpg"
#   }
#   visually_similar_images {
#     url: "http://www.155middlebeach.com/image/cache/data/category_7/british-knights-women-sneakers-rigit-mesh-pu-in-gold-colored-product-no-b38378202-br--9949-500x500_0.jpg"
#   }
#   best_guess_labels {
#     label: "Colored gold"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/021w6f"
#     score: 0.7193999886512756
#     description: "Tile"
#   }
#   web_entities {
#     entity_id: "/m/01x5q"
#     score: 0.6675000190734863
#     description: "Ceramic"
#   }
#   web_entities {
#     entity_id: "/m/0jjw"
#     score: 0.5702000260353088
#     description: "Art"
#   }
#   web_entities {
#     entity_id: "/m/081hv"
#     score: 0.564300000667572
#     description: "Wedding"
#   }
#   web_entities {
#     entity_id: "/m/02f6b9"
#     score: 0.5069000124931335
#     description: "Anniversary"
#   }
#   web_entities {
#     entity_id: "/m/01rg3p"
#     score: 0.506600022315979
#     description: "Easel"
#   }
#   web_entities {
#     entity_id: "/m/05wkw"
#     score: 0.4837999939918518
#     description: "Photography"
#   }
#   web_entities {
#     entity_id: "/m/02yk19"
#     score: 0.46129998564720154
#     description: "Wedding anniversary"
#   }
#   web_entities {
#     entity_id: "/m/06gjp9"
#     score: 0.44609999656677246
#     description: "Floral design"
#   }
#   web_entities {
#     entity_id: "/m/0l7_8"
#     score: 0.41040000319480896
#     description: "Floor"
#   }
#   full_matching_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317036128_nmzq_2048x.jpg?v=1522222148"
#   }
#   full_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#   }
#   full_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/preview_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#   }
#   partial_matching_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_2048x.jpg?v=1522411471"
#   }
#   partial_matching_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317037640_c8hi_2048x.jpg?v=1522411471"
#   }
#   partial_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/18/43/f3d8-20b5-4557-ae5b-65dfb3ee4a6c/original_floral-wreath-personalised-wedding-framed-tile.jpg"
#   }
#   partial_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/2a/70/80d4-fcdc-4d53-9762-a4ce92f0b0ff/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#   }
#   partial_matching_images {
#     url: "http://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_600x.jpg?v=1522411471"
#   }
#   partial_matching_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317037640_c8hi_400x400.jpg?v=1522411471"
#   }
#   partial_matching_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_400x400.jpg?v=1522411471"
#   }
#   partial_matching_images {
#     url: "https://i.etsystatic.com/14557558/d/il/185ab1/1317036128/il_340x270.1317036128_nmzq.jpg?version=0"
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/hendogdesigns/product/personalised-boys-alphabet-picture-on-a-framed-tile"
#     page_title: "boys alphabet illustration <b>tile</b> on <b>easel or framed</b> by hendog designs ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#     }
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/preview_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#     }
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/2a/70/80d4-fcdc-4d53-9762-a4ce92f0b0ff/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/hendogdesigns/product/floral-wreath-personalised-wedding-framed-tile"
#     page_title: "floral wreath <b>personalised wedding tile easel or framed</b> by hendog ..."
#     partial_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/18/43/f3d8-20b5-4557-ae5b-65dfb3ee4a6c/original_floral-wreath-personalised-wedding-framed-tile.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://hendogdesigns.co.uk/products/anniversary-gift-floral-wreath-gift-for-couple-personalised-anniversary-gift-tile-on-easel-or-framed-ruby-wedding-golden-wedding"
#     page_title: "<b>Anniversary</b> Floral Wreath <b>Tile</b> - Oak <b>Easel or Framed</b> - Hendog ..."
#     partial_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317037640_c8hi_2048x.jpg?v=1522411471"
#     }
#     partial_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_400x400.jpg?v=1522411471"
#     }
#     partial_matching_images {
#       url: "http://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_600x.jpg?v=1522411471"
#     }
#     partial_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317037640_c8hi_400x400.jpg?v=1522411471"
#     }
#     partial_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_2048x.jpg?v=1522411471"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://hendogdesigns.co.uk/products/boys-alphabet-personalised-name-tile-boys-name-tile-on-easel-or-framed-animal-picture-gift-for-him-boys-birthday-kids-art"
#     page_title: "BOYS Alphabet <b>Personalised</b> Name <b>Tile</b> - <b>Framed</b> or Oak <b>Easel</b> ..."
#     full_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317037640_c8hi_2048x.jpg?v=1522411471"
#     }
#     full_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317036128_nmzq_2048x.jpg?v=1522222148"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/uk/listing/519205564/girls-alphabet-personalised-name-tile"
#     page_title: "GIRLS Alphabet <b>Personalised</b> Name <b>Tile</b> Girls Name <b>Tile</b> on - Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/14557558/d/il/185ab1/1317036128/il_340x270.1317036128_nmzq.jpg?version=0"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/uk/market/ceramic_initials"
#     page_title: "Ceramic initials | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/14557558/d/il/185ab1/1317036128/il_340x270.1317036128_nmzq.jpg?version=0"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://www.ceiimage.org/framed-alphabet-picture/"
#     page_title: "<b>Framed</b> Alphabet Picture - Best Of Alphabet Ceiimage.Org"
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://allstarma.net/alphabet-ceramic-tiles"
#     page_title: "Alphabet Ceramic <b>Tiles</b> Image collections - modern <b>tile</b> texture ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317032760_frg5_580x@2x.jpg?v=1522222160"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/18/43/f3d8-20b5-4557-ae5b-65dfb3ee4a6c/original_floral-wreath-personalised-wedding-framed-tile.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/b1/d9/adf7-9d71-4f7e-ae1a-ade5cf52e86b/original_floral-wreath-personalised-wedding-framed-tile.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/5b/6e/e1b8-c2be-4c4a-a2fb-0e52da6028d8/original_wedding-anniversary-personalised-framed-tile-picture.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/b5/1d/95a6-d158-464b-aca5-9e4f118264eb/original_wedding-anniversary-personalised-framed-tile-picture.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/FullSizeRender_-_Copy_12_2048x.jpg?v=1522411471"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/36/a7/42c1-b912-4950-9e6b-c565061cad84/original_floral-wreath-personalised-wedding-framed-tile.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.pinimg.com/736x/eb/c7/fd/ebc7fd6013be0185b72d91cce9dc256f--scrabble-crafts-scrabble-letters.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/a1/26/2545-e362-4d51-8b4a-d01623ef1250/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/Photo_24-05-2017_14_18_05_2048x.jpg?v=1522404636"
#   }
#   best_guess_labels {
#     label: "wedding anniversary personalised tile easel or framed"
#     language_code: "en"
#   }
# }
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
df_10k_random_
# Out:
#                                                  url  \
# 0  https://assets-notonthehighstreet-com.s3.amazo...
# 1  https://assets-notonthehighstreet-com.s3.amazo...
# 2  https://assets-notonthehighstreet-com.s3.amazo...
# 3  https://assets-notonthehighstreet-com.s3.amazo...
# 4  https://assets-notonthehighstreet-com.s3.amazo...
# 5  https://assets-notonthehighstreet-com.s3.amazo...
# 6  https://assets-notonthehighstreet-com.s3.amazo...
# 7  https://assets-notonthehighstreet-com.s3.amazo...
# 8  https://assets-notonthehighstreet-com.s3.amazo...
# 9  https://assets-notonthehighstreet-com.s3.amazo...
#
#                                       image_property  \
# 0  {'imagePropertiesAnnotation': {'dominantColors...
# 1  {'imagePropertiesAnnotation': {'dominantColors...
# 2  {'imagePropertiesAnnotation': {'dominantColors...
# 3  {'imagePropertiesAnnotation': {'dominantColors...
# 4  {'imagePropertiesAnnotation': {'dominantColors...
# 5  {'imagePropertiesAnnotation': {'dominantColors...
# 6  {'imagePropertiesAnnotation': {'dominantColors...
# 7  {'imagePropertiesAnnotation': {'dominantColors...
# 8  {'imagePropertiesAnnotation': {'dominantColors...
# 9  {'imagePropertiesAnnotation': {'dominantColors...
#
#                                        web_detection  \
# 0  {'webDetection': {'webEntities': [{'entityId':...
# 1  {'webDetection': {'webEntities': [{'entityId':...
# 2  {'webDetection': {'webEntities': [{'entityId':...
# 3  {'webDetection': {'webEntities': [{'entityId':...
# 4  {'webDetection': {'webEntities': [{'entityId':...
# 5  {'webDetection': {'webEntities': [{'entityId':...
# 6  {'webDetection': {'webEntities': [{'entityId':...
# 7  {'webDetection': {'webEntities': [{'entityId':...
# 8  {'webDetection': {'webEntities': [{'entityId':...
# 9  {'webDetection': {'webEntities': [{'entityId':...
#
#                                           web_entity
# 0  [{'entityId': '/m/01h3n', 'score': 0.776250004...
# 1  [{'entityId': '/m/03lnq3', 'score': 0.89781475...
# 2  [{'entityId': '/m/0lbxg', 'score': 0.702400028...
# 3  [{'entityId': '/m/05fc9mj', 'score': 0.8762999...
# 4  [{'entityId': '/m/01jwgf', 'score': 0.47429999...
# 5  [{'entityId': '/m/027_ny3', 'score': 0.3996879...
# 6  [{'entityId': '/m/0174g1', 'score': 0.70499998...
# 7  [{'entityId': '/m/01llwg', 'score': 0.79987418...
# 8  [{'entityId': '/m/01llx7', 'score': 0.88950002...
# 9  [{'entityId': '/m/021w6f', 'score': 0.71939998...

# %%
df_10k_random_.iloc[0]
# Out:
# url               https://assets-notonthehighstreet-com.s3.amazo...
# image_property    {'imagePropertiesAnnotation': {'dominantColors...
# web_detection     {'webDetection': {'webEntities': [{'entityId':...
# web_entity        [{'entityId': '/m/01h3n', 'score': 0.776250004...
# Name: 0, dtype: object

# %%
df_10k_random_.iloc[0]['url']
# Out:
# 'https://assets-notonthehighstreet-com.s3.amazonaws.com/fs/af/b0/65f6-1dbc-41d1-8146-54e7353aa2aa/normal_christmas-nail-art-stickers.jpg'

# %%
df_10k_random_.iloc[0]['web_entity']
# Out:
# [{'description': 'Bee', 'entityId': '/m/01h3n', 'score': 0.7762500047683716},
#  {'description': 'Nail', 'entityId': '/m/023j4r', 'score': 0.7027000188827515},
#  {'description': 'Nail art',
#   'entityId': '/m/0zdksk1',
#   'score': 0.5293999910354614},
#  {'description': 'Decal',
#   'entityId': '/m/0204p6',
#   'score': 0.43650001287460327},
#  {'entityId': '/t/24mypdx4svpvn', 'score': 0.4174000024795532},
#  {'description': 'Sticker',
#   'entityId': '/m/05b97g',
#   'score': 0.33239999413490295},
#  {'description': 'Honey bee',
#   'entityId': '/m/0fz0z',
#   'score': 0.3203999996185303},
#  {'entityId': '/m/0rzp91s', 'score': 0.31450000405311584},
#  {'description': 'Nail Art-Cards',
#   'entityId': '/g/11gh3gv56b',
#   'score': 0.2946999967098236},
#  {'entityId': '/t/2559cfx2jwyf6', 'score': 0.2653000056743622}]

# %%
xx = df_10k_random_.iloc[0]['web_entity']
xx
# Out:
# [{'description': 'Bee', 'entityId': '/m/01h3n', 'score': 0.7762500047683716},
#  {'description': 'Nail', 'entityId': '/m/023j4r', 'score': 0.7027000188827515},
#  {'description': 'Nail art',
#   'entityId': '/m/0zdksk1',
#   'score': 0.5293999910354614},
#  {'description': 'Decal',
#   'entityId': '/m/0204p6',
#   'score': 0.43650001287460327},
#  {'entityId': '/t/24mypdx4svpvn', 'score': 0.4174000024795532},
#  {'description': 'Sticker',
#   'entityId': '/m/05b97g',
#   'score': 0.33239999413490295},
#  {'description': 'Honey bee',
#   'entityId': '/m/0fz0z',
#   'score': 0.3203999996185303},
#  {'entityId': '/m/0rzp91s', 'score': 0.31450000405311584},
#  {'description': 'Nail Art-Cards',
#   'entityId': '/g/11gh3gv56b',
#   'score': 0.2946999967098236},
#  {'entityId': '/t/2559cfx2jwyf6', 'score': 0.2653000056743622}]

# %%
df_xx = pd.DataFrame(xx)
df_xx['']
# Out:
#       description          entityId    score
# 0             Bee          /m/01h3n  0.77625
# 1            Nail         /m/023j4r  0.70270
# 2        Nail art        /m/0zdksk1  0.52940
# 3           Decal         /m/0204p6  0.43650
# 4             NaN  /t/24mypdx4svpvn  0.41740
# 5         Sticker         /m/05b97g  0.33240
# 6       Honey bee          /m/0fz0z  0.32040
# 7             NaN        /m/0rzp91s  0.31450
# 8  Nail Art-Cards     /g/11gh3gv56b  0.29470
# 9             NaN  /t/2559cfx2jwyf6  0.26530

# %%
# convert web_entity to df 

url_ = df_10k_random_.iloc[0]['url']
df_web_entity = pd.DataFrame(df_10k_random_.iloc[0]['web_entity'])
df_web_entity['url'] = url_

# merge 

df_10k_random_merge = pd.merge(df_10k_random_, df_web_entity,  how='left', left_on=['url'], right_on=['url'])

# %%
df_10k_random_
# Out:
#                                                  url  \
# 0  https://assets-notonthehighstreet-com.s3.amazo...
# 1  https://assets-notonthehighstreet-com.s3.amazo...
# 2  https://assets-notonthehighstreet-com.s3.amazo...
# 3  https://assets-notonthehighstreet-com.s3.amazo...
# 4  https://assets-notonthehighstreet-com.s3.amazo...
# 5  https://assets-notonthehighstreet-com.s3.amazo...
# 6  https://assets-notonthehighstreet-com.s3.amazo...
# 7  https://assets-notonthehighstreet-com.s3.amazo...
# 8  https://assets-notonthehighstreet-com.s3.amazo...
# 9  https://assets-notonthehighstreet-com.s3.amazo...
#
#                                       image_property  \
# 0  {'imagePropertiesAnnotation': {'dominantColors...
# 1  {'imagePropertiesAnnotation': {'dominantColors...
# 2  {'imagePropertiesAnnotation': {'dominantColors...
# 3  {'imagePropertiesAnnotation': {'dominantColors...
# 4  {'imagePropertiesAnnotation': {'dominantColors...
# 5  {'imagePropertiesAnnotation': {'dominantColors...
# 6  {'imagePropertiesAnnotation': {'dominantColors...
# 7  {'imagePropertiesAnnotation': {'dominantColors...
# 8  {'imagePropertiesAnnotation': {'dominantColors...
# 9  {'imagePropertiesAnnotation': {'dominantColors...
#
#                                        web_detection  \
# 0  {'webDetection': {'webEntities': [{'entityId':...
# 1  {'webDetection': {'webEntities': [{'entityId':...
# 2  {'webDetection': {'webEntities': [{'entityId':...
# 3  {'webDetection': {'webEntities': [{'entityId':...
# 4  {'webDetection': {'webEntities': [{'entityId':...
# 5  {'webDetection': {'webEntities': [{'entityId':...
# 6  {'webDetection': {'webEntities': [{'entityId':...
# 7  {'webDetection': {'webEntities': [{'entityId':...
# 8  {'webDetection': {'webEntities': [{'entityId':...
# 9  {'webDetection': {'webEntities': [{'entityId':...
#
#                                           web_entity
# 0  [{'entityId': '/m/01h3n', 'score': 0.776250004...
# 1  [{'entityId': '/m/03lnq3', 'score': 0.89781475...
# 2  [{'entityId': '/m/0lbxg', 'score': 0.702400028...
# 3  [{'entityId': '/m/05fc9mj', 'score': 0.8762999...
# 4  [{'entityId': '/m/01jwgf', 'score': 0.47429999...
# 5  [{'entityId': '/m/027_ny3', 'score': 0.3996879...
# 6  [{'entityId': '/m/0174g1', 'score': 0.70499998...
# 7  [{'entityId': '/m/01llwg', 'score': 0.79987418...
# 8  [{'entityId': '/m/01llx7', 'score': 0.88950002...
# 9  [{'entityId': '/m/021w6f', 'score': 0.71939998...

# %%
# convert web_entity to df 
"""
url_ = df_10k_random_.iloc[0]['url']
df_web_entity = pd.DataFrame(df_10k_random_.iloc[0]['web_entity'])
df_web_entity['url'] = url_

# merge 

df_10k_random_merge = pd.merge(df_10k_random_, df_web_entity,  how='left', left_on=['url'], right_on=['url'])
"""
# Out:
# "\nurl_ = df_10k_random_.iloc[0]['url']\ndf_web_entity = pd.DataFrame(df_10k_random_.iloc[0]['web_entity'])\ndf_web_entity['url'] = url_\n\n# merge \n\ndf_10k_random_merge = pd.merge(df_10k_random_, df_web_entity,  how='left', left_on=['url'], right_on=['url'])\n"

# %%
pd.DataFrame(df_10k_random_.iloc[0]['web_entity'])
# Out:
#       description          entityId    score
# 0             Bee          /m/01h3n  0.77625
# 1            Nail         /m/023j4r  0.70270
# 2        Nail art        /m/0zdksk1  0.52940
# 3           Decal         /m/0204p6  0.43650
# 4             NaN  /t/24mypdx4svpvn  0.41740
# 5         Sticker         /m/05b97g  0.33240
# 6       Honey bee          /m/0fz0z  0.32040
# 7             NaN        /m/0rzp91s  0.31450
# 8  Nail Art-Cards     /g/11gh3gv56b  0.29470
# 9             NaN  /t/2559cfx2jwyf6  0.26530

# %%
frame = pd.DataFrame()

# %%
# convert web_entity to df 
frame = pd.DataFrame()
list_ = []

#for i in range(5):
for i in range(len(df_10k_random_)):
  url_ = df_10k_random_.iloc[i]['url']
  df_web_entity = pd.DataFrame(df_10k_random_.iloc[i]['web_entity'])
  df_web_entity['url'] = url_
  # merge 
  df_10k_random_merge = pd.merge(df_10k_random_, df_web_entity,  how='inner', left_on=['url'], right_on=['url'])
  list_.append(df_10k_random_merge)
frame = pd.concat(list_)
frame = frame.reset_index()

# %%
frame.url.value_counts()
# Out:
# https://assets-notonthehighstreet-com.s3.amazonaws.com/fs/f6/0b/6b23-9cd3-49ca-8f3c-27ee60231c87/normal_birthstone-initial-bracelet-in-yellow-or-rose-gold.jpg       10
# https://assets-notonthehighstreet-com.s3.amazonaws.com/fs/c5/aa/f3d9-e372-49be-a912-a0c8c1535dad/normal_raindrop-umbrella-cushion.jpg                                10
# https://assets-notonthehighstreet-com.s3.amazonaws.com/fs/b6/de/76f0-3a58-4ca6-908e-83668d86379d/normal_on-top-of-the-world-mountain-bike-screen-print.jpg           10
# https://assets-notonthehighstreet-com.s3.amazonaws.com/fs/63/98/0063-8e6a-4d45-b6f5-784e39451915/normal_days-together-personalised-wooden-keyring.jpg                10
# https://assets-notonthehighstreet-com.s3.amazonaws.com/fs/b5/33/2821-187e-4e25-93e3-3c4082c16d50/normal_london-coasters.jpg                                          10
# https://assets-notonthehighstreet-com.s3.amazonaws.com/fs/24/9c/845a-9bba-41da-addb-fe9f1f3a1bef/normal_druzy-triangle-gold-necklace.jpg                             10
# https://assets-notonthehighstreet-com.s3.amazonaws.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/normal_first-my-father-s-day-card.jpg                               10
# https://assets-notonthehighstreet-com.s3.amazonaws.com/fs/af/b0/65f6-1dbc-41d1-8146-54e7353aa2aa/normal_christmas-nail-art-stickers.jpg                              10
# https://assets-notonthehighstreet-com.s3.amazonaws.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/normal_personalised-boys-alphabet-picture-on-a-framed-tile.jpg      10
# https://assets-notonthehighstreet-com.s3.amazonaws.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/normal_large-wooden-acorn-and-pinecone-christmas-decorations.jpg    10
# Name: url, dtype: int64

# %%
frame.iloc[99]['web_entity']
# Out:
# [{'description': 'Tile', 'entityId': '/m/021w6f', 'score': 0.7193999886512756},
#  {'description': 'Ceramic',
#   'entityId': '/m/01x5q',
#   'score': 0.6675000190734863},
#  {'description': 'Art', 'entityId': '/m/0jjw', 'score': 0.5702000260353088},
#  {'description': 'Wedding',
#   'entityId': '/m/081hv',
#   'score': 0.564300000667572},
#  {'description': 'Anniversary',
#   'entityId': '/m/02f6b9',
#   'score': 0.5069000124931335},
#  {'description': 'Easel', 'entityId': '/m/01rg3p', 'score': 0.506600022315979},
#  {'description': 'Photography',
#   'entityId': '/m/05wkw',
#   'score': 0.4837999939918518},
#  {'description': 'Wedding anniversary',
#   'entityId': '/m/02yk19',
#   'score': 0.46129998564720154},
#  {'description': 'Floral design',
#   'entityId': '/m/06gjp9',
#   'score': 0.44609999656677246},
#  {'description': 'Floor',
#   'entityId': '/m/0l7_8',
#   'score': 0.41040000319480896}]

# %%
frame[frame.url == frame.iloc[99]['url'] ].reset_index()
# Out:
#    level_0  index                                                url  \
# 0       90      0  https://assets-notonthehighstreet-com.s3.amazo...
# 1       91      1  https://assets-notonthehighstreet-com.s3.amazo...
# 2       92      2  https://assets-notonthehighstreet-com.s3.amazo...
# 3       93      3  https://assets-notonthehighstreet-com.s3.amazo...
# 4       94      4  https://assets-notonthehighstreet-com.s3.amazo...
# 5       95      5  https://assets-notonthehighstreet-com.s3.amazo...
# 6       96      6  https://assets-notonthehighstreet-com.s3.amazo...
# 7       97      7  https://assets-notonthehighstreet-com.s3.amazo...
# 8       98      8  https://assets-notonthehighstreet-com.s3.amazo...
# 9       99      9  https://assets-notonthehighstreet-com.s3.amazo...
#
#                                       image_property  \
# 0  {'imagePropertiesAnnotation': {'dominantColors...
# 1  {'imagePropertiesAnnotation': {'dominantColors...
# 2  {'imagePropertiesAnnotation': {'dominantColors...
# 3  {'imagePropertiesAnnotation': {'dominantColors...
# 4  {'imagePropertiesAnnotation': {'dominantColors...
# 5  {'imagePropertiesAnnotation': {'dominantColors...
# 6  {'imagePropertiesAnnotation': {'dominantColors...
# 7  {'imagePropertiesAnnotation': {'dominantColors...
# 8  {'imagePropertiesAnnotation': {'dominantColors...
# 9  {'imagePropertiesAnnotation': {'dominantColors...
#
#                                        web_detection  \
# 0  {'webDetection': {'webEntities': [{'entityId':...
# 1  {'webDetection': {'webEntities': [{'entityId':...
# 2  {'webDetection': {'webEntities': [{'entityId':...
# 3  {'webDetection': {'webEntities': [{'entityId':...
# 4  {'webDetection': {'webEntities': [{'entityId':...
# 5  {'webDetection': {'webEntities': [{'entityId':...
# 6  {'webDetection': {'webEntities': [{'entityId':...
# 7  {'webDetection': {'webEntities': [{'entityId':...
# 8  {'webDetection': {'webEntities': [{'entityId':...
# 9  {'webDetection': {'webEntities': [{'entityId':...
#
#                                           web_entity          description  \
# 0  [{'entityId': '/m/021w6f', 'score': 0.71939998...                 Tile
# 1  [{'entityId': '/m/021w6f', 'score': 0.71939998...              Ceramic
# 2  [{'entityId': '/m/021w6f', 'score': 0.71939998...                  Art
# 3  [{'entityId': '/m/021w6f', 'score': 0.71939998...              Wedding
# 4  [{'entityId': '/m/021w6f', 'score': 0.71939998...          Anniversary
# 5  [{'entityId': '/m/021w6f', 'score': 0.71939998...                Easel
# 6  [{'entityId': '/m/021w6f', 'score': 0.71939998...          Photography
# 7  [{'entityId': '/m/021w6f', 'score': 0.71939998...  Wedding anniversary
# 8  [{'entityId': '/m/021w6f', 'score': 0.71939998...        Floral design
# 9  [{'entityId': '/m/021w6f', 'score': 0.71939998...                Floor
#
#     entityId   score
# 0  /m/021w6f  0.7194
# 1   /m/01x5q  0.6675
# 2    /m/0jjw  0.5702
# 3   /m/081hv  0.5643
# 4  /m/02f6b9  0.5069
# 5  /m/01rg3p  0.5066
# 6   /m/05wkw  0.4838
# 7  /m/02yk19  0.4613
# 8  /m/06gjp9  0.4461
# 9   /m/0l7_8  0.4104
