# %%
# python 3 

# gcloud 
from google.cloud import vision
from google.oauth2 import service_account
from google.protobuf.json_format import MessageToDict

# OP 
import pandas as pd 
import numpy as np 

#--------------------------------------------------
# config 
# save ur google cloud credentials below
credentials = service_account.Credentials.from_service_account_file('/Users/yennanliu/Downloads/google_cloud_creds2.json')
client = vision.ImageAnnotatorClient(credentials=credentials)

# %%
# help func 

"""
# https://cloud.google.com/vision/docs/other-features

1) Image properties : vision.enums.Feature.Type.IMAGE_PROPERTIES
2) Web entities : vision.enums.Feature.Type.WEB_DETECTION
3) Safe search :  vision.enums.Feature.Type.SAFE_SEARCH_DETECTION

"""



def call_google_image_api(url,type):
    response = client.annotate_image({
    'image': {'source': {'image_uri': url}},
    'features': [{'type': type}],})
    print ('response : ', response)
    response_dict = MessageToDict(response)
    return response_dict



def g_face_detection(url):
    response = client.annotate_image({
    'image': {'source': {'image_uri': url}},
    'features': [{'type': vision.enums.Feature.Type.FACE_DETECTION}],})
    print ('response : ', response)
    response_dict = MessageToDict(response)
    return response_dict


def g_image_property(url):
    response = client.annotate_image({
    'image': {'source': {'image_uri': url}},
    'features': [{'type': vision.enums.Feature.Type.IMAGE_PROPERTIES}],})
    print ('response : ', response)
    response_dict = MessageToDict(response)
    return response_dict
  
  
def g_web_detection(url):
    response = client.annotate_image({
    'image': {'source': {'image_uri': url}},
    'features': [{'type': vision.enums.Feature.Type.WEB_DETECTION}],})
    print ('response : ', response)
    response_dict = MessageToDict(response)
    return response_dict




def call_google_handwritten_api(uri):

    from google.cloud import vision_v1p3beta1 as vision
    credentials = service_account.Credentials.from_service_account_file('google_cloud_creds2.json')
    
    
    client = vision.ImageAnnotatorClient(credentials=credentials)
    image = vision.types.Image()
    image.source.image_uri = uri

    # Language hint codes for handwritten OCR:
    # en-t-i0-handwrit, mul-Latn-t-i0-handwrit
    # Note: Use only one language hint code per request for handwritten OCR.
    image_context = vision.types.ImageContext(
        language_hints=['en-t-i0-handwrit'])

    response = client.document_text_detection(image=image,
                                              image_context=image_context)

    print('Full Text: {}'.format(response.full_text_annotation.text))
    for page in response.full_text_annotation.pages:
        for block in page.blocks:
            print('\nBlock confidence: {}\n'.format(block.confidence))

            for paragraph in block.paragraphs:
                print('Paragraph confidence: {}'.format(
                    paragraph.confidence))

                for word in paragraph.words:
                    word_text = ''.join([
                        symbol.text for symbol in word.symbols
                    ])
                    print('Word text: {} (confidence: {})'.format(
                        word_text, word.confidence))

                    for symbol in word.symbols:
                        print('\tSymbol: {} (confidence: {})'.format(
                            symbol.text, symbol.confidence))


#--------------------------------------------------



def get_web_entity(web_property_response):
  # in case some requesr got null response  
  try:
    return [i for i in web_property_response['webDetection']['webEntities'] ]
  except:
    return []

# %%
df_10k_random = pd.read_csv('/Users/yennanliu/Downloads/random_10K_image_urls_fixed.csv')

# %%
df_10k_random.head(3)
# Out:
#                                                  url
# 0  https://assets-notonthehighstreet-com.s3.amazo...
# 1  https://assets-notonthehighstreet-com.s3.amazo...
# 2  https://assets-notonthehighstreet-com.s3.amazo...

# %%
# sample data 
df_10k_random_ = df_10k_random.head(10)

# query google vision api 
df_10k_random_['image_property'] = df_10k_random_['url'].apply(lambda x : g_image_property(x))
df_10k_random_['web_detection'] = df_10k_random_['url'].apply(lambda x : g_web_detection(x))
# extract web entity information 
df_10k_random_['web_entity'] = df_10k_random_['web_detection'].apply(lambda x : get_web_entity(x))
# Out:
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 166.0
#         green: 162.0
#         blue: 153.0
#       }
#       score: 0.34678566455841064
#       pixel_fraction: 0.18145833909511566
#     }
#     colors {
#       color {
#         red: 64.0
#         green: 96.0
#         blue: 68.0
#       }
#       score: 0.03624964505434036
#       pixel_fraction: 0.006527777761220932
#     }
#     colors {
#       color {
#         red: 171.0
#         green: 163.0
#         blue: 146.0
#       }
#       score: 0.15224076807498932
#       pixel_fraction: 0.07777778059244156
#     }
#     colors {
#       color {
#         red: 186.0
#         green: 185.0
#         blue: 179.0
#       }
#       score: 0.07636457681655884
#       pixel_fraction: 0.12479166686534882
#     }
#     colors {
#       color {
#         red: 121.0
#         green: 120.0
#         blue: 114.0
#       }
#       score: 0.04679257050156593
#       pixel_fraction: 0.03187499940395355
#     }
#     colors {
#       color {
#         red: 86.0
#         green: 85.0
#         blue: 78.0
#       }
#       score: 0.04497827589511871
#       pixel_fraction: 0.027361111715435982
#     }
#     colors {
#       color {
#         red: 56.0
#         green: 54.0
#         blue: 49.0
#       }
#       score: 0.033778201788663864
#       pixel_fraction: 0.022638889029622078
#     }
#     colors {
#       color {
#         red: 219.0
#         green: 234.0
#         blue: 236.0
#       }
#       score: 0.0325448103249073
#       pixel_fraction: 0.32034721970558167
#     }
#     colors {
#       color {
#         red: 64.0
#         green: 92.0
#         blue: 79.0
#       }
#       score: 0.02984190359711647
#       pixel_fraction: 0.013680555857717991
#     }
#     colors {
#       color {
#         red: 94.0
#         green: 125.0
#         blue: 95.0
#       }
#       score: 0.02679683081805706
#       pixel_fraction: 0.0036805556155741215
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 185.0
#         green: 158.0
#         blue: 139.0
#       }
#       score: 0.20225070416927338
#       pixel_fraction: 0.05693277344107628
#     }
#     colors {
#       color {
#         red: 185.0
#         green: 149.0
#         blue: 148.0
#       }
#       score: 0.14666655659675598
#       pixel_fraction: 0.053011205047369
#     }
#     colors {
#       color {
#         red: 205.0
#         green: 177.0
#         blue: 157.0
#       }
#       score: 0.1768627166748047
#       pixel_fraction: 0.05406162515282631
#     }
#     colors {
#       color {
#         red: 183.0
#         green: 148.0
#         blue: 136.0
#       }
#       score: 0.08781303465366364
#       pixel_fraction: 0.02710084058344364
#     }
#     colors {
#       color {
#         red: 215.0
#         green: 181.0
#         blue: 181.0
#       }
#       score: 0.0709015280008316
#       pixel_fraction: 0.08592437207698822
#     }
#     colors {
#       color {
#         red: 153.0
#         green: 116.0
#         blue: 106.0
#       }
#       score: 0.053304221481084824
#       pixel_fraction: 0.012675070203840733
#     }
#     colors {
#       color {
#         red: 142.0
#         green: 115.0
#         blue: 96.0
#       }
#       score: 0.046419478952884674
#       pixel_fraction: 0.008473389782011509
#     }
#     colors {
#       color {
#         red: 205.0
#         green: 187.0
#         blue: 182.0
#       }
#       score: 0.0424998439848423
#       pixel_fraction: 0.147198885679245
#     }
#     colors {
#       color {
#         red: 152.0
#         green: 114.0
#         blue: 113.0
#       }
#       score: 0.037489090114831924
#       pixel_fraction: 0.008543417789041996
#     }
#     colors {
#       color {
#         red: 172.0
#         green: 154.0
#         blue: 149.0
#       }
#       score: 0.03423192352056503
#       pixel_fraction: 0.39523810148239136
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 347
#       }
#       vertices {
#         y: 347
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 223.0
#         green: 200.0
#         blue: 175.0
#       }
#       score: 0.3367827832698822
#       pixel_fraction: 0.050208333879709244
#     }
#     colors {
#       color {
#         red: 235.0
#         green: 230.0
#         blue: 227.0
#       }
#       score: 0.24570441246032715
#       pixel_fraction: 0.7167361378669739
#     }
#     colors {
#       color {
#         red: 59.0
#         green: 51.0
#         blue: 48.0
#       }
#       score: 0.035400308668613434
#       pixel_fraction: 0.012569444254040718
#     }
#     colors {
#       color {
#         red: 128.0
#         green: 74.0
#         blue: 58.0
#       }
#       score: 0.018277309834957123
#       pixel_fraction: 0.005625000223517418
#     }
#     colors {
#       color {
#         red: 101.0
#         green: 30.0
#         blue: 15.0
#       }
#       score: 0.007512776646763086
#       pixel_fraction: 0.0011111111380159855
#     }
#     colors {
#       color {
#         red: 203.0
#         green: 198.0
#         blue: 195.0
#       }
#       score: 0.1252969205379486
#       pixel_fraction: 0.0637499988079071
#     }
#     colors {
#       color {
#         red: 233.0
#         green: 214.0
#         blue: 193.0
#       }
#       score: 0.057471953332424164
#       pixel_fraction: 0.01354166679084301
#     }
#     colors {
#       color {
#         red: 159.0
#         green: 152.0
#         blue: 148.0
#       }
#       score: 0.03064323030412197
#       pixel_fraction: 0.017569445073604584
#     }
#     colors {
#       color {
#         red: 125.0
#         green: 117.0
#         blue: 113.0
#       }
#       score: 0.024925008416175842
#       pixel_fraction: 0.011388888582587242
#     }
#     colors {
#       color {
#         red: 90.0
#         green: 82.0
#         blue: 79.0
#       }
#       score: 0.02367486245930195
#       pixel_fraction: 0.011388888582587242
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 233.0
#         green: 233.0
#         blue: 225.0
#       }
#       score: 0.24488899111747742
#       pixel_fraction: 0.06173611059784889
#     }
#     colors {
#       color {
#         red: 24.0
#         green: 24.0
#         blue: 21.0
#       }
#       score: 0.16312621533870697
#       pixel_fraction: 0.09416666626930237
#     }
#     colors {
#       color {
#         red: 118.0
#         green: 118.0
#         blue: 110.0
#       }
#       score: 0.12323987483978271
#       pixel_fraction: 0.048055555671453476
#     }
#     colors {
#       color {
#         red: 199.0
#         green: 197.0
#         blue: 189.0
#       }
#       score: 0.09753844141960144
#       pixel_fraction: 0.031180555000901222
#     }
#     colors {
#       color {
#         red: 86.0
#         green: 85.0
#         blue: 82.0
#       }
#       score: 0.08000663667917252
#       pixel_fraction: 0.3577083349227905
#     }
#     colors {
#       color {
#         red: 50.0
#         green: 49.0
#         blue: 49.0
#       }
#       score: 0.07585982978343964
#       pixel_fraction: 0.3492361009120941
#     }
#     colors {
#       color {
#         red: 158.0
#         green: 156.0
#         blue: 148.0
#       }
#       score: 0.07055202126502991
#       pixel_fraction: 0.027708332985639572
#     }
#     colors {
#       color {
#         red: 161.0
#         green: 154.0
#         blue: 134.0
#       }
#       score: 0.04353611543774605
#       pixel_fraction: 0.00798611156642437
#     }
#     colors {
#       color {
#         red: 129.0
#         green: 122.0
#         blue: 101.0
#       }
#       score: 0.03915640711784363
#       pixel_fraction: 0.009027778171002865
#     }
#     colors {
#       color {
#         red: 200.0
#         green: 192.0
#         blue: 173.0
#       }
#       score: 0.038646649569272995
#       pixel_fraction: 0.0069444444961845875
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 88.0
#         green: 78.0
#         blue: 63.0
#       }
#       score: 0.23351836204528809
#       pixel_fraction: 0.056388888508081436
#     }
#     colors {
#       color {
#         red: 238.0
#         green: 232.0
#         blue: 224.0
#       }
#       score: 0.12677127122879028
#       pixel_fraction: 0.15194444358348846
#     }
#     colors {
#       color {
#         red: 61.0
#         green: 131.0
#         blue: 148.0
#       }
#       score: 0.07057429850101471
#       pixel_fraction: 0.1850000023841858
#     }
#     colors {
#       color {
#         red: 242.0
#         green: 186.0
#         blue: 171.0
#       }
#       score: 0.024975689128041267
#       pixel_fraction: 0.008263888768851757
#     }
#     colors {
#       color {
#         red: 215.0
#         green: 128.0
#         blue: 119.0
#       }
#       score: 0.021891634911298752
#       pixel_fraction: 0.00798611156642437
#     }
#     colors {
#       color {
#         red: 214.0
#         green: 80.0
#         blue: 75.0
#       }
#       score: 0.007168736308813095
#       pixel_fraction: 0.0018055555410683155
#     }
#     colors {
#       color {
#         red: 55.0
#         green: 12.0
#         blue: 7.0
#       }
#       score: 0.0024698786437511444
#       pixel_fraction: 0.00020833333837799728
#     }
#     colors {
#       color {
#         red: 91.0
#         green: 84.0
#         blue: 78.0
#       }
#       score: 0.06569154560565948
#       pixel_fraction: 0.0416666679084301
#     }
#     colors {
#       color {
#         red: 244.0
#         green: 230.0
#         blue: 212.0
#       }
#       score: 0.044551506638526917
#       pixel_fraction: 0.03236111253499985
#     }
#     colors {
#       color {
#         red: 116.0
#         green: 117.0
#         blue: 113.0
#       }
#       score: 0.03481007739901543
#       pixel_fraction: 0.030138889327645302
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 187.0
#         green: 193.0
#         blue: 182.0
#       }
#       score: 0.6079646348953247
#       pixel_fraction: 0.25312501192092896
#     }
#     colors {
#       color {
#         red: 26.0
#         green: 28.0
#         blue: 22.0
#       }
#       score: 0.07017625123262405
#       pixel_fraction: 0.020347222685813904
#     }
#     colors {
#       color {
#         red: 160.0
#         green: 165.0
#         blue: 155.0
#       }
#       score: 0.13731607794761658
#       pixel_fraction: 0.023333333432674408
#     }
#     colors {
#       color {
#         red: 47.0
#         green: 50.0
#         blue: 43.0
#       }
#       score: 0.06748747825622559
#       pixel_fraction: 0.027499999850988388
#     }
#     colors {
#       color {
#         red: 224.0
#         green: 226.0
#         blue: 218.0
#       }
#       score: 0.04223116487264633
#       pixel_fraction: 0.6458333134651184
#     }
#     colors {
#       color {
#         red: 119.0
#         green: 122.0
#         blue: 114.0
#       }
#       score: 0.0421275794506073
#       pixel_fraction: 0.012777777388691902
#     }
#     colors {
#       color {
#         red: 81.0
#         green: 83.0
#         blue: 76.0
#       }
#       score: 0.03269679471850395
#       pixel_fraction: 0.017083333805203438
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 236.0
#         green: 236.0
#         blue: 236.0
#       }
#       score: 0.22615693509578705
#       pixel_fraction: 0.16256944835186005
#     }
#     colors {
#       color {
#         red: 231.0
#         green: 225.0
#         blue: 117.0
#       }
#       score: 0.19691269099712372
#       pixel_fraction: 0.008263888768851757
#     }
#     colors {
#       color {
#         red: 233.0
#         green: 225.0
#         blue: 89.0
#       }
#       score: 0.12496335804462433
#       pixel_fraction: 0.005625000223517418
#     }
#     colors {
#       color {
#         red: 218.0
#         green: 212.0
#         blue: 74.0
#       }
#       score: 0.07311296463012695
#       pixel_fraction: 0.006736110895872116
#     }
#     colors {
#       color {
#         red: 218.0
#         green: 212.0
#         blue: 107.0
#       }
#       score: 0.0704493597149849
#       pixel_fraction: 0.006041666492819786
#     }
#     colors {
#       color {
#         red: 82.0
#         green: 76.0
#         blue: 107.0
#       }
#       score: 0.0004907039692625403
#       pixel_fraction: 0.00013888889225199819
#     }
#     colors {
#       color {
#         red: 236.0
#         green: 232.0
#         blue: 199.0
#       }
#       score: 0.04512206092476845
#       pixel_fraction: 0.007916666567325592
#     }
#     colors {
#       color {
#         red: 234.0
#         green: 225.0
#         blue: 162.0
#       }
#       score: 0.041900139302015305
#       pixel_fraction: 0.003888888983055949
#     }
#     colors {
#       color {
#         red: 226.0
#         green: 227.0
#         blue: 152.0
#       }
#       score: 0.04109867662191391
#       pixel_fraction: 0.0027777778450399637
#     }
#     colors {
#       color {
#         red: 238.0
#         green: 220.0
#         blue: 120.0
#       }
#       score: 0.030980536714196205
#       pixel_fraction: 0.0015277777565643191
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 317
#       }
#       vertices {
#         x: 317
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 0.9899999499320984
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 97.0
#         green: 118.0
#         blue: 166.0
#       }
#       score: 0.19681981205940247
#       pixel_fraction: 0.010347221978008747
#     }
#     colors {
#       color {
#         red: 220.0
#         green: 203.0
#         blue: 149.0
#       }
#       score: 0.07184486091136932
#       pixel_fraction: 0.010833333246409893
#     }
#     colors {
#       color {
#         red: 103.0
#         green: 120.0
#         blue: 156.0
#       }
#       score: 0.16015924513339996
#       pixel_fraction: 0.013194444589316845
#     }
#     colors {
#       color {
#         red: 67.0
#         green: 89.0
#         blue: 136.0
#       }
#       score: 0.14588424563407898
#       pixel_fraction: 0.0071527776308357716
#     }
#     colors {
#       color {
#         red: 130.0
#         green: 148.0
#         blue: 186.0
#       }
#       score: 0.08303681761026382
#       pixel_fraction: 0.007430555764585733
#     }
#     colors {
#       color {
#         red: 212.0
#         green: 200.0
#         blue: 164.0
#       }
#       score: 0.06606760621070862
#       pixel_fraction: 0.028263889253139496
#     }
#     colors {
#       color {
#         red: 123.0
#         green: 144.0
#         blue: 191.0
#       }
#       score: 0.05116792023181915
#       pixel_fraction: 0.0027083333116024733
#     }
#     colors {
#       color {
#         red: 71.0
#         green: 88.0
#         blue: 121.0
#       }
#       score: 0.04582860693335533
#       pixel_fraction: 0.004791666753590107
#     }
#     colors {
#       color {
#         red: 193.0
#         green: 196.0
#         blue: 193.0
#       }
#       score: 0.02846316061913967
#       pixel_fraction: 0.12854166328907013
#     }
#     colors {
#       color {
#         red: 162.0
#         green: 157.0
#         blue: 126.0
#       }
#       score: 0.022273141890764236
#       pixel_fraction: 0.06576389074325562
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
#
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 155.0
#         green: 156.0
#         blue: 162.0
#       }
#       score: 0.2973148226737976
#       pixel_fraction: 0.4402777850627899
#     }
#     colors {
#       color {
#         red: 26.0
#         green: 22.0
#         blue: 22.0
#       }
#       score: 0.2609545886516571
#       pixel_fraction: 0.056458331644535065
#     }
#     colors {
#       color {
#         red: 54.0
#         green: 50.0
#         blue: 51.0
#       }
#       score: 0.14950236678123474
#       pixel_fraction: 0.09763889014720917
#     }
#     colors {
#       color {
#         red: 86.0
#         green: 84.0
#         blue: 90.0
#       }
#       score: 0.12736041843891144
#       pixel_fraction: 0.06479166448116302
#     }
#     colors {
#       color {
#         red: 117.0
#         green: 117.0
#         blue: 123.0
#       }
#       score: 0.11153966188430786
#       pixel_fraction: 0.0560416653752327
#     }
#     colors {
#       color {
#         red: 112.0
#         green: 117.0
#         blue: 135.0
#       }
#       score: 0.031021861359477043
#       pixel_fraction: 0.17569445073604584
#     }
#     colors {
#       color {
#         red: 88.0
#         green: 91.0
#         blue: 108.0
#       }
#       score: 0.012497282586991787
#       pixel_fraction: 0.009236111305654049
#     }
#     colors {
#       color {
#         red: 186.0
#         green: 186.0
#         blue: 195.0
#       }
#       score: 0.005976103246212006
#       pixel_fraction: 0.0015972221735864878
#     }
#     colors {
#       color {
#         red: 134.0
#         green: 141.0
#         blue: 161.0
#       }
#       score: 0.0017226987984031439
#       pixel_fraction: 0.0964583307504654
#     }
#     colors {
#       color {
#         red: 50.0
#         green: 51.0
#         blue: 66.0
#       }
#       score: 0.0013972129672765732
#       pixel_fraction: 0.0013194443890824914
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#         y: 30
#       }
#       vertices {
#         x: 349
#         y: 30
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 0.9699999690055847
#   }
# }
# response :  image_properties_annotation {
#   dominant_colors {
#     colors {
#       color {
#         red: 221.0
#         green: 221.0
#         blue: 215.0
#       }
#       score: 0.3792009949684143
#       pixel_fraction: 0.3040972352027893
#     }
#     colors {
#       color {
#         red: 83.0
#         green: 84.0
#         blue: 81.0
#       }
#       score: 0.06210485100746155
#       pixel_fraction: 0.013749999925494194
#     }
#     colors {
#       color {
#         red: 105.0
#         green: 70.0
#         blue: 45.0
#       }
#       score: 0.023440690711140633
#       pixel_fraction: 0.0037499999161809683
#     }
#     colors {
#       color {
#         red: 203.0
#         green: 203.0
#         blue: 199.0
#       }
#       score: 0.16266196966171265
#       pixel_fraction: 0.33965277671813965
#     }
#     colors {
#       color {
#         red: 22.0
#         green: 49.0
#         blue: 102.0
#       }
#       score: 0.0008256178116425872
#       pixel_fraction: 0.0010416667209938169
#     }
#     colors {
#       color {
#         red: 155.0
#         green: 158.0
#         blue: 156.0
#       }
#       score: 0.07520284503698349
#       pixel_fraction: 0.17826388776302338
#     }
#     colors {
#       color {
#         red: 116.0
#         green: 117.0
#         blue: 114.0
#       }
#       score: 0.05778409168124199
#       pixel_fraction: 0.019375000149011612
#     }
#     colors {
#       color {
#         red: 171.0
#         green: 145.0
#         blue: 118.0
#       }
#       score: 0.0479092076420784
#       pixel_fraction: 0.04416666552424431
#     }
#     colors {
#       color {
#         red: 49.0
#         green: 50.0
#         blue: 48.0
#       }
#       score: 0.04632264003157616
#       pixel_fraction: 0.009444444440305233
#     }
#     colors {
#       color {
#         red: 28.0
#         green: 28.0
#         blue: 26.0
#       }
#       score: 0.03934197127819061
#       pixel_fraction: 0.010416666977107525
#     }
#   }
# }
# crop_hints_annotation {
#   crop_hints {
#     bounding_poly {
#       vertices {
#       }
#       vertices {
#         x: 349
#       }
#       vertices {
#         x: 349
#         y: 349
#       }
#       vertices {
#         y: 349
#       }
#     }
#     confidence: 0.7999999523162842
#     importance_fraction: 1.0
#   }
# }
# /Users/yennanliu/anaconda3/envs/ds_dash/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/01h3n"
#     score: 0.7855499982833862
#     description: "Bee"
#   }
#   web_entities {
#     entity_id: "/m/023j4r"
#     score: 0.7027000188827515
#     description: "Nail"
#   }
#   web_entities {
#     entity_id: "/m/0zdksk1"
#     score: 0.5324000120162964
#     description: "Nail art"
#   }
#   web_entities {
#     entity_id: "/t/24mypdx4svpvn"
#     score: 0.4966999888420105
#   }
#   web_entities {
#     entity_id: "/m/02csf"
#     score: 0.4625000059604645
#     description: "Drawing"
#   }
#   web_entities {
#     entity_id: "/m/0204p6"
#     score: 0.43299999833106995
#     description: "Decal"
#   }
#   web_entities {
#     entity_id: "/m/05b97g"
#     score: 0.3301999866962433
#     description: "Sticker"
#   }
#   web_entities {
#     entity_id: "/t/2559cfx2jwyf6"
#     score: 0.32350000739097595
#   }
#   web_entities {
#     entity_id: "/m/0rzp91s"
#     score: 0.3156999945640564
#   }
#   web_entities {
#     entity_id: "/m/0fz0z"
#     score: 0.3147999942302704
#     description: "Honey bee"
#   }
#   full_matching_images {
#     url: "https://katebroughton.co.uk/content/uploads/2012/10/XMNT_CU_WEB-250x250.jpg"
#   }
#   partial_matching_images {
#     url: "https://katebroughton.co.uk/content/uploads/2017/01/BENT_CU_WEB.jpg"
#   }
#   partial_matching_images {
#     url: "https://i.etsystatic.com/5239034/r/il/a3791a/1131235786/il_570xN.1131235786_f328.jpg"
#   }
#   partial_matching_images {
#     url: "https://i.etsystatic.com/5239034/r/il/4e00ed/1131237164/il_570xN.1131237164_az7m.jpg"
#   }
#   partial_matching_images {
#     url: "https://s359.kapook.com/entry/241b6a10-342c-4f9c-acac-26af181029f6.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/listing/251431918/house-plant-leaf-nail-transfers-cheese"
#     page_title: "house plant leaf nail <b>transfers</b> cheese plant <b>nail art decals</b> | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5239034/r/il/4e00ed/1131237164/il_570xN.1131237164_az7m.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/catalog/nail-art/"
#     page_title: "<b>Nail Art</b> - <b>Kate Broughton</b>"
#     full_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2012/10/XMNT_CU_WEB-250x250.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/shop/bee-nail-stickers/"
#     page_title: "<b>Bee nail transfers</b> \302\2434.00 - <b>Kate Broughton</b>"
#     partial_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2017/01/BENT_CU_WEB.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/sg-en/listing/251431918/house-plant-leaf-nail-transfers-cheese"
#     page_title: "house plant leaf nail <b>transfers</b> cheese plant <b>nail art decals</b> | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5239034/r/il/4e00ed/1131237164/il_570xN.1131237164_az7m.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/shop/exotic-bird-nail-transfers/"
#     page_title: "Exotic bird <b>nail transfers</b> \302\2434.00 - <b>Kate Broughton</b>"
#     full_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2012/10/XMNT_CU_WEB-250x250.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/shop/page/3/"
#     page_title: "Shop - <b>Kate Broughton</b>"
#     partial_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2017/01/BENT_CU_WEB.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/listing/113217939/christmas-nail-transfers-handmade"
#     page_title: "christmas nail <b>transfers</b> handmade festive <b>nail art decals</b> | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5239034/r/il/a3791a/1131235786/il_570xN.1131235786_f328.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/shop/badger-nail-stickers/"
#     page_title: "badger <b>nail transfers</b> \302\2434.00 - <b>Kate Broughton</b>"
#     full_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2012/10/XMNT_CU_WEB-250x250.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://katebroughton.co.uk/shop/owl-nail-stickers/"
#     page_title: "owl <b>nail transfers</b> \302\2434.00 - <b>Kate Broughton</b>"
#     full_matching_images {
#       url: "https://katebroughton.co.uk/content/uploads/2012/10/XMNT_CU_WEB-250x250.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/uk/listing/251431918/house-plant-leaf-nail-transfers-cheese"
#     page_title: "house plant leaf nail <b>transfers</b> cheese plant <b>nail art decals</b> | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5239034/r/il/4e00ed/1131237164/il_570xN.1131237164_az7m.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/d2/d9/2aa0-f0f1-4028-9021-cd0e9a5b5f8e/preview_bee-nail-art-stickers.jpg"
#   }
#   visually_similar_images {
#     url: "https://img.shopstyle-cdn.com/pim/54/b7/54b7197d896d336daae529d5a163f670_xlarge.jpg"
#   }
#   visually_similar_images {
#     url: "https://img1.etsystatic.com/167/0/5239034/il_340x270.1177836373_ncnh.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/40/a0/46c0-638a-46bf-98c1-b5c2b3af51f5/original_wild-flower-nail-art-stickers.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/49/8c/8571-eec7-43b6-9cd6-98f0e6259220/original_cat-nail-art-stickers.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.etsystatic.com/5239034/r/il/e0718d/1131234540/il_570xN.1131234540_n5cj.jpg"
#   }
#   visually_similar_images {
#     url: "https://img.etsystatic.com/il/1dcfa9/1131236038/il_fullxfull.1131236038_cmyg.jpg?version=0"
#   }
#   visually_similar_images {
#     url: "https://i.etsystatic.com/5239034/r/il/bb8a8e/1177835057/il_570xN.1177835057_fzgv.jpg"
#   }
#   visually_similar_images {
#     url: "https://katebroughton.co.uk/content/uploads/2017/01/BCNT_flat_WEB-250x250.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/e1/a4/21fc-1f91-4652-807d-e0fef8c2e3ff/original_christmas-nail-art-stickers.jpg"
#   }
#   best_guess_labels {
#     label: "kate broughton bee nail art transfers"
#     language_code: "en"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/03lnq3"
#     score: 0.9685317277908325
#     description: "Key Chains"
#   }
#   web_entities {
#     entity_id: "/m/0d84n"
#     score: 0.5957000255584717
#     description: "Gift"
#   }
#   web_entities {
#     entity_id: "/g/11c6t_8_mf"
#     score: 0.5699999928474426
#   }
#   web_entities {
#     entity_id: "/m/07kdlck"
#     score: 0.5073000192642212
#     description: "Keyring"
#   }
#   web_entities {
#     entity_id: "/m/0rzp91s"
#     score: 0.4975999891757965
#   }
#   web_entities {
#     entity_id: "/m/01p9z0"
#     score: 0.3702000081539154
#     description: "Wood carving"
#   }
#   web_entities {
#     entity_id: "/m/018y5m"
#     score: 0.2825999855995178
#     description: "Valentine\'s Day"
#   }
#   web_entities {
#     entity_id: "/m/01mrgs"
#     score: 0.27630001306533813
#     description: "Craft"
#   }
#   web_entities {
#     entity_id: "/g/11hdc2bvxf"
#     score: 0.26660001277923584
#     description: "Buddha Groove Hand Carved Wood Sitting Buddha Statue"
#   }
#   web_entities {
#     entity_id: "/m/0lbxg"
#     score: 0.2451000064611435
#     description: "Father"
#   }
#   partial_matching_images {
#     url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/ca/market/wooden_keyring"
#     page_title: "Wooden keyring | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/sg-en/market/wooden_keyring"
#     page_title: "Wooden keyring | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/uk/market/wooden_keyring"
#     page_title: "Wooden keyring | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/market/wooden_keyring"
#     page_title: "Wooden keyring | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/market/days_together_but?page=2"
#     page_title: "Days together but | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/hk-en/listing/265326636/carved-heart-personalised-wooden-plant"
#     page_title: "Carved Heart Personalised Wooden Plant Label | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/5853239/d/il/2262f2/1413436554/il_340x270.1413436554_6qhp.jpg?version=1"
#     }
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/0405/9589/products/SAM_4257_large.JPG?v=1523674156"
#   }
#   visually_similar_images {
#     url: "http://cdn.shopify.com/s/files/1/0405/9589/products/Brass_Tag_Keychain_Engraved_with_7_670_Days__Happy_21st___21_Year_Anniversary_Couples_Keychain_H_grande.jpg?v=1503450697"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/0405/9589/products/His_Cowgirl_Hand_Stamped_on_Aluminum_Tag_Keychain_and_Cowboy_Boot_Charm_Keychain_h_large.jpg?v=1453841512"
#   }
#   visually_similar_images {
#     url: "http://cdn.shopify.com/s/files/1/0405/9589/products/Love_You_Mom_Hand_Stamped_Aluminum_Tag_Keychain_Hand_Stamped_Mothers_Keychain_h_grande.jpg?v=1480220955"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/0405/9589/products/Best_Mom_Ever_Hand_Stamped_Aluminum_Tag_Keychain_Hand_Stamped_Mother_s_Keychain_h_large.JPG?v=1475419844"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/0405/9589/products/Engraved__God_Gave_Me_You__Stainless_Steel_Tag_Keychain_with_Birthstone_Charm_Jan_H_large.jpg?v=1518981640"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/0405/9589/products/my_favorite_spoon_aluminum_keychain_large.JPG?v=1491674108"
#   }
#   visually_similar_images {
#     url: "http://cdn.shopify.com/s/files/1/0405/9589/products/My_Best_Catch_Engraved_on_Aluminum_Tag_Keychain_with_Football_Charm_Keychain_Handmade_Couples_Keychain_h_grande.jpg?v=1507063368"
#   }
#   best_guess_labels {
#     label: "keychain"
#   }
# }
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/0cjkt"
#     score: 0.7092999815940857
#     description: "Father\'s Day"
#   }
#   web_entities {
#     entity_id: "/m/0lbxz"
#     score: 0.6980999708175659
#     description: "Mother"
#   }
#   web_entities {
#     entity_id: "/m/0lbxg"
#     score: 0.6916000247001648
#     description: "Father"
#   }
#   web_entities {
#     entity_id: "/m/0cjjt"
#     score: 0.5662000179290771
#     description: "Mother\'s Day"
#   }
#   web_entities {
#     entity_id: "/m/0d84n"
#     score: 0.5449000000953674
#     description: "Gift"
#   }
#   web_entities {
#     entity_id: "/m/03r8dh"
#     score: 0.2858000099658966
#     description: "Greeting & Note Cards"
#   }
#   web_entities {
#     entity_id: "/m/019_nn"
#     score: 0.19990000128746033
#     description: "Friendship"
#   }
#   web_entities {
#     entity_id: "/m/015qdk"
#     score: 0.1624000072479248
#     description: "Feeling"
#   }
#   web_entities {
#     entity_id: "/m/02h40lc"
#     score: 0.15710000693798065
#     description: "English Language"
#   }
#   web_entities {
#     entity_id: "/m/01kcnl"
#     score: 0.15530000627040863
#     description: "Birthday"
#   }
#   full_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/preview_first-my-father-s-day-card.jpg"
#   }
#   full_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/thumb_first-my-father-s-day-card.jpg"
#   }
#   partial_matching_images {
#     url: "https://www.notsocks.co.nz/media/catalog/product/f/i/first_my_mother_card_1.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/oldenglishcompany/product/first-my-mother-card"
#     page_title: "&#39;<b>first my</b>&#39; <b>mother&#39;s day card</b> by old english company ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/thumb_first-my-father-s-day-card.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/oldenglishcompany/product/first-my-father-s-day-card"
#     page_title: "<b>first my</b> father&#39;s <b>day card</b> by old english company ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/preview_first-my-father-s-day-card.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notsocks.co.nz/first-my-mother-forever-my-friend-card"
#     page_title: "<b>First my Mother</b>, Forever <b>my</b> Friend <b>Card</b> - Not Socks Gifts"
#     partial_matching_images {
#       url: "https://www.notsocks.co.nz/media/catalog/product/f/i/first_my_mother_card_1.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/fathers-day/cards-wrap/sentimental-cards?page=2"
#     page_title: "Sentimental Father&#39;s <b>Day Cards</b> | notonthehighstreet.com"
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/preview_first-my-father-s-day-card.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/fathers-day/cards-wrap/fathers-day-cards?page=19"
#     page_title: "Father&#39;s <b>Day Cards</b> | notonthehighstreet.com"
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/preview_first-my-father-s-day-card.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/oldenglishcompany/product/personalised-father-s-day-print"
#     page_title: "personalised dad print by old english company | notonthehighstreet ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/07/05/6f4c-8ec8-423c-b3c4-0c508de9b368/thumb_first-my-father-s-day-card.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/system/product_images/images/002/037/250/preview_first-my-mother-card.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/e2/7d/0b2a-f948-4fed-b053-6b5e0a79b54c/original_first-mother-s-day-as-my-mummy-personalised-card.jpg"
#   }
#   visually_similar_images {
#     url: "https://quotesboxes.com/wp-content/uploads/2018/08/Happy-Mothers-Day-Quotes-First-My-Mother-Mother39s-Day-Card-for-Mom-CC19-by-OldEnglishCo-218x150.jpg"
#   }
#   visually_similar_images {
#     url: "https://littleglobal.com.au/images/virtuemart/product/resized/cc19-firstmy-mothers-day-card_0x360.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/system/product_images/images/002/073/579/original_first-my-mother-card.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.pinimg.com/236x/d4/c5/c1/d4c5c133c835f1c4bf2656fc0ea03429.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.picclickimg.com/d/l400/pict/172659467138_/First-My-Mother-Forever-My-Friend-Card.jpg"
#   }
#   visually_similar_images {
#     url: "https://img.etsystatic.com/il/858bde/1197078468/il_340x270.1197078468_p8z9.jpg?version=0"
#   }
#   visually_similar_images {
#     url: "http://redonline.cdnds.net/main/thumbs/4752/normal_first-my-mother-forever-my-friend-mother-s-day-card-2.jpg"
#   }
#   visually_similar_images {
#     url: "http://www.familyholiday.net/wp-content/uploads/2014/04/70-Unforgettable-Mother%E2%80%99s-Day-Gift-Ideas-_32.jpg"
#   }
#   best_guess_labels {
#     label: "\'first my\' mother\'s day card"
#     language_code: "en"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/05fc9mj"
#     score: 0.8763999938964844
#     description: "Christmas decoration"
#   }
#   web_entities {
#     entity_id: "/m/025nd"
#     score: 0.6363999843597412
#     description: "Christmas tree"
#   }
#   web_entities {
#     entity_id: "/m/01vq3"
#     score: 0.6108999848365784
#     description: "Christmas Day"
#   }
#   web_entities {
#     entity_id: "/g/11f5j1mf02"
#     score: 0.49939998984336853
#     description: "East of India Wooden"
#   }
#   web_entities {
#     entity_id: "/m/0d84n"
#     score: 0.49709999561309814
#     description: "Gift"
#   }
#   web_entities {
#     entity_id: "/m/04kwhq"
#     score: 0.4002000093460083
#     description: "Christmas ornament"
#   }
#   web_entities {
#     entity_id: "/m/07j7r"
#     score: 0.33149999380111694
#     description: "Tree"
#   }
#   web_entities {
#     entity_id: "/g/11h9vqjh7h"
#     score: 0.28360000252723694
#     description: "Christmas gift"
#   }
#   web_entities {
#     entity_id: "/m/02_wsd"
#     score: 0.23549999296665192
#     description: "Conifer cone"
#   }
#   web_entities {
#     entity_id: "/m/01r546"
#     score: 0.20145021378993988
#     description: "Earring"
#   }
#   full_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/preview_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#   }
#   partial_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/thumb_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/theweddingofmydreams/product/large-wooden-acorn-and-pinecone-christmas-decorations"
#     page_title: "large wooden acorn and pinecone <b>christmas</b> decorations by the ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/preview_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/theweddingofmydreams/product/wooden-star-christmas-decorations"
#     page_title: "wooden star <b>christmas</b> decorations by the wedding of my dreams ..."
#     partial_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/thumb_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/theweddingofmydreams/product/wooden-trees-hanging-christmas-tree-decorations"
#     page_title: "black wooden trees hanging <b>christmas</b> tree decorations by the ..."
#     partial_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/thumb_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/partners/theweddingofmydreams/products?page=5"
#     page_title: "the wedding of my dreams - products | notonthehighstreet.com"
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/11/03/2477-d688-422d-a286-4ed3e7f66aae/preview_large-wooden-acorn-and-pinecone-christmas-decorations.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://image.dhgate.com/0x0s/f2-albu-g6-M00-A3-A8-rBVaSFsVjLiANo1MAAH0xcox0ss345.jpg/10pcs-wooden-baubles-tags-christmas-tree.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.canvasfactory.com/blog/wp-content/uploads/christmas-gift-ideas-2017-diy-gold-glitter-glass-ornaments-min.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.wedgwood.co.uk/media/catalog/product/cache/1/thumbnail/550x550/9df78eab33525d08d6e5fb8d27136e95/w/e/wedgwood-christmas-2018-ls11.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.sincerelysarad.com/wp-content/uploads/2016/10/Balsam-Hill-Tree-Decor.jpg"
#   }
#   visually_similar_images {
#     url: "https://ae01.alicdn.com/kf/HTB15dXmKVXXXXa3XXXXq6xXFXXXB/2pcs-lot-Christmas-font-b-Glass-b-font-ball-Clear-font-b-baubles-b-font-Ornaments.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/25/75/d595-9f6f-4a30-8770-6b9faea64dea/preview_baby-s-first-christmas-personalised-acorn-decoration.jpg"
#   }
#   visually_similar_images {
#     url: "https://sc01.alicdn.com/kf/HTB1ymI_IFXXXXbpapXXq6xXFXXXC/Glass-christmas-balls-christmas-decoration-Glass-christmas.jpg_640x640xz.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/0508/0277/products/IMG_0690_large.JPG?v=1527607586"
#   }
#   visually_similar_images {
#     url: "https://image.made-in-china.com/202f0j00ewkTmbdWPVoZ/High-Quality-Free-Sample-Christmas-Glass-Ball-Light-for-Christmas-Decoration.jpg"
#   }
#   visually_similar_images {
#     url: "https://ae01.alicdn.com/kf/HTB1hvS5PXXXXXXKXpXXq6xXFXXXX/Different-Big-package-Glass-Christmas-Ball-Diameter-6cm-8cm-10cm-12cm-15cm-20cm-Transparent-Glass-Globe.jpg"
#   }
#   best_guess_labels {
#     label: "Christmas decoration"
#   }
# }
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/01jwgf"
#     score: 0.47429999709129333
#     description: "Product"
#   }
#   web_entities {
#     entity_id: "/m/05z87"
#     score: 0.29264944791793823
#     description: "plastic"
#   }
#   web_entities {
#     entity_id: "/m/080f_8b"
#     score: 0.27079999446868896
#     description: "Household goods"
#   }
#   web_entities {
#     entity_id: "/m/068fpk"
#     score: 0.2393999993801117
#     description: "Coasters"
#   }
#   web_entities {
#     entity_id: "/g/11f7pg89w2"
#     score: 0.22360000014305115
#   }
#   web_entities {
#     entity_id: "/m/03y18t"
#     score: 0.21649549901485443
#     description: "Product design"
#   }
#   web_entities {
#     entity_id: "/m/0c_jw"
#     score: 0.20829999446868896
#     description: "Furniture"
#   }
#   web_entities {
#     entity_id: "/g/122fpn6r"
#     score: 0.16670000553131104
#     description: "Drink"
#   }
#   web_entities {
#     entity_id: "/m/01cd9"
#     score: 0.15553702414035797
#     description: "Brand"
#   }
#   web_entities {
#     entity_id: "/m/0d84n"
#     score: 0.1534000039100647
#     description: "Gift"
#   }
#   full_matching_images {
#     url: "https://www.tch.net/media/catalog/product/cache/1/small_image/295x295/9df78eab33525d08d6e5fb8d27136e95/3/E/3E6FCFE68270AD01B203DF16C596C1D5.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.tch.net/shop-by-product/coasters"
#     page_title: "Coasters - Shop By Product - Tch.net"
#     full_matching_images {
#       url: "https://www.tch.net/media/catalog/product/cache/1/small_image/295x295/9df78eab33525d08d6e5fb8d27136e95/3/E/3E6FCFE68270AD01B203DF16C596C1D5.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.tch.net/shop-by-product/coasters?limit=24"
#     page_title: "Coasters - Shop By Product - Tch.net"
#     full_matching_images {
#       url: "https://www.tch.net/media/catalog/product/cache/1/small_image/295x295/9df78eab33525d08d6e5fb8d27136e95/3/E/3E6FCFE68270AD01B203DF16C596C1D5.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://image.made-in-china.com/202f0j00YtVfnwEqZMbN/Custom-Recycled-Absorbent-Paper-Beer-Drink-Coasters.jpg"
#   }
#   visually_similar_images {
#     url: "https://image.made-in-china.com/202f0j00AEiYJatbavcf/Custom-Pulpboard-Absorbent-Paper-Bar-Drink-Coaster.jpg"
#   }
#   visually_similar_images {
#     url: "https://sc01.alicdn.com/kf/HTB1MPQWJpXXXXXQXpXX760XFXXXJ/Led-funny-tempered-glass-material-drink-coaster.png"
#   }
#   visually_similar_images {
#     url: "https://sc02.alicdn.com/kf/HTB11JO4MpXXXXaJXpXXq6xXFXXXc/company-logo-real-leather-metal-drink-coasters.jpg_350x350.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.picclickimg.com/d/l400/pict/162827257196_/Vintage-Travel-Poster-Drink-Coaster-San-Francisco.jpg"
#   }
#   visually_similar_images {
#     url: "https://image.made-in-china.com/202f0j00CQwGueOBMvqj/Custom-Promotional-Special-Shape-Absorbent-Paper-Drink-Coaster.jpg"
#   }
#   visually_similar_images {
#     url: "http://device.com.co/wp-content/uploads/2018/05/cute-toaster-toaster-coaster-super-cute-toaster-with-happy-popping-toast-on-a-drink-coaster.jpg"
#   }
#   visually_similar_images {
#     url: "https://sc02.alicdn.com/kf/HTB1WRS0IpXXXXXnXpXXq6xXFXXXv/zinc-alloy-water-proof-cup-coaster-with.jpg_350x350.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.pinimg.com/236x/21/46/37/214637ee2da64bc1eb1d67d01dca8eef--custom-coasters-personalized-coasters.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.pinimg.com/originals/72/6d/fd/726dfd477b53db27af326676e8bdcee2.jpg"
#   }
#   best_guess_labels {
#     label: "Drink coaster"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/027_ny3"
#     score: 0.5065940022468567
#     description: "Still life photography"
#   }
#   web_entities {
#     entity_id: "/m/0jjw"
#     score: 0.40880000591278076
#     description: "Art"
#   }
#   web_entities {
#     entity_id: "/m/01spzs"
#     score: 0.4067222774028778
#     description: "Still life"
#   }
#   web_entities {
#     entity_id: "/m/0h0vk"
#     score: 0.37720000743865967
#     description: "Contemporary art"
#   }
#   web_entities {
#     entity_id: "/m/010g1bz6"
#     score: 0.35190001130104065
#     description: "/m/02csf"
#   }
#   web_entities {
#     entity_id: "/g/11cs5flkpx"
#     score: 0.32580000162124634
#     description: "Affordable Art Fair"
#   }
#   web_entities {
#     entity_id: "/t/2bp0gchh8ty8x"
#     score: 0.30239999294281006
#   }
#   web_entities {
#     entity_id: "/m/015r61"
#     score: 0.21804332733154297
#     description: "Modern art"
#   }
#   web_entities {
#     entity_id: "/m/05wkw"
#     score: 0.21379999816417694
#     description: "Photography"
#   }
#   web_entities {
#     entity_id: "/m/02csf"
#     score: 0.20711351931095123
#     description: "Drawing"
#   }
#   partial_matching_images {
#     url: "https://ktedwards.co.uk/wp-content/uploads/2017/02/On-top-of-the-world.jpg"
#   }
#   partial_matching_images {
#     url: "https://affordableartfair.com/media/catalog/product/cache/1/small_image/400x/17f82f742ffe127f42dca9de82fb58b1/o/n/on-top-of-the-world-katie-edwards-illustration-wychwood-art-1.jpg"
#   }
#   partial_matching_images {
#     url: "https://affordableartfair.com/media/catalog/product/cache/1/image/300x/17f82f742ffe127f42dca9de82fb58b1/o/n/on-top-of-the-world-katie-edwards-illustration-wychwood-art-1.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://affordableartfair.com/mont-ventoux"
#     page_title: "Affordable <b>Art</b> Fair | Buy prints online by Eliza Southwood"
#     partial_matching_images {
#       url: "https://affordableartfair.com/media/catalog/product/cache/1/image/300x/17f82f742ffe127f42dca9de82fb58b1/o/n/on-top-of-the-world-katie-edwards-illustration-wychwood-art-1.jpg"
#     }
#   }
#   pages_with_matching_images {
# ...
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/24/9c/845a-9bba-41da-addb-fe9f1f3a1bef/thumb_druzy-triangle-gold-necklace.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/iscahandmimi/product/black-hand-carved-druzy-ring"
#     page_title: "black hand carved <b>druzy</b> ring by iscah and mimi | notonthehighstreet ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/24/9c/845a-9bba-41da-addb-fe9f1f3a1bef/thumb_druzy-triangle-gold-necklace.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://img.etsystatic.com/il/2b118f/1358656195/il_340x270.1358656195_bqpl.jpg?version=0"
#   }
#   best_guess_labels {
#     label: "druzy pendant, blue triangle crystal, gold filled chain, raw stone jewelry, precious stone necklace, gift for girlfriend, birthday present"
#     language_code: "en"
#   }
# }
#
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/01llx7"
#     score: 0.8895000219345093
#     description: "Bracelet"
#   }
#   web_entities {
#     entity_id: "/m/01r546"
#     score: 0.766800045967102
#     description: "Earring"
#   }
#   web_entities {
#     entity_id: "/m/01llwg"
#     score: 0.7286314964294434
#     description: "Necklace"
#   }
#   web_entities {
#     entity_id: "/m/025rs2z"
#     score: 0.7149999737739563
#     description: "Gold"
#   }
#   web_entities {
#     entity_id: "/m/04yf6s0"
#     score: 0.6980000138282776
#     description: "Colored gold"
#   }
#   web_entities {
#     entity_id: "/m/09l0j_"
#     score: 0.6733999848365784
#     description: "Ring"
#   }
#   web_entities {
#     entity_id: "/m/07sh0l"
#     score: 0.6636995673179626
#     description: "Locket"
#   }
#   web_entities {
#     entity_id: "/m/0404d"
#     score: 0.6037999987602234
#     description: "Jewellery"
#   }
#   web_entities {
#     entity_id: "/g/11c6vfcpx7"
#     score: 0.5893999934196472
#   }
#   web_entities {
#     entity_id: "/m/06_vzz4"
#     score: 0.5605999827384949
#     description: "Silver-gilt"
#   }
#   full_matching_images {
#     url: "https://img.shopstyle-cdn.com/pim/1d/8e/1d8ed3be266fd9c5624ae8a449b697cb_xlarge.jpg"
#   }
#   full_matching_images {
#     url: "https://www.biancajones.co.uk/wp-content/uploads/2015/04/pink-tourm-bracelet-300x300.jpg"
#   }
#   partial_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/f6/0b/6b23-9cd3-49ca-8f3c-27ee60231c87/preview_birthstone-initial-bracelet-in-yellow-or-rose-gold.jpg"
#   }
#   pages_with_matching_images {
#     url: "https://www.biancajones.co.uk/personalised-jewellery/jewellery/yellow-gold-vermeil/page/4/"
#     page_title: "Yellow &amp; Rose <b>Gold</b> Vermeil Jewellery by Bianca Jones"
#     full_matching_images {
#       url: "https://www.biancajones.co.uk/wp-content/uploads/2015/04/pink-tourm-bracelet-300x300.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/biancajones/product/birthstone-initial-bracelet-in-yellow-or-rose-gold"
#     page_title: "birthstone initial bracelet in yellow <b>gold</b> vermeil by bianca jones ..."
#     partial_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/f6/0b/6b23-9cd3-49ca-8f3c-27ee60231c87/preview_birthstone-initial-bracelet-in-yellow-or-rose-gold.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/partners/biancajones/products"
#     page_title: "bianca jones jewellery - products | notonthehighstreet.com"
#     partial_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/f6/0b/6b23-9cd3-49ca-8f3c-27ee60231c87/preview_birthstone-initial-bracelet-in-yellow-or-rose-gold.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.biancajones.co.uk/personalised-jewellery/jewellery/bracelets/page/2/"
#     page_title: "Bracelets to Personalise with Initials or coordinates Bianca Jones ..."
#     full_matching_images {
#       url: "https://www.biancajones.co.uk/wp-content/uploads/2015/04/pink-tourm-bracelet-300x300.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.shopstyle.co.uk/browse?fts=gold+belcher+bracelet"
#     page_title: "<b>Gold</b> Belcher Bracelet - ShopStyle UK"
#     full_matching_images {
#       url: "https://img.shopstyle-cdn.com/pim/1d/8e/1d8ed3be266fd9c5624ae8a449b697cb_xlarge.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.shopstyle.co.uk/browse?fts=hand+ring+bracelet+chain"
#     page_title: "Hand Ring Bracelet Chain - ShopStyle UK"
#     full_matching_images {
#       url: "https://img.shopstyle-cdn.com/pim/1d/8e/1d8ed3be266fd9c5624ae8a449b697cb_xlarge.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/2083/6627/products/s-l1600_52_93b945cf-e75b-4536-9dd6-e4f616e16ee8_1400x.jpg?v=1535238881"
#   }
#   visually_similar_images {
#     url: "https://sc02.alicdn.com/kf/HTB13D9CNpXXXXbXXXXXq6xXFXXXU/hoodies-cord-with-metal-tips-Custom-Colored.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/2083/6627/products/s-l1600_51_80a0698e-4db6-4023-abe7-77e8c64cb163_1400x.jpg?v=1535238880"
#   }
#   visually_similar_images {
#     url: "https://images.gunsinternational.com/listings_sub/acc_72668/gi_100640761/Dakota-Arms-Model-76-African-400-HandH-Upgraded-Walnut-Stock-Engraved-Case-Colored-Gold-Inlaid-Talle_100640761_72668_03792D36EF0AF2E1.jpg"
#   }
#   visually_similar_images {
#     url: "http://img.luxwatch4you.com/210_210/cartier-trinity-tri-colored-gold.jpg"
#   }
#   visually_similar_images {
#     url: "http://www.blakeconstructionlimited.co.uk/images/category_86/MSTRDS%20Accessory%20%20Sunglasses%20Shades%20Mumbo%20Mirror%20in%20gold%20colored%20128597%20AWLNCC.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/2790/4588/products/1e613e67-b65b-5ccc-ba31-22e749963afa_2048x.jpg?v=1536466049"
#   }
#   visually_similar_images {
#     url: "http://www.blakeconstructionlimited.co.uk/images/category_86/MSTRDS%20Accessory%20%20Sunglasses%20Shades%20Mumbo%20Mirror%20in%20gold%20colored%20128597%20AWLNCC_1.jpg"
#   }
#   visually_similar_images {
#     url: "http://www.angelsarkchildcare.com/images/348/320028711_16473.jpg"
#   }
#   visually_similar_images {
#     url: "https://www.airlineintl.com/files/14/products14756.jpg"
#   }
#   best_guess_labels {
#     label: "Colored gold"
#   }
# }
# response :  web_detection {
#   web_entities {
#     entity_id: "/m/021w6f"
#     score: 0.7193999886512756
#     description: "Tile"
#   }
#   web_entities {
#     entity_id: "/m/01x5q"
#     score: 0.6675000190734863
#     description: "Ceramic"
#   }
#   web_entities {
#     entity_id: "/m/0jjw"
#     score: 0.5702000260353088
#     description: "Art"
#   }
#   web_entities {
#     entity_id: "/m/081hv"
#     score: 0.564300000667572
#     description: "Wedding"
#   }
#   web_entities {
#     entity_id: "/m/02f6b9"
#     score: 0.5069000124931335
#     description: "Anniversary"
#   }
#   web_entities {
#     entity_id: "/m/01rg3p"
#     score: 0.506600022315979
#     description: "Easel"
#   }
#   web_entities {
#     entity_id: "/m/05wkw"
#     score: 0.4837999939918518
#     description: "Photography"
#   }
#   web_entities {
#     entity_id: "/m/02yk19"
#     score: 0.46129998564720154
#     description: "Wedding anniversary"
#   }
#   web_entities {
#     entity_id: "/m/06gjp9"
#     score: 0.44609999656677246
#     description: "Floral design"
#   }
#   web_entities {
#     entity_id: "/m/0l7_8"
#     score: 0.41040000319480896
#     description: "Floor"
#   }
#   full_matching_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317036128_nmzq_2048x.jpg?v=1522222148"
#   }
#   full_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#   }
#   full_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/preview_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#   }
#   partial_matching_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_2048x.jpg?v=1522411471"
#   }
#   partial_matching_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317037640_c8hi_2048x.jpg?v=1522411471"
#   }
#   partial_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/18/43/f3d8-20b5-4557-ae5b-65dfb3ee4a6c/original_floral-wreath-personalised-wedding-framed-tile.jpg"
#   }
#   partial_matching_images {
#     url: "https://cdn.notonthehighstreet.com/fs/2a/70/80d4-fcdc-4d53-9762-a4ce92f0b0ff/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#   }
#   partial_matching_images {
#     url: "http://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_600x.jpg?v=1522411471"
#   }
#   partial_matching_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317037640_c8hi_400x400.jpg?v=1522411471"
#   }
#   partial_matching_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_400x400.jpg?v=1522411471"
#   }
#   partial_matching_images {
#     url: "https://i.etsystatic.com/14557558/d/il/185ab1/1317036128/il_340x270.1317036128_nmzq.jpg?version=0"
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/hendogdesigns/product/personalised-boys-alphabet-picture-on-a-framed-tile"
#     page_title: "boys alphabet illustration <b>tile</b> on <b>easel or framed</b> by hendog designs ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#     }
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/preview_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#     }
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/2a/70/80d4-fcdc-4d53-9762-a4ce92f0b0ff/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.notonthehighstreet.com/hendogdesigns/product/floral-wreath-personalised-wedding-framed-tile"
#     page_title: "floral wreath <b>personalised wedding tile easel or framed</b> by hendog ..."
#     partial_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/18/43/f3d8-20b5-4557-ae5b-65dfb3ee4a6c/original_floral-wreath-personalised-wedding-framed-tile.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://hendogdesigns.co.uk/products/anniversary-gift-floral-wreath-gift-for-couple-personalised-anniversary-gift-tile-on-easel-or-framed-ruby-wedding-golden-wedding"
#     page_title: "<b>Anniversary</b> Floral Wreath <b>Tile</b> - Oak <b>Easel or Framed</b> - Hendog ..."
#     partial_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317037640_c8hi_2048x.jpg?v=1522411471"
#     }
#     partial_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_400x400.jpg?v=1522411471"
#     }
#     partial_matching_images {
#       url: "http://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_600x.jpg?v=1522411471"
#     }
#     partial_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317037640_c8hi_400x400.jpg?v=1522411471"
#     }
#     partial_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1365061927_8701_2048x.jpg?v=1522411471"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://hendogdesigns.co.uk/products/boys-alphabet-personalised-name-tile-boys-name-tile-on-easel-or-framed-animal-picture-gift-for-him-boys-birthday-kids-art"
#     page_title: "BOYS Alphabet <b>Personalised</b> Name <b>Tile</b> - <b>Framed</b> or Oak <b>Easel</b> ..."
#     full_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317037640_c8hi_2048x.jpg?v=1522411471"
#     }
#     full_matching_images {
#       url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317036128_nmzq_2048x.jpg?v=1522222148"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/uk/listing/519205564/girls-alphabet-personalised-name-tile"
#     page_title: "GIRLS Alphabet <b>Personalised</b> Name <b>Tile</b> Girls Name <b>Tile</b> on - Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/14557558/d/il/185ab1/1317036128/il_340x270.1317036128_nmzq.jpg?version=0"
#     }
#   }
#   pages_with_matching_images {
#     url: "https://www.etsy.com/uk/market/ceramic_initials"
#     page_title: "Ceramic initials | Etsy"
#     partial_matching_images {
#       url: "https://i.etsystatic.com/14557558/d/il/185ab1/1317036128/il_340x270.1317036128_nmzq.jpg?version=0"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://www.ceiimage.org/framed-alphabet-picture/"
#     page_title: "<b>Framed</b> Alphabet Picture - Best Of Alphabet Ceiimage.Org"
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#     }
#   }
#   pages_with_matching_images {
#     url: "http://allstarma.net/alphabet-ceramic-tiles"
#     page_title: "Alphabet Ceramic <b>Tiles</b> Image collections - modern <b>tile</b> texture ..."
#     full_matching_images {
#       url: "https://cdn.notonthehighstreet.com/fs/3b/b7/5a65-27dd-4e30-b1fd-ca180f615c3b/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#     }
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/il_fullxfull.1317032760_frg5_580x@2x.jpg?v=1522222160"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/18/43/f3d8-20b5-4557-ae5b-65dfb3ee4a6c/original_floral-wreath-personalised-wedding-framed-tile.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/b1/d9/adf7-9d71-4f7e-ae1a-ade5cf52e86b/original_floral-wreath-personalised-wedding-framed-tile.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/5b/6e/e1b8-c2be-4c4a-a2fb-0e52da6028d8/original_wedding-anniversary-personalised-framed-tile-picture.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/b5/1d/95a6-d158-464b-aca5-9e4f118264eb/original_wedding-anniversary-personalised-framed-tile-picture.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/FullSizeRender_-_Copy_12_2048x.jpg?v=1522411471"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/36/a7/42c1-b912-4950-9e6b-c565061cad84/original_floral-wreath-personalised-wedding-framed-tile.jpg"
#   }
#   visually_similar_images {
#     url: "https://i.pinimg.com/736x/eb/c7/fd/ebc7fd6013be0185b72d91cce9dc256f--scrabble-crafts-scrabble-letters.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.notonthehighstreet.com/fs/a1/26/2545-e362-4d51-8b4a-d01623ef1250/original_personalised-boys-alphabet-picture-on-a-framed-tile.jpg"
#   }
#   visually_similar_images {
#     url: "https://cdn.shopify.com/s/files/1/2702/0242/products/Photo_24-05-2017_14_18_05_2048x.jpg?v=1522404636"
#   }
#   best_guess_labels {
#     label: "wedding anniversary personalised tile easel or framed"
#     language_code: "en"
#   }
# }
# /Users/yennanliu/anaconda3/envs/ds_dash/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/yennanliu/anaconda3/envs/ds_dash/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_10k_random_.head(3)
# Out:
#                                                  url  \
# 0  https://assets-notonthehighstreet-com.s3.amazo...
# 1  https://assets-notonthehighstreet-com.s3.amazo...
# 2  https://assets-notonthehighstreet-com.s3.amazo...
#
#                                       image_property  \
# 0  {'imagePropertiesAnnotation': {'dominantColors...
# 1  {'imagePropertiesAnnotation': {'dominantColors...
# 2  {'imagePropertiesAnnotation': {'dominantColors...
#
#                                        web_detection  \
# 0  {'webDetection': {'fullMatchingImages': [{'url...
# 1  {'webDetection': {'visuallySimilarImages': [{'...
# 2  {'webDetection': {'fullMatchingImages': [{'url...
#
#                                           web_entity
# 0  [{'description': 'Bee', 'entityId': '/m/01h3n'...
# 1  [{'description': 'Key Chains', 'entityId': '/m...
# 2  [{'description': 'Father's Day', 'entityId': '...

# %%
# convert web_entity to df 
frame = pd.DataFrame()
list_ = []

#for i in range(5):
for i in range(len(df_10k_random_)):
  url_ = df_10k_random_.iloc[i]['url']
  df_web_entity = pd.DataFrame(df_10k_random_.iloc[i]['web_entity'])
  df_web_entity['url'] = url_
  # merge 
  df_10k_random_merge = pd.merge(df_10k_random_, df_web_entity,  how='inner', left_on=['url'], right_on=['url'])
  list_.append(df_10k_random_merge)
frame = pd.concat(list_)
frame = frame.reset_index()

# %%
frame
# Out:
#     index                                                url  \
# 0       0  https://assets-notonthehighstreet-com.s3.amazo...
# 1       1  https://assets-notonthehighstreet-com.s3.amazo...
# 2       2  https://assets-notonthehighstreet-com.s3.amazo...
# 3       3  https://assets-notonthehighstreet-com.s3.amazo...
# 4       4  https://assets-notonthehighstreet-com.s3.amazo...
# 5       5  https://assets-notonthehighstreet-com.s3.amazo...
# 6       6  https://assets-notonthehighstreet-com.s3.amazo...
# 7       7  https://assets-notonthehighstreet-com.s3.amazo...
# 8       8  https://assets-notonthehighstreet-com.s3.amazo...
# 9       9  https://assets-notonthehighstreet-com.s3.amazo...
# 10      0  https://assets-notonthehighstreet-com.s3.amazo...
# 11      1  https://assets-notonthehighstreet-com.s3.amazo...
# 12      2  https://assets-notonthehighstreet-com.s3.amazo...
# 13      3  https://assets-notonthehighstreet-com.s3.amazo...
# 14      4  https://assets-notonthehighstreet-com.s3.amazo...
# 15      5  https://assets-notonthehighstreet-com.s3.amazo...
# 16      6  https://assets-notonthehighstreet-com.s3.amazo...
# 17      7  https://assets-notonthehighstreet-com.s3.amazo...
# 18      8  https://assets-notonthehighstreet-com.s3.amazo...
# 19      9  https://assets-notonthehighstreet-com.s3.amazo...
# 20      0  https://assets-notonthehighstreet-com.s3.amazo...
# 21      1  https://assets-notonthehighstreet-com.s3.amazo...
# 22      2  https://assets-notonthehighstreet-com.s3.amazo...
# 23      3  https://assets-notonthehighstreet-com.s3.amazo...
# 24      4  https://assets-notonthehighstreet-com.s3.amazo...
# 25      5  https://assets-notonthehighstreet-com.s3.amazo...
# 26      6  https://assets-notonthehighstreet-com.s3.amazo...
# 27      7  https://assets-notonthehighstreet-com.s3.amazo...
# 28      8  https://assets-notonthehighstreet-com.s3.amazo...
# 29      9  https://assets-notonthehighstreet-com.s3.amazo...
# ..    ...                                                ...
# 70      0  https://assets-notonthehighstreet-com.s3.amazo...
# 71      1  https://assets-notonthehighstreet-com.s3.amazo...
# 72      2  https://assets-notonthehighstreet-com.s3.amazo...
# 73      3  https://assets-notonthehighstreet-com.s3.amazo...
# 74      4  https://assets-notonthehighstreet-com.s3.amazo...
# 75      5  https://assets-notonthehighstreet-com.s3.amazo...
# 76      6  https://assets-notonthehighstreet-com.s3.amazo...
# 77      7  https://assets-notonthehighstreet-com.s3.amazo...
# 78      8  https://assets-notonthehighstreet-com.s3.amazo...
# 79      9  https://assets-notonthehighstreet-com.s3.amazo...
# 80      0  https://assets-notonthehighstreet-com.s3.amazo...
# 81      1  https://assets-notonthehighstreet-com.s3.amazo...
# 82      2  https://assets-notonthehighstreet-com.s3.amazo...
# 83      3  https://assets-notonthehighstreet-com.s3.amazo...
# 84      4  https://assets-notonthehighstreet-com.s3.amazo...
# 85      5  https://assets-notonthehighstreet-com.s3.amazo...
# 86      6  https://assets-notonthehighstreet-com.s3.amazo...
# 87      7  https://assets-notonthehighstreet-com.s3.amazo...
# 88      8  https://assets-notonthehighstreet-com.s3.amazo...
# 89      9  https://assets-notonthehighstreet-com.s3.amazo...
# 90      0  https://assets-notonthehighstreet-com.s3.amazo...
# 91      1  https://assets-notonthehighstreet-com.s3.amazo...
# 92      2  https://assets-notonthehighstreet-com.s3.amazo...
# 93      3  https://assets-notonthehighstreet-com.s3.amazo...
# 94      4  https://assets-notonthehighstreet-com.s3.amazo...
# 95      5  https://assets-notonthehighstreet-com.s3.amazo...
# 96      6  https://assets-notonthehighstreet-com.s3.amazo...
# 97      7  https://assets-notonthehighstreet-com.s3.amazo...
# 98      8  https://assets-notonthehighstreet-com.s3.amazo...
# 99      9  https://assets-notonthehighstreet-com.s3.amazo...
#
#                                        image_property  \
# 0   {'imagePropertiesAnnotation': {'dominantColors...
# 1   {'imagePropertiesAnnotation': {'dominantColors...
# 2   {'imagePropertiesAnnotation': {'dominantColors...
# 3   {'imagePropertiesAnnotation': {'dominantColors...
# 4   {'imagePropertiesAnnotation': {'dominantColors...
# 5   {'imagePropertiesAnnotation': {'dominantColors...
# 6   {'imagePropertiesAnnotation': {'dominantColors...
# 7   {'imagePropertiesAnnotation': {'dominantColors...
# 8   {'imagePropertiesAnnotation': {'dominantColors...
# 9   {'imagePropertiesAnnotation': {'dominantColors...
# 10  {'imagePropertiesAnnotation': {'dominantColors...
# 11  {'imagePropertiesAnnotation': {'dominantColors...
# 12  {'imagePropertiesAnnotation': {'dominantColors...
# 13  {'imagePropertiesAnnotation': {'dominantColors...
# 14  {'imagePropertiesAnnotation': {'dominantColors...
# 15  {'imagePropertiesAnnotation': {'dominantColors...
# 16  {'imagePropertiesAnnotation': {'dominantColors...
# 17  {'imagePropertiesAnnotation': {'dominantColors...
# 18  {'imagePropertiesAnnotation': {'dominantColors...
# 19  {'imagePropertiesAnnotation': {'dominantColors...
# 20  {'imagePropertiesAnnotation': {'dominantColors...
# 21  {'imagePropertiesAnnotation': {'dominantColors...
# 22  {'imagePropertiesAnnotation': {'dominantColors...
# 23  {'imagePropertiesAnnotation': {'dominantColors...
# 24  {'imagePropertiesAnnotation': {'dominantColors...
# 25  {'imagePropertiesAnnotation': {'dominantColors...
# 26  {'imagePropertiesAnnotation': {'dominantColors...
# 27  {'imagePropertiesAnnotation': {'dominantColors...
# 28  {'imagePropertiesAnnotation': {'dominantColors...
# 29  {'imagePropertiesAnnotation': {'dominantColors...
# ..                                                ...
# 70  {'imagePropertiesAnnotation': {'dominantColors...
# 71  {'imagePropertiesAnnotation': {'dominantColors...
# 72  {'imagePropertiesAnnotation': {'dominantColors...
# 73  {'imagePropertiesAnnotation': {'dominantColors...
# 74  {'imagePropertiesAnnotation': {'dominantColors...
# 75  {'imagePropertiesAnnotation': {'dominantColors...
# 76  {'imagePropertiesAnnotation': {'dominantColors...
# 77  {'imagePropertiesAnnotation': {'dominantColors...
# 78  {'imagePropertiesAnnotation': {'dominantColors...
# 79  {'imagePropertiesAnnotation': {'dominantColors...
# 80  {'imagePropertiesAnnotation': {'dominantColors...
# 81  {'imagePropertiesAnnotation': {'dominantColors...
# 82  {'imagePropertiesAnnotation': {'dominantColors...
# 83  {'imagePropertiesAnnotation': {'dominantColors...
# 84  {'imagePropertiesAnnotation': {'dominantColors...
# 85  {'imagePropertiesAnnotation': {'dominantColors...
# 86  {'imagePropertiesAnnotation': {'dominantColors...
# 87  {'imagePropertiesAnnotation': {'dominantColors...
# 88  {'imagePropertiesAnnotation': {'dominantColors...
# 89  {'imagePropertiesAnnotation': {'dominantColors...
# 90  {'imagePropertiesAnnotation': {'dominantColors...
# 91  {'imagePropertiesAnnotation': {'dominantColors...
# 92  {'imagePropertiesAnnotation': {'dominantColors...
# 93  {'imagePropertiesAnnotation': {'dominantColors...
# 94  {'imagePropertiesAnnotation': {'dominantColors...
# 95  {'imagePropertiesAnnotation': {'dominantColors...
# 96  {'imagePropertiesAnnotation': {'dominantColors...
# 97  {'imagePropertiesAnnotation': {'dominantColors...
# 98  {'imagePropertiesAnnotation': {'dominantColors...
# 99  {'imagePropertiesAnnotation': {'dominantColors...
#
#                                         web_detection  \
# 0   {'webDetection': {'fullMatchingImages': [{'url...
# 1   {'webDetection': {'fullMatchingImages': [{'url...
# 2   {'webDetection': {'fullMatchingImages': [{'url...
# 3   {'webDetection': {'fullMatchingImages': [{'url...
# 4   {'webDetection': {'fullMatchingImages': [{'url...
# 5   {'webDetection': {'fullMatchingImages': [{'url...
# 6   {'webDetection': {'fullMatchingImages': [{'url...
# 7   {'webDetection': {'fullMatchingImages': [{'url...
# 8   {'webDetection': {'fullMatchingImages': [{'url...
# 9   {'webDetection': {'fullMatchingImages': [{'url...
# 10  {'webDetection': {'visuallySimilarImages': [{'...
# 11  {'webDetection': {'visuallySimilarImages': [{'...
# 12  {'webDetection': {'visuallySimilarImages': [{'...
# 13  {'webDetection': {'visuallySimilarImages': [{'...
# 14  {'webDetection': {'visuallySimilarImages': [{'...
# 15  {'webDetection': {'visuallySimilarImages': [{'...
# 16  {'webDetection': {'visuallySimilarImages': [{'...
# 17  {'webDetection': {'visuallySimilarImages': [{'...
# 18  {'webDetection': {'visuallySimilarImages': [{'...
# 19  {'webDetection': {'visuallySimilarImages': [{'...
# 20  {'webDetection': {'fullMatchingImages': [{'url...
# 21  {'webDetection': {'fullMatchingImages': [{'url...
# 22  {'webDetection': {'fullMatchingImages': [{'url...
# 23  {'webDetection': {'fullMatchingImages': [{'url...
# 24  {'webDetection': {'fullMatchingImages': [{'url...
# 25  {'webDetection': {'fullMatchingImages': [{'url...
# 26  {'webDetection': {'fullMatchingImages': [{'url...
# 27  {'webDetection': {'fullMatchingImages': [{'url...
# 28  {'webDetection': {'fullMatchingImages': [{'url...
# 29  {'webDetection': {'fullMatchingImages': [{'url...
# ..                                                ...
# 70  {'webDetection': {'fullMatchingImages': [{'url...
# 71  {'webDetection': {'fullMatchingImages': [{'url...
# 72  {'webDetection': {'fullMatchingImages': [{'url...
# 73  {'webDetection': {'fullMatchingImages': [{'url...
# 74  {'webDetection': {'fullMatchingImages': [{'url...
# 75  {'webDetection': {'fullMatchingImages': [{'url...
# 76  {'webDetection': {'fullMatchingImages': [{'url...
# 77  {'webDetection': {'fullMatchingImages': [{'url...
# 78  {'webDetection': {'fullMatchingImages': [{'url...
# 79  {'webDetection': {'fullMatchingImages': [{'url...
# 80  {'webDetection': {'fullMatchingImages': [{'url...
# 81  {'webDetection': {'fullMatchingImages': [{'url...
# 82  {'webDetection': {'fullMatchingImages': [{'url...
# 83  {'webDetection': {'fullMatchingImages': [{'url...
# 84  {'webDetection': {'fullMatchingImages': [{'url...
# 85  {'webDetection': {'fullMatchingImages': [{'url...
# 86  {'webDetection': {'fullMatchingImages': [{'url...
# 87  {'webDetection': {'fullMatchingImages': [{'url...
# 88  {'webDetection': {'fullMatchingImages': [{'url...
# 89  {'webDetection': {'fullMatchingImages': [{'url...
# 90  {'webDetection': {'fullMatchingImages': [{'url...
# 91  {'webDetection': {'fullMatchingImages': [{'url...
# 92  {'webDetection': {'fullMatchingImages': [{'url...
# 93  {'webDetection': {'fullMatchingImages': [{'url...
# 94  {'webDetection': {'fullMatchingImages': [{'url...
# 95  {'webDetection': {'fullMatchingImages': [{'url...
# 96  {'webDetection': {'fullMatchingImages': [{'url...
# 97  {'webDetection': {'fullMatchingImages': [{'url...
# 98  {'webDetection': {'fullMatchingImages': [{'url...
# 99  {'webDetection': {'fullMatchingImages': [{'url...
#
#                                            web_entity  \
# 0   [{'description': 'Bee', 'entityId': '/m/01h3n'...
# 1   [{'description': 'Bee', 'entityId': '/m/01h3n'...
# 2   [{'description': 'Bee', 'entityId': '/m/01h3n'...
# 3   [{'description': 'Bee', 'entityId': '/m/01h3n'...
# 4   [{'description': 'Bee', 'entityId': '/m/01h3n'...
# 5   [{'description': 'Bee', 'entityId': '/m/01h3n'...
# 6   [{'description': 'Bee', 'entityId': '/m/01h3n'...
# 7   [{'description': 'Bee', 'entityId': '/m/01h3n'...
# 8   [{'description': 'Bee', 'entityId': '/m/01h3n'...
# 9   [{'description': 'Bee', 'entityId': '/m/01h3n'...
# 10  [{'description': 'Key Chains', 'entityId': '/m...
# 11  [{'description': 'Key Chains', 'entityId': '/m...
# 12  [{'description': 'Key Chains', 'entityId': '/m...
# 13  [{'description': 'Key Chains', 'entityId': '/m...
# 14  [{'description': 'Key Chains', 'entityId': '/m...
# 15  [{'description': 'Key Chains', 'entityId': '/m...
# 16  [{'description': 'Key Chains', 'entityId': '/m...
# 17  [{'description': 'Key Chains', 'entityId': '/m...
# 18  [{'description': 'Key Chains', 'entityId': '/m...
# 19  [{'description': 'Key Chains', 'entityId': '/m...
# 20  [{'description': 'Father's Day', 'entityId': '...
# 21  [{'description': 'Father's Day', 'entityId': '...
# 22  [{'description': 'Father's Day', 'entityId': '...
# 23  [{'description': 'Father's Day', 'entityId': '...
# 24  [{'description': 'Father's Day', 'entityId': '...
# 25  [{'description': 'Father's Day', 'entityId': '...
# 26  [{'description': 'Father's Day', 'entityId': '...
# 27  [{'description': 'Father's Day', 'entityId': '...
# 28  [{'description': 'Father's Day', 'entityId': '...
# 29  [{'description': 'Father's Day', 'entityId': '...
# ..                                                ...
# 70  [{'description': 'Necklace', 'entityId': '/m/0...
# 71  [{'description': 'Necklace', 'entityId': '/m/0...
# 72  [{'description': 'Necklace', 'entityId': '/m/0...
# 73  [{'description': 'Necklace', 'entityId': '/m/0...
# 74  [{'description': 'Necklace', 'entityId': '/m/0...
# 75  [{'description': 'Necklace', 'entityId': '/m/0...
# 76  [{'description': 'Necklace', 'entityId': '/m/0...
# 77  [{'description': 'Necklace', 'entityId': '/m/0...
# 78  [{'description': 'Necklace', 'entityId': '/m/0...
# 79  [{'description': 'Necklace', 'entityId': '/m/0...
# 80  [{'description': 'Bracelet', 'entityId': '/m/0...
# 81  [{'description': 'Bracelet', 'entityId': '/m/0...
# 82  [{'description': 'Bracelet', 'entityId': '/m/0...
# 83  [{'description': 'Bracelet', 'entityId': '/m/0...
# 84  [{'description': 'Bracelet', 'entityId': '/m/0...
# 85  [{'description': 'Bracelet', 'entityId': '/m/0...
# 86  [{'description': 'Bracelet', 'entityId': '/m/0...
# 87  [{'description': 'Bracelet', 'entityId': '/m/0...
# 88  [{'description': 'Bracelet', 'entityId': '/m/0...
# 89  [{'description': 'Bracelet', 'entityId': '/m/0...
# 90  [{'description': 'Tile', 'entityId': '/m/021w6...
# 91  [{'description': 'Tile', 'entityId': '/m/021w6...
# 92  [{'description': 'Tile', 'entityId': '/m/021w6...
# 93  [{'description': 'Tile', 'entityId': '/m/021w6...
# 94  [{'description': 'Tile', 'entityId': '/m/021w6...
# 95  [{'description': 'Tile', 'entityId': '/m/021w6...
# 96  [{'description': 'Tile', 'entityId': '/m/021w6...
# 97  [{'description': 'Tile', 'entityId': '/m/021w6...
# 98  [{'description': 'Tile', 'entityId': '/m/021w6...
# 99  [{'description': 'Tile', 'entityId': '/m/021w6...
#
#                                           description          entityId  \
# 0                                                 Bee          /m/01h3n
# 1                                                Nail         /m/023j4r
# 2                                            Nail art        /m/0zdksk1
# 3                                                 NaN  /t/24mypdx4svpvn
# 4                                             Drawing          /m/02csf
# 5                                               Decal         /m/0204p6
# 6                                             Sticker         /m/05b97g
# 7                                                 NaN  /t/2559cfx2jwyf6
# 8                                                 NaN        /m/0rzp91s
# 9                                           Honey bee          /m/0fz0z
# 10                                         Key Chains         /m/03lnq3
# 11                                               Gift          /m/0d84n
# 12                                                NaN     /g/11c6t_8_mf
# 13                                            Keyring        /m/07kdlck
# 14                                                NaN        /m/0rzp91s
# 15                                       Wood carving         /m/01p9z0
# 16                                    Valentine's Day         /m/018y5m
# 17                                              Craft         /m/01mrgs
# 18  Buddha Groove Hand Carved Wood Sitting Buddha ...     /g/11hdc2bvxf
# 19                                             Father          /m/0lbxg
# 20                                       Father's Day          /m/0cjkt
# 21                                             Mother          /m/0lbxz
# 22                                             Father          /m/0lbxg
# 23                                       Mother's Day          /m/0cjjt
# 24                                               Gift          /m/0d84n
# 25                              Greeting & Note Cards         /m/03r8dh
# 26                                         Friendship         /m/019_nn
# 27                                            Feeling         /m/015qdk
# 28                                   English Language        /m/02h40lc
# 29                                           Birthday         /m/01kcnl
# ..                                                ...               ...
# 70                                           Necklace         /m/01llwg
# 71                                             Locket         /m/07sh0l
# 72                                           Gemstone          /m/03c4j
# 73                                          Jewellery          /m/0404d
# 74                                  Charms & Pendants         /m/01krjr
# 75                                              Druse        /m/0by0gyx
# 76                                               Ring         /m/09l0j_
# 77                                               Gold        /m/025rs2z
# 78                                            Crystal          /m/01t4h
# 79                                                NaN     /g/11g6ql6l2h
# 80                                           Bracelet         /m/01llx7
# 81                                            Earring         /m/01r546
# 82                                           Necklace         /m/01llwg
# 83                                               Gold        /m/025rs2z
# 84                                       Colored gold        /m/04yf6s0
# 85                                               Ring         /m/09l0j_
# 86                                             Locket         /m/07sh0l
# 87                                          Jewellery          /m/0404d
# 88                                                NaN     /g/11c6vfcpx7
# 89                                        Silver-gilt        /m/06_vzz4
# 90                                               Tile         /m/021w6f
# 91                                            Ceramic          /m/01x5q
# 92                                                Art           /m/0jjw
# 93                                            Wedding          /m/081hv
# 94                                        Anniversary         /m/02f6b9
# 95                                              Easel         /m/01rg3p
# 96                                        Photography          /m/05wkw
# 97                                Wedding anniversary         /m/02yk19
# 98                                      Floral design         /m/06gjp9
# 99                                              Floor          /m/0l7_8
#
#        score
# 0   0.785550
# 1   0.702700
# 2   0.532400
# 3   0.496700
# 4   0.462500
# 5   0.433000
# 6   0.330200
# 7   0.323500
# 8   0.315700
# 9   0.314800
# 10  0.968532
# 11  0.595700
# 12  0.570000
# 13  0.507300
# 14  0.497600
# 15  0.370200
# 16  0.282600
# 17  0.276300
# 18  0.266600
# 19  0.245100
# 20  0.709300
# 21  0.698100
# 22  0.691600
# 23  0.566200
# 24  0.544900
# 25  0.285800
# 26  0.199900
# 27  0.162400
# 28  0.157100
# 29  0.155300
# ..       ...
# 70  0.833964
# 71  0.755606
# 72  0.721800
# 73  0.715500
# 74  0.713400
# 75  0.713200
# 76  0.666700
# 77  0.603100
# 78  0.597800
# 79  0.560500
# 80  0.889500
# 81  0.766800
# 82  0.728631
# 83  0.715000
# 84  0.698000
# 85  0.673400
# 86  0.663700
# 87  0.603800
# 88  0.589400
# 89  0.560600
# 90  0.719400
# 91  0.667500
# 92  0.570200
# 93  0.564300
# 94  0.506900
# 95  0.506600
# 96  0.483800
# 97  0.461300
# 98  0.446100
# 99  0.410400
#
# [100 rows x 8 columns]

# %%
#frame.url.value_counts()
