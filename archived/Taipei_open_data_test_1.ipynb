# %%
! python --version
! date
# Out:
# Python 3.5.1 :: Anaconda 2.4.1 (x86_64)
# Mar 24 Mag 2016 22:22:36 CST

# %% [markdown]
# # source
# http://data.taipei/opendata/datalist/datasetMeta/outboundDesc?id=8ef1626a-892a-4218-8344-f7ac46e1aa48&rid=ddb80380-f1b3-4f8e-8016-7ed9cba571d5

# %%
import requests
from bs4 import BeautifulSoup
import lxml
import urllib, json
import pandas as pd, numpy as np
# %matplotlib inline
# %pylab inline
import seaborn
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/GGV/anaconda/envs/J_env/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
url = "http://data.taipei/opendata/datalist/apiAccess?scope=resourceAquire&rid=ddb80380-f1b3-4f8e-8016-7ed9cba571d5"
response = urllib.urlopen(url)
data = json.loads(response.read())
print data
# Out:
# {u'result': {u'count': 408, u'sort': u'', u'limit': 10000, u'results': [{u'sip': u'10.7.0.11', u'vtyp': u'1', u'sbi': u'0', u'sna': u'\u6377\u904b\u5e02\u653f\u5e9c\u7ad9(3\u865f\u51fa\u53e3)', u'aren': u'The S.W. side of Road Zhongxiao East Road & Road Chung Yan.', u'sno': u'0001', u'bemp': u'0', u'mday': u'20151012003926', u'nbcnt': u'0', u'sv': u'0', u'tot': u'180', u'snaen': u'MRT Taipei City Hall Stataion(Exit 3)-2', u'iid': u'339', u'ar': u'\u5fe0\u5b5d\u6771\u8def/\u677e\u4ec1\u8def(\u6771\u5357\u5074)', u'act': u'0', u'lat': u'25.0408578889', u'lng': u'121.567904444', u'_id': u'1', u'sarea': u'\u4fe1\u7fa9\u5340', u'sareaen': u'Xinyi Dist.', u'sd': u'20000101000000'}, {u'sip': u'10.250.2.1', u'vtyp': u'1', u'sbi': u'0', u'sna': u'\u6377\u904b\u570b\u7236\u7d00\u5ff5\u9928\u7ad9(2\u865f\u51fa\u53e3)', u'aren': u'Sec,4. Zhongxiao E.Rd/GuangFu S. Rd', u'sno': u'0002', u'bemp': u'0', u'mday': u'20151012003917', u'nbcnt': u'0', u'sv': u'0', u'tot': u'48', u'snaen': u'MRT S.Y.S Mem
# ...

# %%
data
# Out:
# {u'result': {u'count': 408,
#   u'limit': 10000,
#   u'offset': 0,
#   u'results': [{u'_id': u'1',
#     u'act': u'0',
#     u'ar': u'\u5fe0\u5b5d\u6771\u8def/\u677e\u4ec1\u8def(\u6771\u5357\u5074)',
#     u'aren': u'The S.W. side of Road Zhongxiao East Road & Road Chung Yan.',
#     u'bemp': u'0',
#     u'iid': u'339',
#     u'lat': u'25.0408578889',
#     u'lng': u'121.567904444',
#     u'mday': u'20151012003926',
#     u'nbcnt': u'0',
#     u'sarea': u'\u4fe1\u7fa9\u5340',
#     u'sareaen': u'Xinyi Dist.',
#     u'sbi': u'0',
#     u'sd': u'20000101000000',
#     u'sip': u'10.7.0.11',
#     u'sna': u'\u6377\u904b\u5e02\u653f\u5e9c\u7ad9(3\u865f\u51fa\u53e3)',
#     u'snaen': u'MRT Taipei City Hall Stataion(Exit 3)-2',
#     u'sno': u'0001',
#     u'sv': u'0',
#     u'tot': u'180',
#     u'vtyp': u'1'},
#    {u'_id': u'2',
#     u'act': u'0',
#     u'ar': u'\u5fe0\u5b5d\u6771\u8def\u56db\u6bb5/\u5149\u5fa9\u5357\u8def\u53e3(\u897f\u5357\u5074)',
# ...

# %%
data['result'].keys()
# Out:
# [u'count', u'sort', u'limit', u'results', u'offset']

# %%
data['result']['results'][1]
# Out:
# {u'_id': u'2',
#  u'act': u'0',
#  u'ar': u'\u5fe0\u5b5d\u6771\u8def\u56db\u6bb5/\u5149\u5fa9\u5357\u8def\u53e3(\u897f\u5357\u5074)',
#  u'aren': u'Sec,4. Zhongxiao E.Rd/GuangFu S. Rd',
#  u'bemp': u'0',
#  u'iid': u'340',
#  u'lat': u'25.041',
#  u'lng': u'121.556945',
#  u'mday': u'20151012003917',
#  u'nbcnt': u'0',
#  u'sarea': u'\u5927\u5b89\u5340',
#  u'sareaen': u'Daan Dist.',
#  u'sbi': u'0',
#  u'sd': u'20000101000000',
#  u'sip': u'10.250.2.1',
#  u'sna': u'\u6377\u904b\u570b\u7236\u7d00\u5ff5\u9928\u7ad9(2\u865f\u51fa\u53e3)',
#  u'snaen': u'MRT S.Y.S Memorial Hall Stataion(Exit 2.)',
#  u'sno': u'0002',
#  u'sv': u'0',
#  u'tot': u'48',
#  u'vtyp': u'1'}

# %%
geo=[[] for k in range(2)]
for item in range(len(data['result']['results'])):
    geo[0].append(data['result']['results'][item]['lat'])
    geo[1].append(data['result']['results'][item]['lng'])

# %%
geo
# Out:
# [[u'25.0408578889',
#   u'25.041',
#   u'25.0377972222',
#   u'25.0360361111',
#   u'25.0365638889',
#   u'25.0347361111',
#   u'25.0330388889',
#   u'25.0352138889',
#   u'25.03159',
#   u'25.0286611111',
#   u'25.034937',
#   u'25.026679',
#   u'25.03809',
#   u'25.06424',
#   u'25.049845',
#   u'25.036084',
#   u'25.05840',
#   u'25.048268',
#   u'25.02863',
#   u'25.025896',
#   u'25.057985',
#   u'25.048616',
#   u'25.055074',
#   u'25.032981',
#   u'25.04543',
#   u'25.050142',
#   u'25.05469',
#   u'25.04814',
#   u'25.03164',
#   u'25.017054',
#   u'25.022413',
#   u'25.023884',
#   u'25.04878',
#   u'25.058369',
#   u'25.059978',
#   u'25.02101',
#   u'25.033700',
#   u'25.02665',
#   u'25.058',
#   u'25.04287',
#   u'25.047425',
#   u'25.04431',
#   u'25.035639',
#   u'25.05973',
#   u'25.01476  ',
#   u'25.05646',
#   u'25.041924 ',
#   u'25.05247',
#   u'25.040901',
#   u'25.062002',
#   u'25.065031',
#   u'25.054761',
#   u'25.044781',
#   u'25.028798',
# ...

# %%
location = pd.DataFrame(geo).T
location.columns = ['lat', 'lon']
location
# Out:
#                lat            lon
# 0    25.0408578889  121.567904444
# 1           25.041     121.556945
# 2    25.0377972222  121.565169444
# 3    25.0360361111     121.562325
# 4    25.0365638889    121.5686639
# 5    25.0347361111  121.565658333
# 6    25.0330388889  121.565619444
# 7    25.0352138889  121.563688889
# 8         25.03159     121.574353
# 9    25.0286611111  121.566116667
# 10       25.034937      121.55762
# 11       25.026679     121.561747
# 12        25.03809      121.58367
# 13        25.06424      121.54037
# 14       25.049845     121.571885
# 15       25.036084     121.579135
# 16        25.05840      121.55504
# 17       25.048268     121.552278
# 18        25.02863      121.56981
# 19       25.025896     121.543293
# 20       25.057985     121.548982
# 21       25.048616     121.578095
# 22       25.055074     121.602798
# 23       25.032981     121.537328
# 24        25.04543      121.57205
# 25       25.050142     121.592375
# ...
