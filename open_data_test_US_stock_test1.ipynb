# %%
! python --version
! date
# Out:
# Python 3.5.1 :: Anaconda 2.4.1 (x86_64)
# Gio 26 Mag 2016 13:54:17 CST

# %%
# import modules 

import quandl
import pandas as pd, numpy as np
# %matplotlib inline
# %pylab inline
import seaborn
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/GGV/anaconda/envs/GGV_DASH/lib/python3.4/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
#  input API key 
# https://www.quandl.com/tools/python
# http://pythonhosted.org/Quandl/
# https://pypi.python.org/pypi/Quandl/3.0.0

quandl.ApiConfig.api_key = "8xawN97zMz2wU2xEuUen"

# %%
data = quandl.get('GOOG/NYSE_IBM', collapse='weekly') 
data.head()
# Out:
#             Open  High    Low  Close  Volume
# Date
# 1981-03-15     0   NaN  15.81  15.81     NaN
# 1981-03-22     0   NaN  15.69  15.78     NaN
# 1981-03-29     0   NaN  15.41  15.44     NaN
# 1981-04-05     0   NaN  15.19  15.28     NaN
# 1981-04-12     0   NaN  15.12  15.19     NaN

# %%
quandl.get("FRED/GDP")
# Out:
#               VALUE
# DATE
# 1947-01-01    243.1
# 1947-04-01    246.3
# 1947-07-01    250.1
# 1947-10-01    260.3
# 1948-01-01    266.2
# 1948-04-01    272.9
# 1948-07-01    279.5
# 1948-10-01    280.7
# 1949-01-01    275.4
# 1949-04-01    271.7
# 1949-07-01    273.3
# 1949-10-01    271.0
# 1950-01-01    281.2
# 1950-04-01    290.7
# 1950-07-01    308.5
# 1950-10-01    320.3
# 1951-01-01    336.4
# 1951-04-01    344.5
# 1951-07-01    351.8
# 1951-10-01    356.6
# 1952-01-01    360.2
# 1952-04-01    361.4
# 1952-07-01    368.1
# 1952-10-01    381.2
# 1953-01-01    388.5
# 1953-04-01    392.3
# 1953-07-01    391.7
# 1953-10-01    386.5
# 1954-01-01    385.9
# 1954-04-01    386.7
# ...             ...
# 2008-10-01  14549.9
# 2009-01-01  14383.9
# 2009-04-01  14340.4
# 2009-07-01  14384.1
# 2009-10-01  14566.5
# 2010-01-01  14681.1
# 2010-04-01  14888.6
# 2010-07-01  15057.7
# 2010-10-01  15230.2
# 2011-01-01  15238.4
# 2011-04-01  15460.9
# 2011-07-01  15587.1
# 2011-10-01  15785.3
# ...

# %%
quandl.get("FRED/GDP", start_date="2001-12-31", end_date="2005-12-31")
# Out:
#               VALUE
# DATE
# 2002-01-01  10834.4
# 2002-04-01  10934.8
# 2002-07-01  11037.1
# 2002-10-01  11103.8
# 2003-01-01  11230.1
# 2003-04-01  11370.7
# 2003-07-01  11625.1
# 2003-10-01  11816.8
# 2004-01-01  11988.4
# 2004-04-01  12181.4
# 2004-07-01  12367.7
# 2004-10-01  12562.2
# 2005-01-01  12813.7
# 2005-04-01  12974.1
# 2005-07-01  13205.4
# 2005-10-01  13381.6
