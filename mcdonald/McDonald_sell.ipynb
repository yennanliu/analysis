# %%
import sqlite3
import datetime as dt   
import time
import csv
import requests
import pandas as pd, numpy as np
import pprint
import matplotlib.pyplot as plt
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/GGV/anaconda/envs/GGV_DASH/lib/python3.4/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
# helper functions

def sqlite_test():
	try:
		conn = sqlite3.connect('/Users/GGV/Desktop/mcdonald_listings.sqlite')
		c = conn.cursor()
		query = "select * from trafi limit 10 ;"
		df = pd.read_sql_query(query, conn)
		print (df)
		print ("Sqlite connect OK")
	except:
		print ("Sqlite connect failed")




def sqlite_query_df(query):
	try:
		conn = sqlite3.connect('/Users/GGV/Desktop/mcdonald_listings.sqlite')
		c = conn.cursor()
		df = pd.read_sql_query(query, conn)
		print ("Sqlite connect OK")
		return df 
	except:
		print ("Sqlite connect failed")

# %%
query= '''

select * 
FROM listings 
'''
listings = sqlite_query_df(query)
# Out:
# Sqlite connect OK

# %%
query= '''

select * 
FROM reviews 
'''
reviews = sqlite_query_df(query)
# Out:
# Sqlite connect OK

# %%
reviews.head(2)
# Out:
#        username  negative  neutral  positive
# 0  fionasohyuru         0        0        18
# 1    purple0603         0        0         9

# %%
listings.head(2)
# Out:
#        username                                        description  \
# 0  fionasohyuru  Curly fries / Twister Fries (Taste exactly lik...
# 1    purple0603  Brand new in original macdonald packaging\r\rC...
#
#                                   title can_mail  price meetup_details  \
# 0                 Twister fries (2.5kg)     None   18.0           None
# 1  Hello Kitty - Macdonald Royal Series     None   50.0           None
#
#   can_meetup  likes condition meetup_location
# 0    Meet-Up      3       New            None
# 1       None      3      None            None

# %% [markdown]
# #### 1. What is the average number of likes across all listings?

# %%
query_avg_like= '''

select 
avg(likes) 
FROM listings 

'''
avg_like = sqlite_query_df(query_avg_like)
avg_like
# Out:
# Sqlite connect OK
#    avg(likes)
# 0   13.789954

# %% [markdown]
# ####  2. What is the average number of likes for used listings?

# %%
query_avg_like_used= '''

select 
avg(likes) 
FROM listings 
WHERE condition == 'Used'
'''
avg_like_used = sqlite_query_df(query_avg_like_used)
avg_like_used
# Out:
# Sqlite connect OK
#    avg(likes)
# 0    5.418033

# %% [markdown]
# #### 3. What is the average price for all the listings with mcdonald keyword in the title? (Hint: include all variations of mcdonalds)

# %%
query_avg_price_m_keyword= '''

select 
avg(price) 
FROM listings 
WHERE 
LOWER(title)  like '%%mcdonalds%%'
'''
avg_price_m_keyword = sqlite_query_df(query_avg_price_m_keyword)
avg_price_m_keyword
# Out:
# Sqlite connect OK
#    avg(price)
# 0    24.26087

# %% [markdown]
# #### 4. Find the number of listings unrelated to Mcdonalds.

# %%
query_num_unrelated_m= '''


WITH LIST AS (

SELECT * FROM 
listings 
WHERE 

LOWER(title) NOT like '%%mcdonalds%%' 
AND
LOWER(description) NOT like '%%mcdonalds%%'

)

select 
COUNT(*)
FROM LIST 


'''
num_unrelated_m = sqlite_query_df(query_num_unrelated_m)
num_unrelated_m
# Out:
# Sqlite connect OK
#    COUNT(*)
# 0      2427

# %% [markdown]
# DONT know if "MacDonald" is related to "Mcdonalds"  :)

# %% [markdown]
# #### 5. List the usernames of the top 3 sellers with the highest number of positive ratings.

# %%
query_top_3_seller= '''

select 
* 
FROM reviews 
ORDER BY  positive DESC 
LIMIT 3

'''
top_3_seller = sqlite_query_df(query_top_3_seller)
top_3_seller
# Out:
# Sqlite connect OK
#                 username  negative  neutral  positive
# 0                    bxs         0        0      1229
# 1       hardrockseller99         1        0       920
# 2  hellomisterneospacian         3        2       760

# %% [markdown]
# #### 6.  What is the total number of sellers with more than 200 reviews?

# %%
query_review= '''

SELECT count(*)
FROM
  ( SELECT username,
           sum(negative) + sum(positive) + sum(neutral) AS sum_
   FROM reviews
   GROUP BY 1
   HAVING sum_ > 200
   ORDER BY sum_ DESC) sub

'''
review = sqlite_query_df(query_review)
review
# Out:
# Sqlite connect OK
#    count(*)
# 0        66

# %% [markdown]
# #### 7. What is the total number of users with only positive reviews?

# %%
query_only_positive_review= '''

SELECT count(*)
FROM
  ( SELECT 
  username,
  sum(negative),
  sum(positive), 
  sum(neutral)
           
   FROM reviews
   GROUP BY 1
   HAVING sum(negative) = 0
   and sum(neutral) = 0
   and sum(positive) > 0
   ) sub

'''
positive_review = sqlite_query_df(query_only_positive_review)
positive_review
# Out:
# Sqlite connect OK
#    count(*)
# 0      1231

# %% [markdown]
# #### 8.  What is the total number of listings by users with only positive reviews?

# %%
query_list_positive_review= '''

WITH user_list AS
  ( SELECT username
   FROM reviews
   GROUP BY 1
   HAVING sum(negative) = 0
   AND sum(neutral) = 0
   AND sum(positive) > 0)
SELECT count(*)
FROM listings
JOIN user_list ON listings.username = user_list.username
ORDER BY listings.username
   
  

'''
list_positive_review = sqlite_query_df(query_list_positive_review)
list_positive_review
# Out:
# Sqlite connect OK
#    count(*)
# 0      1890

# %% [markdown]
# #### 9.  For the top 3 sellers with the highest number of listings, list their usernames, total listings and the total value of their listings

# %%
query_top_user_detail= '''

select 
username,
count(username),
sum(price),
sum(likes)

FROM listings 
group by username
order by count(username) desc

limit 3 

'''
top_user_detail = sqlite_query_df(query_top_user_detail)
top_user_detail
# Out:
# Sqlite connect OK
#      username  count(username)  sum(price)  sum(likes)
# 0    eliset08               62      2115.0         344
# 1      tmatma               56       695.0         172
# 2  scotty2198               24       663.0        3694

# %% [markdown]
# #### 10.  For the top 3 sellers with the most reviews, list their usernames, total listings, and total reviews in descending number of reviews received by each seller

# %%
listings
# Out:
#                  username                                        description  \
# 0            fionasohyuru  Curly fries / Twister Fries (Taste exactly lik...
# 1              purple0603  Brand new in original macdonald packaging\r\rC...
# 2               bakaarisu  From the macdonalds toy series _ÙÓ±\r\rWant to...
# 3           lady_moiselle  Brand new in packaging\rMacdonald's happy meal...
# 4            leefabian_ed  Common Room (Negotiable)  $850 for 3 Pax $750 ...
# 5               garrieneo  Recently bought to accompany my daughter bladi...
# 6              dynamic888  Male Room Sharing (2 in 1room) \r*Balestier Ro...
# 7               hotchoice  OPEN FOR VIEWING_ÙÔÎ\rÏ¬above #10floor Edgefi...
# 8                   nines  Mcdonald Secret Life Of Pets Gidget\r\rWithout...
# 9                kiwichua                                               None
# 10          giftsboutique  All @ $4 MCD Macdonald Coke Contour Bottles \r...
# 11                 zpphie  Brand new set of usborne first reading, 50 boo...
# 12      thesmartbookworms  **Please note this is a pre order listing\rSui...
# 13        rainbow_pumpkin  Brand new in packaging\r\rTags: #LoveBonito #L...
# 14              obisidian  4 in stock, $2 each\r\r*Prices are exclude mai...
# 15                joliene  About 15cm in length \r\rAble to pose as to wh...
# 16               melvis31  Birdie and Hamburglar figurine (soft plushie) ...
# 17              fixit8877  Limited Edition Rio 2016 Mac Swimming Theme Gl...
# 18             babychanel              Like new\rNo nego\r\rMacdonald bless
# 9          3.0                                               None       None
# 10         4.0                                               None    Meet-Up
# 11        88.0                                               None    Meet-Up
# 12        86.0                                               None       None
# 13        55.0                                               None       None
# 14         2.0                                               None       None
# 15         3.0                                               None       None
# 16         3.0                                               None       None
# 17       100.0                                    Chinese Gdn MRT    Meet-Up
# 18         2.0                                               None       None
# 19       200.0        Weekdays after 7pm\rWeekends PM to arrange     Meet-Up
# 20         0.0                                               None    Meet-Up
# 21        20.0                                               None       None
# 22        10.0                                             yishun    Meet-Up
# 23        80.0                                               None       None
# 24         0.0                                   Yio chu kang mrt    Meet-Up
# 25         5.0                                               None       None
# 26        20.0                                               None    Meet-Up
# 27         0.0                                               None       None
# 28       650.0                                               None       None
# 29         6.0                                               None       None
# ...        ...                                                ...        ...
# 2598       3.0  PM me for place to meet up town or east area p...    Meet-Up
# 2599       4.0                                               None       None
# 2600       2.0                                               None       None
# 2601     100.0                                               None       None
# 2602      50.0                                               None       None
# 2603      15.0  Vivocity Macdonald or Cityhall Mrt\rWeekday 6:...    Meet-Up
# 2604      80.0                                               None       None
# 2605      15.0                                               None    Meet-Up
# 2606       0.0                                               None       None
# 2607      20.0                                               None    Meet-Up
# 2608       5.0                                               None       None
# 2609      10.0                                               None       None
# 2610      33.0                                               None    Meet-Up
# 2611       3.0                                               None       None
# 2612       5.0  Mon - Fri before 630pm. Chinatown MRT. \rSun f...    Meet-Up
# 2613      15.0                                               None       None
# 2614       3.0                                               None       None
# 2615       6.0                                               None       None
# 2616       3.0                                               None       None
# 2617       2.0                                               None       None
# 2618     300.0                                               None       None
# 2619       6.0                                               None       None
# 2620      15.0                                               None       None
# 2621       6.0                             Tanjong Pagar / Outram    Meet-Up
# 2622      20.0                                               None    Meet-Up
# 2623      10.0                                               None    Meet-Up
# 2624       0.0                                               None       None
# 2625      15.0                                               None    Meet-Up
# 2626       4.0                                               None       None
# 2627       3.0                                               None       None
#
#       likes condition meetup_location
# 0         3       New            None
# 1         3      None            None
# 2        26      Used            None
# 3        22       New            None
# 4        19      None            None
# 5        24      Used            None
# 6        19      None            None
# 7        33      None            None
# 8         0      None            None
# 9         2      None            None
# 10        1       New            None
# 11       34       New       Singapore
# 12        8       New            None
# 13       22      None            None
# 14        4      None            None
# 15        4      None            None
# 16        2      None            None
# 17        4       New       Singapore
# 18        4      None            None
# 19        8      Used            None
# 20       12       New            None
# 21        5      None            None
# 22        2       New       Singapore
# 23        3       New            None
# 24        8      None       Singapore
# 25        2      None            None
# 26        1      None       Singapore
# 27        4      None            None
# 28       10       New            None
# 29        0      None            None
# ...     ...       ...             ...
# 2598      4       New       Singapore
# 2599    167      None            None
# 2600    193      None            None
# 2601      4       New            None
# 2602      1       New            None
# 2603    105      None       Singapore
# 2604      2       New            None
# 2605     66       New       Singapore
# 2606     16      None            None
# 2607     69       New       Singapore
# 2608     40      None            None
# 2609    113      None            None
# 2610     13       New       Singapore
# 2611      3      None            None
# 2612      6      None            None
# 2613      5      None            None
# 2614     11      None            None
# 2615     12      None            None
# 2616      6      None            None
# 2617      4       New            None
# 2618     12      Used            None
# 2619     15      None            None
# 2620      5      None            None
# 2621      2       New       Singapore
# 2622      2       New            None
# 2623     14       New            None
# 2624     27      None            None
# 2625      2       New            None
# 2626     16      None            None
# 2627    273      None            None
#
# [2628 rows x 10 columns]
