# %%
import urllib 

import requests
from bs4 import BeautifulSoup
import lxml
import urllib, json
import pandas as pd, numpy as np
import pprint
import datetime as dt 
from urllib.parse   import quote

# %% [markdown]
# #  Grab hotel id list in TPE city

# %%
r3.json()[0]
# Out:
# {'address': 'No. 258, Section 2, Yen Ping North Road',
#  'book_domestic_without_cc_details': 0,
#  'checkin': {'from': '15:00', 'to': '23:00'},
#  'checkout': {'from': '', 'to': '12:00'},
#  'city': 'Taipei',
#  'city_id': -2637882,
#  'class': 3,
#  'class_is_estimated': 0,
#  'commission': 0,
#  'contractchain_id': 0,
#  'countrycode': 'tw',
#  'created': '0000-00-00 00:00:00',
#  'creditcard_required': 1,
#  'currencycode': 'TWD',
#  'district': '',
#  'exact_class': '3.0',
#  'hotel_id': '73010',
#  'hoteltype_id': 14,
#  'is_closed': 0,
#  'languagecode': 'en',
#  'location': {'latitude': 25.0604831410682, 'longitude': 121.511203050613},
#  'max_persons_in_reservation': 0,
#  'max_rooms_in_reservation': 0,
#  'maxrate': 2940,
#  'minrate': 1799,
#  'name': 'Dong Wu Hotel',
#  'nr_rooms': 60,
#  'pagename': 'dongwu',
#  'preferred': 0,
#  'ranking': 1436381,
#  'review_nr': 1256,
#  'review_score': 8.5,
#  'url': 'http://www.booking.com/hotel/tw/dongwu.html',
#  'zip': '103'}

# %%
output = [[] for k in range(0,8)]


for count, item in reversed(list(enumerate(r3.json()))):
    
    output[0].append(r3.json()[count]['name'])
    output[1].append(r3.json()[count]['address'])
    output[2].append(r3.json()[count]['city'])
    output[3].append(r3.json()[count]['city_id'])
    output[4].append(r3.json()[count]['hotel_id'])
    output[5].append(r3.json()[count]['location']['latitude'])
    output[6].append(r3.json()[count]['location']['longitude'])
    output[7].append(r3.json()[count]['zip'])

# %%
df_ = pd.DataFrame(output).T
df_.columns = [['name','address','city','city_id','hotel_id','latitude','longitude','zip']]
df_.head()
# Out:
#                           name                                      address  \
# 0                       臺灣米勒會館                   2 Section 2, Xinglong Road
# 1      Taipei Beautiful Hostel                3F-1, No. 35, Hanzhong Street
# 2  New Castle Apartment Beitou                               99 Xinmin Road
# 3                  Linsen Loft  No. 500, Linsen N. Road, Zhongshan District
# 4                  JunLi Hotel                      No. 16, Gongyuan Street
#
#      city   city_id hotel_id latitude longitude  zip
# 0  Taipei  -2637882  2229994  24.9986   121.545  116
# 1  Taipei  -2637882  2224408  25.0443   121.507  108
# 2  Taipei  -2637882  2202783  25.1416   121.514  112
# 3  Taipei  -2637882  2171075  25.0617   121.526  104
# 4  Taipei  -2637882  2141659  25.0091   121.463  220

# %% [markdown]
# # Grab hotel photos  in TPE city

# %%
output_photo = [[] for k in range(0,3)]


for count, item in reversed(list(enumerate(r3.json()))):
    
    output_photo[0].append(r4.json()[count]['hotel_id'])
    output_photo[1].append(r4.json()[count]['url_max300'])
    output_photo[2].append(r4.json()[count]['url_original'])

# %%
df_photo = pd.DataFrame(output_photo).T
df_photo.columns = [['hotel_id','url_max300','url_original']]

df_photo_ = df_photo.groupby('hotel_id').first().reset_index()
df_photo_.head()
# Out:
#   hotel_id                                         url_max300  \
# 0   173172  http://aff.bstatic.com/images/hotel/max300_wat...
# 1   173181  http://aff.bstatic.com/images/hotel/max300_wat...
# 2   174086  http://aff.bstatic.com/images/hotel/max300_wat...
# 3   175162  http://aff.bstatic.com/images/hotel/max300_wat...
# 4   175170  http://aff.bstatic.com/images/hotel/max300_wat...
#
#                                         url_original
# 0  http://aff.bstatic.com/images/hotel/max500_wat...
# 1  http://aff.bstatic.com/images/hotel/max500_wat...
# 2  http://aff.bstatic.com/images/hotel/max500_wat...
# 3  http://aff.bstatic.com/images/hotel/max500_wat...
# 4  http://aff.bstatic.com/images/hotel/max500_wat...

# %%
df_merge = pd.merge(df_,df_photo_,  how='left',on = 'hotel_id')

df_merge.sort('hotel_id')
# Out:
# //anaconda/envs/g_dash/lib/python3.4/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#                                         name  \
# 298                            Yesinn Taipei
# 297                    Meander Hostel Taipei
# 296                  The Gaia Hotel - Taipei
# 295                 Taipei 101 SPARKLE Hotel
# 294                                Cho Hotel
# 293                 Green World Hotel Sansui
# 292         Hotel Puri Taipei Station Branch
# 291                         Inn Cube - Ximen
# 290                     New May Flower Hotel
# 289                                CHECK inn
# 288                              Horizon Inn
# 287        Beauty Hotels Taipei - Hotel Bfun
# 286                 Mandarin Oriental Taipei
# 285  Easymind Guesthouse Taipei Main Station
# 284                  ColorMix Hotel & Hostel
# 283                                Liz Hotel
# 282             City Suites - Taipei Nandong
# 281                         Hotel Prima Casa
# 280               City Suites - Taipei Nanxi
# 279                           Fun Inn Taipei
# 278          Star Hostel Taipei Main Station
# 277                               York Hotel
# 276                           I'm Inn Taipei
# 275                           Hotel Relax II
# 274                                 Just Inn
# 273       Beauty Hotels Taipei - Hotel Bchic
# 272           The Tango Hotel Taipei FuHsing
# 271                       Design Ximen Hotel
# 270                             Longshan Inn
# 269                Rose Boutique Hotel-Ximen
# ..                                       ...
# 326             HOTEL COZZI Zhongxiao Taipei
# 325                Ximen Taipei - DreamHouse
# 324          NEOSOHO - Taipei Station Branch
# 591            Evergreen Laurel Hotel Taipei
# 323             Chaiin Hotel - Tzung Tung Fu
# 322                  Backpackers Inn, Taipei
# 590                        Yomi Hotel Taipei
# 321     Muzik Hotel Ximending –Xining Branch
# 320                           Tomorrow Hotel
# 319                      Rose Boutique Hotel
# 318                          Galaxy Mini Inn
# 317                      Friends Yo Yo Hotel
# 316                      Humble House Taipei
# 315                              Lihao Hotel
# 314                              Forever Inn
# 313                             Cheers Hotel
# 312                On My Way - Taipei Hostel
# 311                             Eslite Hotel
# 310                                VIP Hotel
# 309                           Madison Taipei
# 308          Flip Flop Hostel - Main Station
# 307                                 Mei Stay
# 306    Mr Lobster’s Secret Den design hostel
# 305             Green World Hotel - Zhonghua
# 304                       Taipei City Hostel
# 303                              Happy Hotel
# 302                           Dong Men Hotel
# 301                          Main Inn Taipei
# 307   847650   25.048   121.549    105
# 306   849980  25.0504   121.513    103
# 305   852930   25.045   121.509    100
# 304   863445  25.0459   121.505  10842
# 303   877894  25.0499   121.574    105
# 302   881059  25.0345   121.528    100
# 301   890872  25.0497   121.514    103
# 300   899859  25.0083   121.455  22055
# 299   907951  25.0094   121.457    220
#
#                                             url_max300  \
# 298                                                NaN
# 297                                                NaN
# 296                                                NaN
# 295                                                NaN
# 294                                                NaN
# 293                                                NaN
# 292                                                NaN
# 291                                                NaN
# 290                                                NaN
# 289                                                NaN
# 288                                                NaN
# 287                                                NaN
# 286                                                NaN
# 285                                                NaN
# 284                                                NaN
# 283                                                NaN
# 282                                                NaN
# 281                                                NaN
# 280                                                NaN
# 279                                                NaN
# 278                                                NaN
# 277                                                NaN
# 276                                                NaN
# 275                                                NaN
# 274                                                NaN
# 273                                                NaN
# 272                                                NaN
# 271                                                NaN
# 270                                                NaN
# 269                                                NaN
# ..                                                 ...
# 326                                                NaN
# 325                                                NaN
# 324                                                NaN
# 591  http://aff.bstatic.com/images/hotel/max300_wat...
# 323                                                NaN
# 322                                                NaN
# 590  http://aff.bstatic.com/images/hotel/max300_wat...
# 321                                                NaN
# 320                                                NaN
# 319                                                NaN
# 318                                                NaN
# 317                                                NaN
# 316                                                NaN
# 315                                                NaN
# 314                                                NaN
# 313                                                NaN
# 312                                                NaN
# 311                                                NaN
# 310                                                NaN
# 309                                                NaN
# 308                                                NaN
# 307                                                NaN
# 306                                                NaN
# 305                                                NaN
# 304                                                NaN
# 303                                                NaN
# 302                                                NaN
# 301                                                NaN
# 300                                                NaN
# 299                                                NaN
#
#                                           url_original
# 298                                                NaN
# 297                                                NaN
# 296                                                NaN
# 295                                                NaN
# 294                                                NaN
# 293                                                NaN
# 292                                                NaN
# 291                                                NaN
# 290                                                NaN
# 289                                                NaN
# 288                                                NaN
# 287                                                NaN
# 286                                                NaN
# 285                                                NaN
# 284                                                NaN
# 283                                                NaN
# 282                                                NaN
# 281                                                NaN
# 280                                                NaN
# 279                                                NaN
# 278                                                NaN
# 277                                                NaN
# 276                                                NaN
# 275                                                NaN
# 274                                                NaN
# 273                                                NaN
# 272                                                NaN
# 271                                                NaN
# 270                                                NaN
# 269                                                NaN
# ..                                                 ...
# 326                                                NaN
# 325                                                NaN
# 324                                                NaN
# 591  http://aff.bstatic.com/images/hotel/max500_wat...
# 323                                                NaN
# 322                                                NaN
# 590  http://aff.bstatic.com/images/hotel/max500_wat...
# 321                                                NaN
# 320                                                NaN
# 319                                                NaN
# 318                                                NaN
# 317                                                NaN
# 316                                                NaN
# 315                                                NaN
# 314                                                NaN
# 313                                                NaN
# 312                                                NaN
# 311                                                NaN
# 310                                                NaN
# 309                                                NaN
# 308                                                NaN
# 307                                                NaN
# 306                                                NaN
# 305                                                NaN
# 304                                                NaN
# 303                                                NaN
# 302                                                NaN
# 301                                                NaN
# 300                                                NaN
# 299                                                NaN
#
# [596 rows x 10 columns]
